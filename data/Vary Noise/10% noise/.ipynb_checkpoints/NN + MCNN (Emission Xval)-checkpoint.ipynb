# %%
import pandas as pd
import numpy as np
import keras
import scipy
import matplotlib.pyplot as plt
from numpy import mean
from numpy import std
from sklearn.model_selection import GroupKFold
from sklearn import linear_model
from lineartree import RandomForestRegressor
from sklearn import metrics
from scipy.signal import savgol_filter
from keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from scikeras.wrappers import KerasRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
from numpy.random import seed
seed(1)
from tensorflow.keras.utils import set_random_seed
set_random_seed(2)

# %%
def rae(actual, predicted):
    actual = np.asarray(actual).reshape(-1,1)
    predicted = np.asarray(predicted).reshape(-1,1)
    numerator = np.sum(np.abs(predicted - actual))
    denominator = np.sum(np.abs(np.mean(actual) - actual))
    return numerator / denominator

# %%
def peak_eV_nm(peak_eV):
    peak_eV = np.asarray(peak_eV).reshape(-1,1)
    return 1239.84193/peak_eV

# %%
def FWHM_eV_nm(peak_eV,fwhm_eV):
    peak_eV = np.asarray(peak_eV).reshape(-1,1)
    fwhm_eV = np.asarray(fwhm_eV).reshape(-1,1)
    return  2*(1239.84193/(peak_eV-fwhm_eV/2) - 1239.84193/(peak_eV))

# %%
def predict_dist(X, model, num_samples):
    preds = [model(X, training=True) for _ in range(num_samples)]
    return np.hstack(preds)

# %%
def predict_point(X, model, num_samples):
    pred_dist = predict_dist(X, model, num_samples)
    return pred_dist.mean(axis=1)

# %%
#Define models

initializer = keras.initializers.HeNormal(seed=1)
opt = keras.optimizers.Adam(learning_rate=0.001)

model_peak = keras.models.Sequential()
model_peak.add(Dense(5, input_shape=(5,), kernel_initializer=initializer, activation='relu'))
model_peak.add(Dense(50,  activation='relu'))
model_peak.add(keras.layers.Dropout(0.2))
model_peak.add(Dense(50,  activation='relu'))
model_peak.add(keras.layers.Dropout(0.2))
model_peak.add(Dense(1, kernel_initializer=initializer))
# Compile model
model_peak.compile(loss='mean_squared_error', optimizer= opt)

model_fwhm = keras.models.Sequential()
model_fwhm.add(Dense(5, input_shape=(5,), kernel_initializer=initializer, activation='relu'))
model_fwhm.add(Dense(50,  activation='relu'))
model_fwhm.add(keras.layers.Dropout(0.2))
model_fwhm.add(Dense(50,  activation='relu'))
model_fwhm.add(keras.layers.Dropout(0.2))
model_fwhm.add(Dense(1, kernel_initializer=initializer))
# Compile model
model_fwhm.compile(loss='mean_squared_error', optimizer= opt)

model_cascade = keras.models.Sequential()
model_cascade.add(Dense(6, input_shape=(6,), kernel_initializer=initializer, activation='relu'))
model_cascade.add(Dense(50,  activation='relu'))
model_cascade.add(keras.layers.Dropout(0.2))
model_cascade.add(Dense(50,  activation='relu'))
model_cascade.add(keras.layers.Dropout(0.2))
model_cascade.add(Dense(1, kernel_initializer=initializer))
# Compile model
model_cascade.compile(loss='mean_squared_error', optimizer= opt)

# %%
#Xval on Train/Val set, 10-fold cross validation (Group splits), PL Peak, FWHM (eV), Normalized
# load dataset into Pandas DataFrame (cleaned PL data)
df = pd.read_csv('CdSe PL Train Val.csv')

#normalize input and output data
min_params = pd.Series([0, 0, 3, 200, 0, 400, 15, 1239.84193/620, 0.05], index =['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV'])
max_params = pd.Series([50, 50, 150, 310, 600, 620, 80, 1239.84193/400, 0.4], index =['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV'])
df[['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV']] = (df[['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV']] - min_params) / (max_params- min_params)

X = df[['OA_Cd_ratio','T_reactor','Cd_mM','Se_mM','t_s']]
X2 = df[['OA_Cd_ratio','T_reactor','Cd_mM','Se_mM','t_s','Peak_eV']]
y = df['Peak_eV']
z = df['FWHM_eV']
group = df['Expt. No']

#Split groups for cross validation by Experiment number
gkf = GroupKFold(n_splits=10)
matrix = np.zeros([10,16])
matrix_fwhm = np.zeros([10,16])
matrix_cascade = np.zeros([10,16])

j = 0
#Loop through the 10 splits
for train_index, test_index in gkf.split(X, groups=group):
    #Separate out training and test sets
    X_train = X.iloc[train_index, :]
    X2_train = X2.iloc[train_index, :]
    y_train = y[train_index]
    z_train = z[train_index]
    X_test = X.iloc[test_index, :]
    X2_test = X2.iloc[test_index, :]
    y_test = y[test_index]
    z_test = z[test_index]
    
    #Load weights
    model_peak.load_weights('initialize_weights3.h5')
    model_fwhm.load_weights('initialize_weights3.h5')
    model_cascade.load_weights('initialize_weights4.h5')

    #Train models
    #prediction for Peak
    model_peak.fit(X_train, y_train, epochs=300, validation_data=(X_test, y_test),verbose = 1, use_multiprocessing=False, workers = 100)
    y_pred = model_peak.predict(X_test)
    #prediction for FWHM (direct)
    model_fwhm.fit(X_train, z_train, epochs=300, validation_data=(X_test, z_test),verbose = 1, use_multiprocessing=False, workers = 100)
    y_pred_fwhm = model_fwhm.predict(X_test)
    #prediction for FWHM (cascade)
    model_cascade.fit(X2_train, z_train, epochs=300, validation_data=(X2_test, z_test),verbose = 1, use_multiprocessing=False, workers = 100)
    X_test.insert(5, "Peak_eV", model_peak.predict(X_test), True)
    y_pred_cascade = model_cascade.predict(X_test)

    
    #prediction for Peak with dropout
    X_test = X.iloc[test_index, :]
    X_test_t = K.constant(X_test)
    y_pred_d =  predict_point(X_test_t, model_peak, 1000)
    #prediction for FWHM (direct)
    y_pred_fwhm_d = predict_point(X_test_t, model_fwhm, 1000)
    #prediction for FWHM (cascade)
    X_test.insert(5, "Peak_eV", y_pred_d, True)
    X_test_t2 = K.constant(X_test)
    y_pred_cascade_d = predict_point(X_test_t2, model_cascade, 1000)
    
    #errors in eV (normalized)
    #UN-normalize eV predictions by scaling with ratio

    ratio = (1239.84193/400 - 1239.84193/620)
    ratio2 = 0.35
    matrix[j,0] = metrics.mean_absolute_error(y_test, y_pred)*ratio
    matrix[j,1] = metrics.r2_score(y_test, y_pred)
    matrix[j,2] = rae(y_test, y_pred)
    matrix[j,3] = ratio*np.sqrt(metrics.mean_squared_error(y_test, y_pred))
    matrix[j,4] = metrics.mean_absolute_error(y_test, y_pred_d)*ratio 
    matrix[j,5] = metrics.r2_score(y_test, y_pred_d)
    matrix[j,6] = rae(y_test, y_pred_d)
    matrix[j,7] = ratio*np.sqrt(metrics.mean_squared_error(y_test, y_pred_d))

    matrix_fwhm[j,0] = metrics.mean_absolute_error(z_test, y_pred_fwhm)*ratio2
    matrix_fwhm[j,1] = metrics.r2_score(z_test, y_pred_fwhm)
    matrix_fwhm[j,2] = rae(z_test, y_pred_fwhm)
    matrix_fwhm[j,3] = ratio2*np.sqrt(metrics.mean_squared_error(z_test, y_pred_fwhm))
    matrix_fwhm[j,4] = metrics.mean_absolute_error(z_test, y_pred_fwhm_d)*ratio2
    matrix_fwhm[j,5] = metrics.r2_score(z_test, y_pred_fwhm_d)
    matrix_fwhm[j,6] = rae(z_test, y_pred_fwhm_d)
    matrix_fwhm[j,7] = ratio2*np.sqrt(metrics.mean_squared_error(z_test, y_pred_fwhm_d))
    
    matrix_cascade[j,0] = metrics.mean_absolute_error(z_test, y_pred_cascade)*ratio2
    matrix_cascade[j,1] = metrics.r2_score(z_test, y_pred_cascade)
    matrix_cascade[j,2] = rae(z_test, y_pred_cascade)
    matrix_cascade[j,3] = ratio2*np.sqrt(metrics.mean_squared_error(z_test, y_pred_cascade))
    matrix_cascade[j,4] = metrics.mean_absolute_error(z_test, y_pred_cascade_d)*ratio2
    matrix_cascade[j,5] = metrics.r2_score(z_test, y_pred_cascade_d)
    matrix_cascade[j,6] = rae(z_test, y_pred_cascade_d)
    matrix_cascade[j,7] = ratio2*np.sqrt(metrics.mean_squared_error(z_test, y_pred_cascade_d))
    
    

    #errors in nm
    #UNnormalize the data first
    y_test = y_test*(1239.84193/400 - 1239.84193/620)+1239.84193/620
    y_pred = y_pred*(1239.84193/400 - 1239.84193/620)+1239.84193/620
    y_pred_d = y_pred_d*(1239.84193/400 - 1239.84193/620)+1239.84193/620
    z_test = z_test*(0.35)+0.05
    y_pred_fwhm = y_pred_fwhm*(0.35)+0.05
    y_pred_fwhm_d = y_pred_fwhm_d*(0.35)+0.05
    y_pred_cascade = y_pred_cascade*(0.35)+0.05
    y_pred_cascade_d = y_pred_cascade_d*(0.35)+0.05
    
    #Calculate data in nm and eV
    matrix[j,8] = metrics.mean_absolute_error(peak_eV_nm(y_test), peak_eV_nm(y_pred))
    matrix[j,9] = metrics.r2_score(peak_eV_nm(y_test), peak_eV_nm(y_pred))
    matrix[j,10] = rae(peak_eV_nm(y_test), peak_eV_nm(y_pred))
    matrix[j,11] = np.sqrt(metrics.mean_squared_error(peak_eV_nm(y_test), peak_eV_nm(y_pred)))
    matrix[j,12] = metrics.mean_absolute_error(peak_eV_nm(y_test), peak_eV_nm(y_pred_d))
    matrix[j,13] = metrics.r2_score(peak_eV_nm(y_test), peak_eV_nm(y_pred_d))
    matrix[j,14] = rae(peak_eV_nm(y_test), peak_eV_nm(y_pred_d))
    matrix[j,15] = np.sqrt(metrics.mean_squared_error(peak_eV_nm(y_test), peak_eV_nm(y_pred_d)))

    matrix_fwhm[j,8] = metrics.mean_absolute_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm))
    matrix_fwhm[j,9] = metrics.r2_score(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm))
    matrix_fwhm[j,10] = rae(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm))
    matrix_fwhm[j,11] = np.sqrt(metrics.mean_squared_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm)))
    matrix_fwhm[j,12] = metrics.mean_absolute_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm_d)) 
    matrix_fwhm[j,13] = metrics.r2_score(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm_d))
    matrix_fwhm[j,14] = rae(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm_d)) 
    matrix_fwhm[j,15] = np.sqrt(metrics.mean_squared_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm_d))) 

    matrix_cascade[j,8] = metrics.mean_absolute_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade))
    matrix_cascade[j,9] = metrics.r2_score(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade))
    matrix_cascade[j,10] = rae(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade))
    matrix_cascade[j,11] = np.sqrt(metrics.mean_squared_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade)))
    matrix_cascade[j,12] = metrics.mean_absolute_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade_d))
    matrix_cascade[j,13] = metrics.r2_score(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade_d))
    matrix_cascade[j,14] = rae(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade_d))
    matrix_cascade[j,15] = np.sqrt(metrics.mean_squared_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade_d)))

    j+=1

matrix_2 = np.zeros([1,32])
matrix_2[0,:16] = matrix.mean(0)[:16]
matrix_2[0,16:32] = np.std(matrix[:,:16], axis=0)

matrix_3 = np.zeros([1,32])
matrix_3[0,:16] = matrix_fwhm.mean(0)[:16]
matrix_3[0,16:32]= np.std(matrix_fwhm[:,:16], axis=0)

matrix_4 = np.zeros([1,32])
matrix_4[0,:16] = matrix_cascade.mean(0)[:16]
matrix_4[0,16:32] = np.std(matrix_cascade[:,:16], axis=0)

np.set_printoptions(precision=5, threshold=5, edgeitems=4, suppress=True)
# Out:
# Epoch 1/300
# 144/144 [==============================] - 1s 2ms/step - loss: 0.0724 - val_loss: 0.0544
# Epoch 2/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0557 - val_loss: 0.0539
# Epoch 3/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0533 - val_loss: 0.0518
# Epoch 4/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0518 - val_loss: 0.0515
# Epoch 5/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0515 - val_loss: 0.0512
# Epoch 6/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0498 - val_loss: 0.0509
# Epoch 7/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0499 - val_loss: 0.0506
# Epoch 8/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0497 - val_loss: 0.0505
# Epoch 9/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0489 - val_loss: 0.0504
# Epoch 10/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0496 - val_loss: 0.0510
# Epoch 11/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0487 - val_loss: 0.0502
# Epoch 12/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0483 - val_loss: 0.0504
# Epoch 13/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0487 - val_loss: 0.0501
# Epoch 14/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0487 - val_loss: 0.0500
# Epoch 15/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0479 - val_loss: 0.0499
# Epoch 16/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0483 - val_loss: 0.0496
# Epoch 17/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0484 - val_loss: 0.0517
# Epoch 18/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0480 - val_loss: 0.0495
# Epoch 19/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0481 - val_loss: 0.0497
# Epoch 20/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0482 - val_loss: 0.0497
# Epoch 21/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0476 - val_loss: 0.0497
# Epoch 22/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0479 - val_loss: 0.0501
# Epoch 23/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0475 - val_loss: 0.0503
# Epoch 24/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0480 - val_loss: 0.0507
# Epoch 25/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0481 - val_loss: 0.0499
# Epoch 26/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0481 - val_loss: 0.0500
# Epoch 27/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0481 - val_loss: 0.0495
# Epoch 28/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0474 - val_loss: 0.0495
# Epoch 29/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0475 - val_loss: 0.0497
# Epoch 30/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0479 - val_loss: 0.0500
# Epoch 31/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0479 - val_loss: 0.0500
# Epoch 32/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0474 - val_loss: 0.0499
# Epoch 33/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0475 - val_loss: 0.0507
# Epoch 34/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0476 - val_loss: 0.0493
# Epoch 35/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0476 - val_loss: 0.0495
# Epoch 36/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0475 - val_loss: 0.0498
# Epoch 37/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0475 - val_loss: 0.0499
# Epoch 38/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0475 - val_loss: 0.0502
# Epoch 39/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0478 - val_loss: 0.0500
# Epoch 40/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0471 - val_loss: 0.0513
# Epoch 41/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0469 - val_loss: 0.0502
# Epoch 42/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0471 - val_loss: 0.0496
# Epoch 43/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0476 - val_loss: 0.0496
# Epoch 44/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0474 - val_loss: 0.0496
# Epoch 45/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0474 - val_loss: 0.0503
# Epoch 46/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0473 - val_loss: 0.0501
# Epoch 47/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0474 - val_loss: 0.0501
# Epoch 48/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0473 - val_loss: 0.0498
# Epoch 49/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0474 - val_loss: 0.0499
# Epoch 50/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0472 - val_loss: 0.0499
# Epoch 51/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0471 - val_loss: 0.0498
# Epoch 52/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0471 - val_loss: 0.0500
# Epoch 53/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0476 - val_loss: 0.0502
# Epoch 54/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0473 - val_loss: 0.0505
# Epoch 55/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0475 - val_loss: 0.0495
# Epoch 56/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0469 - val_loss: 0.0500
# Epoch 57/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0470 - val_loss: 0.0494
# Epoch 58/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0472 - val_loss: 0.0500
# Epoch 59/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0471 - val_loss: 0.0493
# Epoch 60/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0472 - val_loss: 0.0498
# Epoch 61/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0473 - val_loss: 0.0500
# Epoch 62/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0474 - val_loss: 0.0506
# Epoch 63/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0472 - val_loss: 0.0499
# Epoch 64/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0472 - val_loss: 0.0507
# Epoch 65/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0473 - val_loss: 0.0500
# Epoch 66/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0470 - val_loss: 0.0505
# Epoch 67/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0473 - val_loss: 0.0500
# Epoch 68/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0473 - val_loss: 0.0520
# Epoch 69/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0475 - val_loss: 0.0500
# Epoch 70/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0465 - val_loss: 0.0500
# Epoch 71/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0467 - val_loss: 0.0500
# Epoch 72/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0470 - val_loss: 0.0498
# Epoch 73/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0470 - val_loss: 0.0504
# Epoch 74/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0466 - val_loss: 0.0500
# Epoch 75/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0469 - val_loss: 0.0498
# Epoch 76/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0470 - val_loss: 0.0498
# Epoch 77/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0468 - val_loss: 0.0502
# Epoch 78/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0467 - val_loss: 0.0499
# Epoch 79/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0469 - val_loss: 0.0499
# Epoch 80/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0470 - val_loss: 0.0497
# Epoch 81/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0469 - val_loss: 0.0497
# Epoch 82/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0467 - val_loss: 0.0498
# Epoch 83/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0469 - val_loss: 0.0499
# Epoch 84/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0467 - val_loss: 0.0509
# Epoch 85/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0467 - val_loss: 0.0499
# Epoch 86/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0467 - val_loss: 0.0498
# Epoch 87/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0469 - val_loss: 0.0501
# Epoch 88/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0470 - val_loss: 0.0500
# Epoch 89/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0468 - val_loss: 0.0508
# Epoch 90/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0469 - val_loss: 0.0500
# Epoch 91/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0468 - val_loss: 0.0506
# Epoch 92/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0467 - val_loss: 0.0497
# Epoch 93/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0470 - val_loss: 0.0497
# Epoch 94/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0469 - val_loss: 0.0499
# Epoch 95/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0465 - val_loss: 0.0506
# Epoch 96/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0468 - val_loss: 0.0497
# Epoch 97/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0469 - val_loss: 0.0495
# Epoch 98/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0470 - val_loss: 0.0507
# Epoch 99/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0467 - val_loss: 0.0503
# Epoch 100/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0469 - val_loss: 0.0502
# Epoch 101/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0472 - val_loss: 0.0498
# Epoch 102/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0469 - val_loss: 0.0498
# Epoch 103/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0462 - val_loss: 0.0500
# Epoch 104/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0464 - val_loss: 0.0504
# Epoch 105/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0466 - val_loss: 0.0500
# Epoch 106/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0468 - val_loss: 0.0498
# Epoch 107/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0466 - val_loss: 0.0497
# Epoch 108/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0468 - val_loss: 0.0499
# Epoch 109/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0468 - val_loss: 0.0501
# Epoch 110/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0465 - val_loss: 0.0502
# Epoch 111/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0466 - val_loss: 0.0499
# Epoch 112/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0468 - val_loss: 0.0505
# Epoch 113/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0466 - val_loss: 0.0495
# Epoch 114/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0466 - val_loss: 0.0500
# Epoch 115/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0470 - val_loss: 0.0497
# Epoch 116/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0470 - val_loss: 0.0504
# Epoch 117/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0468 - val_loss: 0.0498
# Epoch 118/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0468 - val_loss: 0.0502
# Epoch 119/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0466 - val_loss: 0.0501
# Epoch 120/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0468 - val_loss: 0.0508
# Epoch 121/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0465 - val_loss: 0.0498
# Epoch 122/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0462 - val_loss: 0.0499
# Epoch 123/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0464 - val_loss: 0.0496
# Epoch 124/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0464 - val_loss: 0.0495
# Epoch 125/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0470 - val_loss: 0.0496
# Epoch 126/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0465 - val_loss: 0.0502
# Epoch 127/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0461 - val_loss: 0.0496
# Epoch 128/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0465 - val_loss: 0.0492
# Epoch 129/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0466 - val_loss: 0.0500
# Epoch 130/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0464 - val_loss: 0.0499
# Epoch 131/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0465 - val_loss: 0.0501
# Epoch 132/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0466 - val_loss: 0.0500
# Epoch 133/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0466 - val_loss: 0.0494
# Epoch 134/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0467 - val_loss: 0.0496
# Epoch 135/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0466 - val_loss: 0.0501
# Epoch 136/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0467 - val_loss: 0.0500
# Epoch 137/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0463 - val_loss: 0.0501
# Epoch 138/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0467 - val_loss: 0.0498
# Epoch 139/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0460 - val_loss: 0.0497
# Epoch 140/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0466 - val_loss: 0.0502
# Epoch 141/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0466 - val_loss: 0.0502
# Epoch 142/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0466 - val_loss: 0.0499
# Epoch 143/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0464 - val_loss: 0.0506
# Epoch 144/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0469 - val_loss: 0.0503
# Epoch 145/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0465 - val_loss: 0.0499
# Epoch 146/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0463 - val_loss: 0.0501
# Epoch 147/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0466 - val_loss: 0.0500
# Epoch 148/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0463 - val_loss: 0.0498
# Epoch 149/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0462 - val_loss: 0.0498
# Epoch 150/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0466 - val_loss: 0.0504
# Epoch 151/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0468 - val_loss: 0.0505
# Epoch 152/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0468 - val_loss: 0.0500
# Epoch 153/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0464 - val_loss: 0.0498
# Epoch 154/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0466 - val_loss: 0.0506
# Epoch 155/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0468 - val_loss: 0.0503
# Epoch 156/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0463 - val_loss: 0.0500
# Epoch 157/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0463 - val_loss: 0.0498
# Epoch 158/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0463 - val_loss: 0.0511
# Epoch 159/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0466 - val_loss: 0.0501
# Epoch 160/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0465 - val_loss: 0.0499
# Epoch 161/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0466 - val_loss: 0.0496
# Epoch 162/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0465 - val_loss: 0.0499
# Epoch 163/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0462 - val_loss: 0.0497
# Epoch 164/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0464 - val_loss: 0.0498
# Epoch 165/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0462 - val_loss: 0.0490
# Epoch 166/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0464 - val_loss: 0.0495
# Epoch 167/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0465 - val_loss: 0.0498
# Epoch 168/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0461 - val_loss: 0.0496
# Epoch 169/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0462 - val_loss: 0.0497
# Epoch 170/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0461 - val_loss: 0.0498
# Epoch 171/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0466 - val_loss: 0.0506
# Epoch 172/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0463 - val_loss: 0.0501
# Epoch 173/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0457 - val_loss: 0.0494
# Epoch 174/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0462 - val_loss: 0.0498
# Epoch 175/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0462 - val_loss: 0.0497
# Epoch 176/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0457 - val_loss: 0.0497
# Epoch 177/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0460 - val_loss: 0.0498
# Epoch 178/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0465 - val_loss: 0.0501
# Epoch 179/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0463 - val_loss: 0.0504
# Epoch 180/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0462 - val_loss: 0.0499
# Epoch 181/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0460 - val_loss: 0.0500
# Epoch 182/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0463 - val_loss: 0.0499
# Epoch 183/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0463 - val_loss: 0.0503
# Epoch 184/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0465 - val_loss: 0.0499
# Epoch 185/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0464 - val_loss: 0.0500
# Epoch 186/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0462 - val_loss: 0.0501
# Epoch 187/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0460 - val_loss: 0.0502
# Epoch 188/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0459 - val_loss: 0.0496
# Epoch 189/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0465 - val_loss: 0.0499
# Epoch 190/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0463 - val_loss: 0.0507
# Epoch 191/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0462 - val_loss: 0.0500
# Epoch 192/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0459 - val_loss: 0.0495
# Epoch 193/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0463 - val_loss: 0.0497
# Epoch 194/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0462 - val_loss: 0.0496
# Epoch 195/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0461 - val_loss: 0.0497
# Epoch 196/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0464 - val_loss: 0.0503
# Epoch 197/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0463 - val_loss: 0.0499
# Epoch 198/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0461 - val_loss: 0.0502
# Epoch 199/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0463 - val_loss: 0.0495
# Epoch 200/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0461 - val_loss: 0.0496
# Epoch 201/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0461 - val_loss: 0.0500
# Epoch 202/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0460 - val_loss: 0.0501
# Epoch 203/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0460 - val_loss: 0.0501
# Epoch 204/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0460 - val_loss: 0.0496
# Epoch 205/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0459 - val_loss: 0.0500
# Epoch 206/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0460 - val_loss: 0.0499
# Epoch 207/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0464 - val_loss: 0.0504
# Epoch 208/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0463 - val_loss: 0.0499
# Epoch 209/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0465 - val_loss: 0.0496
# Epoch 210/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0460 - val_loss: 0.0495
# Epoch 211/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0463 - val_loss: 0.0498
# Epoch 212/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0460 - val_loss: 0.0503
# Epoch 213/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0459 - val_loss: 0.0506
# Epoch 214/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0461 - val_loss: 0.0502
# Epoch 215/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0460 - val_loss: 0.0501
# Epoch 216/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0462 - val_loss: 0.0499
# Epoch 217/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0461 - val_loss: 0.0500
# Epoch 218/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0463 - val_loss: 0.0503
# Epoch 219/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0462 - val_loss: 0.0497
# Epoch 220/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0460 - val_loss: 0.0502
# Epoch 221/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0460 - val_loss: 0.0495
# Epoch 222/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0461 - val_loss: 0.0500
# Epoch 223/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0460 - val_loss: 0.0498
# Epoch 224/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0463 - val_loss: 0.0495
# Epoch 225/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0461 - val_loss: 0.0496
# Epoch 226/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0459 - val_loss: 0.0497
# Epoch 227/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0463 - val_loss: 0.0494
# Epoch 228/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0460 - val_loss: 0.0496
# Epoch 229/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0461 - val_loss: 0.0495
# Epoch 230/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0458 - val_loss: 0.0494
# Epoch 231/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0462 - val_loss: 0.0495
# Epoch 232/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0458 - val_loss: 0.0497
# Epoch 233/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0464 - val_loss: 0.0500
# Epoch 234/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0462 - val_loss: 0.0492
# Epoch 235/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0460 - val_loss: 0.0494
# Epoch 236/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0457 - val_loss: 0.0494
# Epoch 237/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0463 - val_loss: 0.0497
# Epoch 238/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0458 - val_loss: 0.0495
# Epoch 239/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0459 - val_loss: 0.0493
# Epoch 240/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0461 - val_loss: 0.0499
# Epoch 241/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0461 - val_loss: 0.0500
# Epoch 242/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0458 - val_loss: 0.0499
# Epoch 243/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0462 - val_loss: 0.0499
# Epoch 244/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0457 - val_loss: 0.0495
# Epoch 245/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0458 - val_loss: 0.0495
# Epoch 246/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0457 - val_loss: 0.0494
# Epoch 247/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0458 - val_loss: 0.0497
# Epoch 248/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0459 - val_loss: 0.0505
# Epoch 249/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0460 - val_loss: 0.0495
# Epoch 250/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0458 - val_loss: 0.0497
# Epoch 251/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0460 - val_loss: 0.0492
# Epoch 252/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0458 - val_loss: 0.0492
# Epoch 253/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0461 - val_loss: 0.0494
# Epoch 254/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0461 - val_loss: 0.0500
# Epoch 255/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0458 - val_loss: 0.0497
# Epoch 256/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0460 - val_loss: 0.0498
# Epoch 257/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0458 - val_loss: 0.0494
# Epoch 258/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0460 - val_loss: 0.0497
# Epoch 259/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0459 - val_loss: 0.0496
# Epoch 260/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0461 - val_loss: 0.0495
# Epoch 261/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0459 - val_loss: 0.0497
# Epoch 262/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0463 - val_loss: 0.0497
# Epoch 263/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0459 - val_loss: 0.0496
# Epoch 264/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0460 - val_loss: 0.0497
# Epoch 265/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0457 - val_loss: 0.0498
# Epoch 266/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0455 - val_loss: 0.0500
# Epoch 267/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0460 - val_loss: 0.0499
# Epoch 268/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0458 - val_loss: 0.0496
# Epoch 269/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0459 - val_loss: 0.0500
# Epoch 270/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0458 - val_loss: 0.0494
# Epoch 271/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0457 - val_loss: 0.0496
# Epoch 272/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0461 - val_loss: 0.0497
# Epoch 273/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0460 - val_loss: 0.0496
# Epoch 274/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0459 - val_loss: 0.0497
# Epoch 275/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0458 - val_loss: 0.0498
# Epoch 276/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0460 - val_loss: 0.0494
# Epoch 277/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0455 - val_loss: 0.0503
# Epoch 278/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0460 - val_loss: 0.0495
# Epoch 279/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0458 - val_loss: 0.0498
# Epoch 280/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0458 - val_loss: 0.0498
# Epoch 281/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0456 - val_loss: 0.0501
# Epoch 282/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0458 - val_loss: 0.0502
# Epoch 283/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0459 - val_loss: 0.0499
# Epoch 284/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0462 - val_loss: 0.0499
# Epoch 285/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0456 - val_loss: 0.0497
# Epoch 286/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0457 - val_loss: 0.0500
# Epoch 287/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0455 - val_loss: 0.0497
# Epoch 288/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0455 - val_loss: 0.0496
# Epoch 289/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0455 - val_loss: 0.0500
# Epoch 290/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0456 - val_loss: 0.0500
# Epoch 291/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0460 - val_loss: 0.0494
# Epoch 292/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0458 - val_loss: 0.0498
# Epoch 293/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0460 - val_loss: 0.0505
# Epoch 294/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0456 - val_loss: 0.0498
# Epoch 295/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0458 - val_loss: 0.0503
# Epoch 296/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0458 - val_loss: 0.0494
# Epoch 297/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0458 - val_loss: 0.0496
# Epoch 298/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0457 - val_loss: 0.0499
# Epoch 299/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0458 - val_loss: 0.0497
# Epoch 300/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0459 - val_loss: 0.0501
# 16/16 [==============================] - 0s 667us/step
# Epoch 1/300
# 144/144 [==============================] - 1s 2ms/step - loss: 0.0091 - val_loss: 0.0042
# Epoch 2/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0053 - val_loss: 0.0040
# Epoch 3/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0050 - val_loss: 0.0040
# Epoch 4/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0049 - val_loss: 0.0040
# Epoch 5/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 6/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0046 - val_loss: 0.0037
# Epoch 7/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0045 - val_loss: 0.0038
# Epoch 8/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0043 - val_loss: 0.0037
# Epoch 9/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0042 - val_loss: 0.0035
# Epoch 10/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0040 - val_loss: 0.0035
# Epoch 11/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0040 - val_loss: 0.0037
# Epoch 12/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0039 - val_loss: 0.0035
# Epoch 13/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0038 - val_loss: 0.0034
# Epoch 14/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0038 - val_loss: 0.0034
# Epoch 15/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0038 - val_loss: 0.0034
# Epoch 16/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0038 - val_loss: 0.0034
# Epoch 17/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0038 - val_loss: 0.0034
# Epoch 18/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0038 - val_loss: 0.0034
# Epoch 19/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0038 - val_loss: 0.0034
# Epoch 20/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 0.0035
# Epoch 21/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 0.0034
# Epoch 22/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 0.0034
# Epoch 23/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 0.0034
# Epoch 24/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0038 - val_loss: 0.0034
# Epoch 25/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0038 - val_loss: 0.0034
# Epoch 26/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 0.0034
# Epoch 27/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 0.0033
# Epoch 28/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 0.0035
# Epoch 29/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 0.0034
# Epoch 30/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 0.0033
# Epoch 31/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 32/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 0.0033
# Epoch 33/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 0.0034
# Epoch 34/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 0.0034
# Epoch 35/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 0.0035
# Epoch 36/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 0.0034
# Epoch 37/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 0.0033
# Epoch 38/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 0.0033
# Epoch 39/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0036 - val_loss: 0.0033
# Epoch 40/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0036 - val_loss: 0.0034
# Epoch 41/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0036 - val_loss: 0.0033
# Epoch 42/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 0.0033
# Epoch 43/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0036 - val_loss: 0.0034
# Epoch 44/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0036 - val_loss: 0.0034
# Epoch 45/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0036 - val_loss: 0.0033
# Epoch 46/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0036 - val_loss: 0.0033
# Epoch 47/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0036 - val_loss: 0.0035
# Epoch 48/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0036 - val_loss: 0.0033
# Epoch 49/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0036 - val_loss: 0.0034
# Epoch 50/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0035 - val_loss: 0.0034
# Epoch 51/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0036 - val_loss: 0.0032
# Epoch 52/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0035 - val_loss: 0.0034
# Epoch 53/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0036 - val_loss: 0.0033
# Epoch 54/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0036 - val_loss: 0.0033
# Epoch 55/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0036 - val_loss: 0.0033
# Epoch 56/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0036 - val_loss: 0.0034
# Epoch 57/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0036 - val_loss: 0.0033
# Epoch 58/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 59/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0035 - val_loss: 0.0034
# Epoch 60/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 61/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0035 - val_loss: 0.0034
# Epoch 62/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0036 - val_loss: 0.0033
# Epoch 63/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0035 - val_loss: 0.0034
# Epoch 64/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 65/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 66/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0036 - val_loss: 0.0033
# Epoch 67/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 68/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 69/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 70/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 71/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 72/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 73/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 74/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 75/300
# 144/144 [==============================] - 0s 2ms/step - loss: 0.0035 - val_loss: 0.0032
# Epoch 76/300
# 144/144 [==============================] - 0s 2ms/step - loss: 0.0035 - val_loss: 0.0034
# Epoch 77/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 78/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 79/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 80/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 81/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0032
# Epoch 82/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0032
# Epoch 83/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 84/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 85/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0031
# Epoch 86/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 87/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 88/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0032
# Epoch 89/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 90/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 91/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 92/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 93/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 94/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 95/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 96/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 97/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0031
# Epoch 98/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 99/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 100/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 101/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 102/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 103/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 104/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 105/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 106/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 107/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0031
# Epoch 108/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 109/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0034
# Epoch 110/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 111/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 112/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 113/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 114/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 115/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 116/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 117/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 118/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 119/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 120/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 121/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 122/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 123/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 124/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 125/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 126/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 127/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 128/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 129/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 130/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 131/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 132/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 133/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 134/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 135/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0030
# Epoch 136/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 137/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 138/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 139/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 140/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 141/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 142/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 143/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 144/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 145/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 146/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 147/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 148/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 149/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 150/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0030
# Epoch 151/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 152/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 153/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 154/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 155/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 156/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 157/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 158/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 159/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 160/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 161/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 162/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 163/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 164/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 165/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 166/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 167/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 168/300
# ...
# Epoch 147/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 148/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 149/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 150/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 151/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 152/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 153/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 154/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0032
# Epoch 155/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 156/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 157/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 158/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 159/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 160/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 161/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 162/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 163/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 164/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 165/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 166/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 167/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 168/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 169/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 170/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 171/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 172/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 173/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 174/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 175/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 176/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 177/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 178/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 179/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 180/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 181/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0032
# Epoch 182/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 183/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 184/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 185/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0032
# Epoch 186/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 187/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 188/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 189/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 190/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 191/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 192/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 193/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 194/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 195/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 196/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 197/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 198/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0032
# Epoch 199/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 200/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 201/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 202/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 203/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0032
# Epoch 204/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 205/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 206/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 207/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 208/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 209/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 210/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 211/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 212/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 213/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 214/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 215/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 216/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 217/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 218/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 219/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 220/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 221/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 222/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 223/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 224/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 225/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 226/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 227/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 228/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 229/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 230/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 231/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 232/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 233/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 234/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 235/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 236/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 237/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 238/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 239/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 240/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 241/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 242/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 243/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 244/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 245/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0032
# Epoch 246/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 247/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 248/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 249/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 250/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 251/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 252/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 253/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 254/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 255/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 256/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 257/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0030
# Epoch 258/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 259/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 260/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0030
# Epoch 261/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 262/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0032
# Epoch 263/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 264/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 265/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 266/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 267/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 268/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 269/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 270/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 271/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 272/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 273/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 274/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 275/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0032
# Epoch 276/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 277/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0032
# Epoch 278/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0032
# Epoch 279/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0032
# Epoch 280/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 281/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 282/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 283/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 284/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 285/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0032
# Epoch 286/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 287/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 288/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 289/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 290/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 291/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 292/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 293/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 294/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 295/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0030
# Epoch 296/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 297/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0032
# Epoch 298/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0032
# Epoch 299/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 300/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0030
# 16/16 [==============================] - 0s 667us/step
# 16/16 [==============================] - 0s 667us/step

# %%
print('\033[1m' + 'Model without Dropout at Inference' + '\033[0m')
print('\033[1m' + 'Absorbance Peak' + '\033[0m')
print("MAE (eV): \t", "{:.4f}".format(matrix_2[0,0]), "{:.4f}".format(matrix_2[0,16]))
print("R2 (eV):\t", "{:.4f}".format(matrix_2[0,1]), "{:.4f}".format(matrix_2[0,17]))
print("RAE (eV):\t", "{:.4f}".format(matrix_2[0,2]), "{:.4f}".format(matrix_2[0,18]))
print("RMSE (eV):\t", "{:.4f}".format(matrix_2[0,3]), "{:.4f}".format(matrix_2[0,19]))

print("MAE (nm):\t","{:.4f}".format(matrix_2[0,8]), "{:.4f}".format(matrix_2[0,24]))
print("R2 (nm):\t", "{:.4f}".format(matrix_2[0,9]), "{:.4f}".format(matrix_2[0,25]))
print("RAE (nm):\t","{:.4f}".format(matrix_2[0,10]), "{:.4f}".format(matrix_2[0,26]))
print("RMSE (nm):\t", "{:.4f}".format(matrix_2[0,11]), "{:.4f}".format(matrix_2[0,27]))

print('\033[1m' + 'Absorbance FWHM (direct)' + '\033[0m')
print("MAE (eV): \t", "{:.4f}".format(matrix_3[0,0]), "{:.4f}".format(matrix_3[0,16]))
print("R2 (eV):\t", "{:.4f}".format(matrix_3[0,1]), "{:.4f}".format(matrix_3[0,17]))
print("RAE (eV):\t", "{:.4f}".format(matrix_3[0,2]), "{:.4f}".format(matrix_3[0,18]))
print("RMSE (eV):\t", "{:.4f}".format(matrix_3[0,3]), "{:.4f}".format(matrix_3[0,19]))

print("MAE (nm):\t","{:.4f}".format(matrix_3[0,8]), "{:.4f}".format(matrix_3[0,24]))
print("R2 (nm):\t", "{:.4f}".format(matrix_3[0,9]), "{:.4f}".format(matrix_3[0,25]))
print("RAE (nm):\t","{:.4f}".format(matrix_3[0,10]), "{:.4f}".format(matrix_3[0,26]))
print("RMSE (nm):\t", "{:.4f}".format(matrix_3[0,11]), "{:.4f}".format(matrix_3[0,27]))

print('\033[1m' + 'Absorbance FWHM (cascade)' + '\033[0m')
print("MAE (eV): \t", "{:.4f}".format(matrix_4[0,0]), "{:.4f}".format(matrix_4[0,16]))
print("R2 (eV):\t", "{:.4f}".format(matrix_4[0,1]), "{:.4f}".format(matrix_4[0,17]))
print("RAE (eV):\t", "{:.4f}".format(matrix_4[0,2]), "{:.4f}".format(matrix_4[0,18]))
print("RMSE (eV):\t", "{:.4f}".format(matrix_4[0,3]), "{:.4f}".format(matrix_4[0,19]))

print("MAE (nm):\t","{:.4f}".format(matrix_4[0,8]), "{:.4f}".format(matrix_4[0,24]))
print("R2 (nm):\t", "{:.4f}".format(matrix_4[0,9]), "{:.4f}".format(matrix_4[0,25]))
print("RAE (nm):\t","{:.4f}".format(matrix_4[0,10]), "{:.4f}".format(matrix_4[0,26]))
print("RMSE (nm):\t", "{:.4f}".format(matrix_4[0,11]), "{:.4f}".format(matrix_4[0,27]))
# Out:
# Model without Dropout at Inference
# Absorbance Peak
# MAE (eV): 	 0.1892 0.0042
# R2 (eV):	 0.2535 0.0287
# RAE (eV):	 0.8587 0.0198
# RMSE (eV):	 0.2392 0.0052
# MAE (nm):	 43.8498 1.3885
# R2 (nm):	 0.2284 0.0339
# RAE (nm):	 0.8607 0.0193
# RMSE (nm):	 56.5471 2.0842
# Absorbance FWHM (direct)
# MAE (eV): 	 0.0150 0.0007
# R2 (eV):	 0.3676 0.0655
# RAE (eV):	 0.7757 0.0426
# RMSE (eV):	 0.0200 0.0010
# MAE (nm):	 6.8472 0.3293
# R2 (nm):	 0.1728 0.0409
# RAE (nm):	 0.8796 0.0276
# RMSE (nm):	 9.1934 0.4366
# Absorbance FWHM (cascade)
# MAE (eV): 	 0.0146 0.0007
# R2 (eV):	 0.4058 0.0568
# RAE (eV):	 0.7542 0.0360
# RMSE (eV):	 0.0193 0.0009
# MAE (nm):	 6.8035 0.3146
# R2 (nm):	 0.1793 0.0466
# RAE (nm):	 0.8738 0.0212
# RMSE (nm):	 9.1558 0.4390

# %%
print('\033[1m' + 'Model with Dropout at Inference' + '\033[0m')
print('\033[1m' + 'Absorbance Peak' + '\033[0m')
print("MAE (eV): \t", "{:.4f}".format(matrix_2[0,4]), "{:.4f}".format(matrix_2[0,20]))
print("R2 (eV):\t", "{:.4f}".format(matrix_2[0,5]), "{:.4f}".format(matrix_2[0,21]))
print("RAE (eV):\t", "{:.4f}".format(matrix_2[0,6]), "{:.4f}".format(matrix_2[0,22]))
print("RMSE (eV):\t", "{:.4f}".format(matrix_2[0,7]), "{:.4f}".format(matrix_2[0,23]))

print("MAE (nm):\t","{:.4f}".format(matrix_2[0,12]), "{:.4f}".format(matrix_2[0,28]))
print("R2 (nm):\t", "{:.4f}".format(matrix_2[0,13]), "{:.4f}".format(matrix_2[0,29]))
print("RAE (nm):\t","{:.4f}".format(matrix_2[0,14]), "{:.4f}".format(matrix_2[0,30]))
print("RMSE (nm):\t", "{:.4f}".format(matrix_2[0,15]), "{:.4f}".format(matrix_2[0,31]))

print('\033[1m' + 'Absorbance FWHM (direct)' + '\033[0m')
print("MAE (eV): \t", "{:.4f}".format(matrix_3[0,4]), "{:.4f}".format(matrix_3[0,20]))
print("R2 (eV):\t", "{:.4f}".format(matrix_3[0,5]), "{:.4f}".format(matrix_3[0,21]))
print("RAE (eV):\t", "{:.4f}".format(matrix_3[0,6]), "{:.4f}".format(matrix_3[0,22]))
print("RMSE (eV):\t", "{:.4f}".format(matrix_3[0,7]), "{:.4f}".format(matrix_3[0,23]))

print("MAE (nm):\t","{:.4f}".format(matrix_3[0,12]), "{:.4f}".format(matrix_3[0,28]))
print("R2 (nm):\t", "{:.4f}".format(matrix_3[0,13]), "{:.4f}".format(matrix_3[0,29]))
print("RAE (nm):\t","{:.4f}".format(matrix_3[0,14]), "{:.4f}".format(matrix_3[0,30]))
print("RMSE (nm):\t", "{:.4f}".format(matrix_3[0,15]), "{:.4f}".format(matrix_3[0,31]))
print('\033[1m' + 'Absorbance FWHM (cascade)' + '\033[0m')
print("MAE (eV): \t", "{:.4f}".format(matrix_4[0,4]), "{:.4f}".format(matrix_4[0,20]))
print("R2 (eV):\t", "{:.4f}".format(matrix_4[0,5]), "{:.4f}".format(matrix_4[0,21]))
print("RAE (eV):\t", "{:.4f}".format(matrix_4[0,6]), "{:.4f}".format(matrix_4[0,22]))
print("RMSE (eV):\t", "{:.4f}".format(matrix_4[0,7]), "{:.4f}".format(matrix_4[0,23]))

print("MAE (nm):\t","{:.4f}".format(matrix_4[0,12]), "{:.4f}".format(matrix_4[0,28]))
print("R2 (nm):\t", "{:.4f}".format(matrix_4[0,13]), "{:.4f}".format(matrix_4[0,29]))
print("RAE (nm):\t","{:.4f}".format(matrix_4[0,14]), "{:.4f}".format(matrix_4[0,30]))
print("RMSE (nm):\t", "{:.4f}".format(matrix_4[0,15]), "{:.4f}".format(matrix_4[0,31]))
# Out:
# Model with Dropout at Inference
# Absorbance Peak
# MAE (eV): 	 0.1890 0.0042
# R2 (eV):	 0.2547 0.0292
# RAE (eV):	 0.8578 0.0201
# RMSE (eV):	 0.2390 0.0052
# MAE (nm):	 43.8050 1.4060
# R2 (nm):	 0.2299 0.0344
# RAE (nm):	 0.8598 0.0197
# RMSE (nm):	 56.4916 2.1037
# Absorbance FWHM (direct)
# MAE (eV): 	 0.0151 0.0007
# R2 (eV):	 0.3682 0.0666
# RAE (eV):	 0.7767 0.0441
# RMSE (eV):	 0.0199 0.0010
# MAE (nm):	 6.8517 0.3300
# R2 (nm):	 0.1746 0.0417
# RAE (nm):	 0.8801 0.0281
# RMSE (nm):	 9.1834 0.4382
# Absorbance FWHM (cascade)
# MAE (eV): 	 0.0146 0.0007
# R2 (eV):	 0.4108 0.0548
# RAE (eV):	 0.7532 0.0379
# RMSE (eV):	 0.0193 0.0009
# MAE (nm):	 6.8057 0.3142
# R2 (nm):	 0.1853 0.0465
# RAE (nm):	 0.8741 0.0220
# RMSE (nm):	 9.1223 0.4390

# %%
np.savetxt("NN+MMCN_PL_Val_peak.csv", matrix, delimiter=",")
np.savetxt("NN+MMCN_PL_Val_fwhm.csv", matrix_fwhm, delimiter=",")
np.savetxt("NN+MMCN_PL_Val_cascade.csv", matrix_cascade, delimiter=",")
