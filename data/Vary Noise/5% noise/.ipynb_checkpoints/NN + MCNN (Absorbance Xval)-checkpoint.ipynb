# %%
import pandas as pd
import numpy as np
import keras
import scipy
import matplotlib.pyplot as plt
from numpy import mean
from numpy import std
from sklearn.model_selection import GroupKFold
from sklearn import linear_model
from lineartree import RandomForestRegressor
from sklearn import metrics
from scipy.signal import savgol_filter
from keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from scikeras.wrappers import KerasRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
from numpy.random import seed
seed(1)
from tensorflow.keras.utils import set_random_seed
set_random_seed(2)

# %%
def rae(actual, predicted):
    actual = np.asarray(actual).reshape(-1,1)
    predicted = np.asarray(predicted).reshape(-1,1)
    numerator = np.sum(np.abs(predicted - actual))
    denominator = np.sum(np.abs(np.mean(actual) - actual))
    return numerator / denominator

# %%
def peak_eV_nm(peak_eV):
    peak_eV = np.asarray(peak_eV).reshape(-1,1)
    return 1239.84193/peak_eV

# %%
def FWHM_eV_nm(peak_eV,fwhm_eV):
    peak_eV = np.asarray(peak_eV).reshape(-1,1)
    fwhm_eV = np.asarray(fwhm_eV).reshape(-1,1)
    return  2*(1239.84193/(peak_eV-fwhm_eV/2) - 1239.84193/(peak_eV))

# %%
def predict_dist(X, model, num_samples):
    preds = [model(X, training=True) for _ in range(num_samples)]
    return np.hstack(preds)

# %%
def predict_point(X, model, num_samples):
    pred_dist = predict_dist(X, model, num_samples)
    return pred_dist.mean(axis=1)

# %%
#Define models

initializer = keras.initializers.HeNormal(seed=1)
opt = keras.optimizers.Adam(learning_rate=0.001)

model_peak = keras.models.Sequential()
model_peak.add(Dense(5, input_shape=(5,), kernel_initializer=initializer, activation='relu'))
model_peak.add(Dense(50,  activation='relu'))
model_peak.add(keras.layers.Dropout(0.2))
model_peak.add(Dense(50,  activation='relu'))
model_peak.add(keras.layers.Dropout(0.2))
model_peak.add(Dense(1, kernel_initializer=initializer))
# Compile model
model_peak.compile(loss='mean_squared_error', optimizer= opt)

model_fwhm = keras.models.Sequential()
model_fwhm.add(Dense(5, input_shape=(5,), kernel_initializer=initializer, activation='relu'))
model_fwhm.add(Dense(50,  activation='relu'))
model_fwhm.add(keras.layers.Dropout(0.2))
model_fwhm.add(Dense(50,  activation='relu'))
model_fwhm.add(keras.layers.Dropout(0.2))
model_fwhm.add(Dense(1, kernel_initializer=initializer))
# Compile model
model_fwhm.compile(loss='mean_squared_error', optimizer= opt)

model_cascade = keras.models.Sequential()
model_cascade.add(Dense(6, input_shape=(6,), kernel_initializer=initializer, activation='relu'))
model_cascade.add(Dense(50,  activation='relu'))
model_cascade.add(keras.layers.Dropout(0.2))
model_cascade.add(Dense(50,  activation='relu'))
model_cascade.add(keras.layers.Dropout(0.2))
model_cascade.add(Dense(1, kernel_initializer=initializer))
# Compile model
model_cascade.compile(loss='mean_squared_error', optimizer= opt)

# %%
#Xval on Train/Val set, 10-fold cross validation (Group splits), UV Peak, FWHM (eV), Normalized
# load dataset into Pandas DataFrame (cleaned UV data)
df = pd.read_csv('CdSe UV Train Val.csv')

#normalize input and output data
min_params = pd.Series([0, 0, 3, 200, 0, 400, 15, 1239.84193/620, 0.05], index =['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV'])
max_params = pd.Series([50, 50, 150, 310, 600, 620, 80, 1239.84193/400, 0.4], index =['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV'])
df[['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV']] = (df[['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV']] - min_params) / (max_params- min_params)

X = df[['OA_Cd_ratio','T_reactor','Cd_mM','Se_mM','t_s']]
X2 = df[['OA_Cd_ratio','T_reactor','Cd_mM','Se_mM','t_s','Peak_eV']]
y = df['Peak_eV']
z = df['FWHM_eV']
group = df['Expt. No']

#Split groups for cross validation by Experiment number
gkf = GroupKFold(n_splits=10)
matrix = np.zeros([10,16])
matrix_fwhm = np.zeros([10,16])
matrix_cascade = np.zeros([10,16])

j = 0
#Loop through the 10 splits
for train_index, test_index in gkf.split(X, groups=group):
    #Separate out training and test sets
    X_train = X.iloc[train_index, :]
    X2_train = X2.iloc[train_index, :]
    y_train = y[train_index]
    z_train = z[train_index]
    X_test = X.iloc[test_index, :]
    X2_test = X2.iloc[test_index, :]
    y_test = y[test_index]
    z_test = z[test_index]
    
    #Load weights
    model_peak.load_weights('initialize_weights3.h5')
    model_fwhm.load_weights('initialize_weights3.h5')
    model_cascade.load_weights('initialize_weights4.h5')

    #Train models
    #prediction for Peak
    model_peak.fit(X_train, y_train, epochs=300, validation_data=(X_test, y_test),verbose = 1, use_multiprocessing=False, workers = 100)
    y_pred = model_peak.predict(X_test)
    #prediction for FWHM (direct)
    model_fwhm.fit(X_train, z_train, epochs=300, validation_data=(X_test, z_test),verbose = 1, use_multiprocessing=False, workers = 100)
    y_pred_fwhm = model_fwhm.predict(X_test)
    #prediction for FWHM (cascade)
    model_cascade.fit(X2_train, z_train, epochs=300, validation_data=(X2_test, z_test),verbose = 1, use_multiprocessing=False, workers = 100)
    X_test.insert(5, "Peak_eV", model_peak.predict(X_test), True)
    y_pred_cascade = model_cascade.predict(X_test)
    
    #prediction for Peak with dropout
    X_test = X.iloc[test_index, :]
    X_test_t = K.constant(X_test)
    y_pred_d =  predict_point(X_test_t, model_peak, 1000)
    #prediction for FWHM (direct)
    y_pred_fwhm_d = predict_point(X_test_t, model_fwhm, 1000)
    #prediction for FWHM (cascade)
    X_test.insert(5, "Peak_eV", y_pred_d, True)
    X_test_t2 = K.constant(X_test)
    y_pred_cascade_d = predict_point(X_test_t2, model_cascade, 1000)
    
    #errors in eV (normalized)
    #UN-normalize eV predictions by scaling with ratio

    ratio = (1239.84193/400 - 1239.84193/620)
    ratio2 = 0.35
    matrix[j,0] = metrics.mean_absolute_error(y_test, y_pred)*ratio
    matrix[j,1] = metrics.r2_score(y_test, y_pred)
    matrix[j,2] = rae(y_test, y_pred)
    matrix[j,3] = ratio*np.sqrt(metrics.mean_squared_error(y_test, y_pred))
    matrix[j,4] = metrics.mean_absolute_error(y_test, y_pred_d)*ratio 
    matrix[j,5] = metrics.r2_score(y_test, y_pred_d)
    matrix[j,6] = rae(y_test, y_pred_d)
    matrix[j,7] = ratio*np.sqrt(metrics.mean_squared_error(y_test, y_pred_d))

    matrix_fwhm[j,0] = metrics.mean_absolute_error(z_test, y_pred_fwhm)*ratio2
    matrix_fwhm[j,1] = metrics.r2_score(z_test, y_pred_fwhm)
    matrix_fwhm[j,2] = rae(z_test, y_pred_fwhm)
    matrix_fwhm[j,3] = ratio2*np.sqrt(metrics.mean_squared_error(z_test, y_pred_fwhm))
    matrix_fwhm[j,4] = metrics.mean_absolute_error(z_test, y_pred_fwhm_d)*ratio2
    matrix_fwhm[j,5] = metrics.r2_score(z_test, y_pred_fwhm_d)
    matrix_fwhm[j,6] = rae(z_test, y_pred_fwhm_d)
    matrix_fwhm[j,7] = ratio2*np.sqrt(metrics.mean_squared_error(z_test, y_pred_fwhm_d))
    
    matrix_cascade[j,0] = metrics.mean_absolute_error(z_test, y_pred_cascade)*ratio2
    matrix_cascade[j,1] = metrics.r2_score(z_test, y_pred_cascade)
    matrix_cascade[j,2] = rae(z_test, y_pred_cascade)
    matrix_cascade[j,3] = ratio2*np.sqrt(metrics.mean_squared_error(z_test, y_pred_cascade))
    matrix_cascade[j,4] = metrics.mean_absolute_error(z_test, y_pred_cascade_d)*ratio2
    matrix_cascade[j,5] = metrics.r2_score(z_test, y_pred_cascade_d)
    matrix_cascade[j,6] = rae(z_test, y_pred_cascade_d)
    matrix_cascade[j,7] = ratio2*np.sqrt(metrics.mean_squared_error(z_test, y_pred_cascade_d))
    
    

    #errors in nm
    #UNnormalize the data first
    y_test = y_test*(1239.84193/400 - 1239.84193/620)+1239.84193/620
    y_pred = y_pred*(1239.84193/400 - 1239.84193/620)+1239.84193/620
    y_pred_d = y_pred_d*(1239.84193/400 - 1239.84193/620)+1239.84193/620
    z_test = z_test*(0.35)+0.05
    y_pred_fwhm = y_pred_fwhm*(0.35)+0.05
    y_pred_fwhm_d = y_pred_fwhm_d*(0.35)+0.05
    y_pred_cascade = y_pred_cascade*(0.35)+0.05
    y_pred_cascade_d = y_pred_cascade_d*(0.35)+0.05
    
    #Calculate data in nm and eV
    matrix[j,8] = metrics.mean_absolute_error(peak_eV_nm(y_test), peak_eV_nm(y_pred))
    matrix[j,9] = metrics.r2_score(peak_eV_nm(y_test), peak_eV_nm(y_pred))
    matrix[j,10] = rae(peak_eV_nm(y_test), peak_eV_nm(y_pred))
    matrix[j,11] = np.sqrt(metrics.mean_squared_error(peak_eV_nm(y_test), peak_eV_nm(y_pred)))
    matrix[j,12] = metrics.mean_absolute_error(peak_eV_nm(y_test), peak_eV_nm(y_pred_d))
    matrix[j,13] = metrics.r2_score(peak_eV_nm(y_test), peak_eV_nm(y_pred_d))
    matrix[j,14] = rae(peak_eV_nm(y_test), peak_eV_nm(y_pred_d))
    matrix[j,15] = np.sqrt(metrics.mean_squared_error(peak_eV_nm(y_test), peak_eV_nm(y_pred_d)))

    matrix_fwhm[j,8] = metrics.mean_absolute_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm))
    matrix_fwhm[j,9] = metrics.r2_score(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm))
    matrix_fwhm[j,10] = rae(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm))
    matrix_fwhm[j,11] = np.sqrt(metrics.mean_squared_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm)))
    matrix_fwhm[j,12] = metrics.mean_absolute_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm_d)) 
    matrix_fwhm[j,13] = metrics.r2_score(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm_d))
    matrix_fwhm[j,14] = rae(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm_d)) 
    matrix_fwhm[j,15] = np.sqrt(metrics.mean_squared_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm_d))) 

    matrix_cascade[j,8] = metrics.mean_absolute_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade))
    matrix_cascade[j,9] = metrics.r2_score(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade))
    matrix_cascade[j,10] = rae(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade))
    matrix_cascade[j,11] = np.sqrt(metrics.mean_squared_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade)))
    matrix_cascade[j,12] = metrics.mean_absolute_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade_d))
    matrix_cascade[j,13] = metrics.r2_score(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade_d))
    matrix_cascade[j,14] = rae(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade_d))
    matrix_cascade[j,15] = np.sqrt(metrics.mean_squared_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade_d)))

    j+=1

matrix_2 = np.zeros([1,32])
matrix_2[0,:16] = matrix.mean(0)[:16]
matrix_2[0,16:32] = np.std(matrix[:,:16], axis=0)

matrix_3 = np.zeros([1,32])
matrix_3[0,:16] = matrix_fwhm.mean(0)[:16]
matrix_3[0,16:32]= np.std(matrix_fwhm[:,:16], axis=0)

matrix_4 = np.zeros([1,32])
matrix_4[0,:16] = matrix_cascade.mean(0)[:16]
matrix_4[0,16:32] = np.std(matrix_cascade[:,:16], axis=0)

np.set_printoptions(precision=5, threshold=5, edgeitems=4, suppress=True)
# Out:
# Epoch 1/300
# 140/140 [==============================] - 1s 2ms/step - loss: 0.0350 - val_loss: 0.0142
# Epoch 2/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0108 - val_loss: 0.0104
# Epoch 3/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0074 - val_loss: 0.0070
# Epoch 4/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0061 - val_loss: 0.0055
# Epoch 5/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0053 - val_loss: 0.0043
# Epoch 6/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0047 - val_loss: 0.0052
# Epoch 7/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0044 - val_loss: 0.0042
# Epoch 8/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 9/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0041 - val_loss: 0.0039
# Epoch 10/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 11/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 12/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 13/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0036 - val_loss: 0.0040
# Epoch 14/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0035 - val_loss: 0.0036
# Epoch 15/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 16/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 17/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 18/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 19/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0036
# Epoch 20/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0034
# Epoch 21/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 22/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0026
# Epoch 23/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0024
# Epoch 24/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0020
# Epoch 25/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0025 - val_loss: 0.0013
# Epoch 26/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0022 - val_loss: 0.0015
# Epoch 27/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 28/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 29/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 9.4386e-04
# Epoch 30/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 31/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 9.7207e-04
# Epoch 32/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0020 - val_loss: 9.7282e-04
# Epoch 33/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 8.7213e-04
# Epoch 34/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 8.7392e-04
# Epoch 35/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 9.1224e-04
# Epoch 36/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 8.2576e-04
# Epoch 37/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 7.0121e-04
# Epoch 38/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 7.0620e-04
# Epoch 39/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 7.7356e-04
# Epoch 40/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 7.9221e-04
# Epoch 41/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 7.2384e-04
# Epoch 42/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 8.1980e-04
# Epoch 43/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 5.7442e-04
# Epoch 44/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 7.4901e-04
# Epoch 45/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0010
# Epoch 46/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 5.5940e-04
# Epoch 47/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 7.5476e-04
# Epoch 48/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 6.4331e-04
# Epoch 49/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 8.2071e-04
# Epoch 50/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 5.5372e-04
# Epoch 51/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 4.6812e-04
# Epoch 52/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 5.8176e-04
# Epoch 53/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 6.7350e-04
# Epoch 54/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 5.1296e-04
# Epoch 55/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 4.8810e-04
# Epoch 56/300
# 140/140 [==============================] - 0s 982us/step - loss: 0.0014 - val_loss: 8.7393e-04
# Epoch 57/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 7.0910e-04
# Epoch 58/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 4.3897e-04
# Epoch 59/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 4.3040e-04
# Epoch 60/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 5.5772e-04
# Epoch 61/300
# 140/140 [==============================] - 0s 993us/step - loss: 0.0013 - val_loss: 5.5666e-04
# Epoch 62/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 63/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 7.7966e-04
# Epoch 64/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 4.3064e-04
# Epoch 65/300
# 140/140 [==============================] - 0s 961us/step - loss: 0.0012 - val_loss: 5.2104e-04
# Epoch 66/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 5.9213e-04
# Epoch 67/300
# 140/140 [==============================] - 0s 986us/step - loss: 0.0012 - val_loss: 4.0050e-04
# Epoch 68/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 4.3487e-04
# Epoch 69/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 5.9869e-04
# Epoch 70/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 5.1563e-04
# Epoch 71/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 4.3426e-04
# Epoch 72/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 5.5502e-04
# Epoch 73/300
# 140/140 [==============================] - 0s 986us/step - loss: 0.0011 - val_loss: 6.6050e-04
# Epoch 74/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 3.4785e-04
# Epoch 75/300
# 140/140 [==============================] - 0s 997us/step - loss: 0.0011 - val_loss: 4.1429e-04
# Epoch 76/300
# 140/140 [==============================] - 0s 990us/step - loss: 0.0011 - val_loss: 4.2904e-04
# Epoch 77/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 4.4878e-04
# Epoch 78/300
# 140/140 [==============================] - 0s 979us/step - loss: 0.0011 - val_loss: 5.4439e-04
# Epoch 79/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 4.6181e-04
# Epoch 80/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 3.6765e-04
# Epoch 81/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 4.5980e-04
# Epoch 82/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 4.8887e-04
# Epoch 83/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 4.1107e-04
# Epoch 84/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 6.3475e-04
# Epoch 85/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 3.6397e-04
# Epoch 86/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0010 - val_loss: 4.3664e-04
# Epoch 87/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0010 - val_loss: 5.2063e-04
# Epoch 88/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 3.3434e-04
# Epoch 89/300
# 140/140 [==============================] - 0s 987us/step - loss: 0.0010 - val_loss: 4.7692e-04
# Epoch 90/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0010 - val_loss: 5.1675e-04
# Epoch 91/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.8824e-04 - val_loss: 5.1594e-04
# Epoch 92/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0010 - val_loss: 4.8083e-04
# Epoch 93/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.6553e-04 - val_loss: 5.5488e-04
# Epoch 94/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0010 - val_loss: 6.0800e-04
# Epoch 95/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.4073e-04 - val_loss: 4.0739e-04
# Epoch 96/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 4.6928e-04
# Epoch 97/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.8780e-04 - val_loss: 6.4845e-04
# Epoch 98/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.6794e-04 - val_loss: 3.6448e-04
# Epoch 99/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.3803e-04 - val_loss: 5.0068e-04
# Epoch 100/300
# 140/140 [==============================] - 0s 989us/step - loss: 9.9145e-04 - val_loss: 4.7687e-04
# Epoch 101/300
# 140/140 [==============================] - 0s 979us/step - loss: 0.0010 - val_loss: 3.9164e-04
# Epoch 102/300
# 140/140 [==============================] - 0s 990us/step - loss: 0.0011 - val_loss: 4.7027e-04
# Epoch 103/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.8953e-04 - val_loss: 5.0781e-04
# Epoch 104/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0010 - val_loss: 4.6350e-04
# Epoch 105/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.9805e-04 - val_loss: 3.9294e-04
# Epoch 106/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.3536e-04 - val_loss: 4.8549e-04
# Epoch 107/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.2609e-04 - val_loss: 3.7185e-04
# Epoch 108/300
# 140/140 [==============================] - 0s 986us/step - loss: 9.7465e-04 - val_loss: 4.3787e-04
# Epoch 109/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0010 - val_loss: 4.2625e-04
# Epoch 110/300
# 140/140 [==============================] - 0s 982us/step - loss: 9.9517e-04 - val_loss: 4.6141e-04
# Epoch 111/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.6095e-04 - val_loss: 4.1840e-04
# Epoch 112/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.5688e-04 - val_loss: 4.8580e-04
# Epoch 113/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.2135e-04 - val_loss: 4.0417e-04
# Epoch 114/300
# 140/140 [==============================] - 0s 946us/step - loss: 9.6076e-04 - val_loss: 4.5419e-04
# Epoch 115/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0010 - val_loss: 3.9936e-04
# Epoch 116/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.1728e-04 - val_loss: 4.0031e-04
# Epoch 117/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 4.8400e-04
# Epoch 118/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.1302e-04 - val_loss: 5.8082e-04
# Epoch 119/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.6752e-04 - val_loss: 4.3782e-04
# Epoch 120/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.2672e-04 - val_loss: 3.2322e-04
# Epoch 121/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.2893e-04 - val_loss: 4.3453e-04
# Epoch 122/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.6204e-04 - val_loss: 3.9450e-04
# Epoch 123/300
# 140/140 [==============================] - 0s 1000us/step - loss: 9.5069e-04 - val_loss: 6.0166e-04
# Epoch 124/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.3683e-04 - val_loss: 3.3114e-04
# Epoch 125/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.4894e-04 - val_loss: 5.1926e-04
# Epoch 126/300
# 140/140 [==============================] - 0s 928us/step - loss: 9.3227e-04 - val_loss: 4.8584e-04
# Epoch 127/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.3337e-04 - val_loss: 3.5190e-04
# Epoch 128/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.9902e-04 - val_loss: 3.9866e-04
# Epoch 129/300
# 140/140 [==============================] - 0s 968us/step - loss: 9.4433e-04 - val_loss: 3.9568e-04
# Epoch 130/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.3343e-04 - val_loss: 4.8910e-04
# Epoch 131/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.0715e-04 - val_loss: 3.2090e-04
# Epoch 132/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.5924e-04 - val_loss: 4.0124e-04
# Epoch 133/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.3687e-04 - val_loss: 5.0992e-04
# Epoch 134/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.6564e-04 - val_loss: 6.3769e-04
# Epoch 135/300
# 140/140 [==============================] - 0s 989us/step - loss: 0.0010 - val_loss: 3.4049e-04
# Epoch 136/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.4996e-04 - val_loss: 3.4764e-04
# Epoch 137/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.3221e-04 - val_loss: 3.5981e-04
# Epoch 138/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.7944e-04 - val_loss: 3.3295e-04
# Epoch 139/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.3457e-04 - val_loss: 4.6668e-04
# Epoch 140/300
# 140/140 [==============================] - 0s 992us/step - loss: 9.3502e-04 - val_loss: 4.6676e-04
# Epoch 141/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.4117e-04 - val_loss: 4.0110e-04
# Epoch 142/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.2256e-04 - val_loss: 3.4554e-04
# Epoch 143/300
# 140/140 [==============================] - 0s 991us/step - loss: 8.6090e-04 - val_loss: 4.4977e-04
# Epoch 144/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.9213e-04 - val_loss: 3.9206e-04
# Epoch 145/300
# 140/140 [==============================] - 0s 984us/step - loss: 9.1652e-04 - val_loss: 4.4378e-04
# Epoch 146/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.7323e-04 - val_loss: 3.3962e-04
# Epoch 147/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.2553e-04 - val_loss: 3.8014e-04
# Epoch 148/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.3660e-04 - val_loss: 3.1239e-04
# Epoch 149/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.0755e-04 - val_loss: 3.7816e-04
# Epoch 150/300
# 140/140 [==============================] - 0s 979us/step - loss: 8.8664e-04 - val_loss: 5.5127e-04
# Epoch 151/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0010 - val_loss: 6.0329e-04
# Epoch 152/300
# 140/140 [==============================] - 0s 984us/step - loss: 9.8640e-04 - val_loss: 3.1771e-04
# Epoch 153/300
# 140/140 [==============================] - 0s 979us/step - loss: 9.0117e-04 - val_loss: 4.0331e-04
# Epoch 154/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.9690e-04 - val_loss: 3.4505e-04
# Epoch 155/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.8336e-04 - val_loss: 3.6251e-04
# Epoch 156/300
# 140/140 [==============================] - 0s 971us/step - loss: 8.9161e-04 - val_loss: 4.5691e-04
# Epoch 157/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.7761e-04 - val_loss: 4.1619e-04
# Epoch 158/300
# 140/140 [==============================] - 0s 972us/step - loss: 8.8654e-04 - val_loss: 3.6488e-04
# Epoch 159/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.3664e-04 - val_loss: 3.8707e-04
# Epoch 160/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.3877e-04 - val_loss: 3.7184e-04
# Epoch 161/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.8183e-04 - val_loss: 4.4192e-04
# Epoch 162/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.8439e-04 - val_loss: 3.1531e-04
# Epoch 163/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.5619e-04 - val_loss: 3.6209e-04
# Epoch 164/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.5790e-04 - val_loss: 4.2256e-04
# Epoch 165/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.2887e-04 - val_loss: 4.3269e-04
# Epoch 166/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.5116e-04 - val_loss: 3.3982e-04
# Epoch 167/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.1783e-04 - val_loss: 5.3361e-04
# Epoch 168/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.9249e-04 - val_loss: 3.3273e-04
# Epoch 169/300
# 140/140 [==============================] - 0s 986us/step - loss: 8.7858e-04 - val_loss: 5.1979e-04
# Epoch 170/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.2579e-04 - val_loss: 4.8112e-04
# Epoch 171/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.1682e-04 - val_loss: 4.0829e-04
# Epoch 172/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.8216e-04 - val_loss: 4.8401e-04
# Epoch 173/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.7506e-04 - val_loss: 3.9394e-04
# Epoch 174/300
# 140/140 [==============================] - 0s 942us/step - loss: 8.6156e-04 - val_loss: 4.3927e-04
# Epoch 175/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.8915e-04 - val_loss: 3.4604e-04
# Epoch 176/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.3225e-04 - val_loss: 4.1839e-04
# Epoch 177/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.1162e-04 - val_loss: 3.5831e-04
# Epoch 178/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.4453e-04 - val_loss: 3.9038e-04
# Epoch 179/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.8303e-04 - val_loss: 3.3101e-04
# Epoch 180/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.8125e-04 - val_loss: 5.1147e-04
# Epoch 181/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.8525e-04 - val_loss: 3.0444e-04
# Epoch 182/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.3525e-04 - val_loss: 3.0358e-04
# Epoch 183/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.2912e-04 - val_loss: 3.6812e-04
# Epoch 184/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.2634e-04 - val_loss: 3.1650e-04
# Epoch 185/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.5948e-04 - val_loss: 3.4544e-04
# Epoch 186/300
# 140/140 [==============================] - 0s 989us/step - loss: 8.4458e-04 - val_loss: 4.1235e-04
# Epoch 187/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.0023e-04 - val_loss: 3.6193e-04
# Epoch 188/300
# 140/140 [==============================] - 0s 993us/step - loss: 8.6119e-04 - val_loss: 4.5316e-04
# Epoch 189/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.0513e-04 - val_loss: 4.3912e-04
# Epoch 190/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.5632e-04 - val_loss: 4.1061e-04
# Epoch 191/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.7729e-04 - val_loss: 3.1447e-04
# Epoch 192/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.9057e-04 - val_loss: 4.5739e-04
# Epoch 193/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.5499e-04 - val_loss: 3.5246e-04
# Epoch 194/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.2589e-04 - val_loss: 3.9049e-04
# Epoch 195/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.8536e-04 - val_loss: 4.3777e-04
# Epoch 196/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.2926e-04 - val_loss: 3.7932e-04
# Epoch 197/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.6197e-04 - val_loss: 3.7913e-04
# Epoch 198/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.2695e-04 - val_loss: 4.3834e-04
# Epoch 199/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.3335e-04 - val_loss: 5.3429e-04
# Epoch 200/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.3896e-04 - val_loss: 3.6921e-04
# Epoch 201/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.8070e-04 - val_loss: 5.6591e-04
# Epoch 202/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.4996e-04 - val_loss: 3.6889e-04
# Epoch 203/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.4145e-04 - val_loss: 3.3207e-04
# Epoch 204/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.4015e-04 - val_loss: 4.1336e-04
# Epoch 205/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.2804e-04 - val_loss: 3.3264e-04
# Epoch 206/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.7397e-04 - val_loss: 5.2428e-04
# Epoch 207/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.1307e-04 - val_loss: 4.2234e-04
# Epoch 208/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.7046e-04 - val_loss: 7.1547e-04
# Epoch 209/300
# 140/140 [==============================] - 0s 986us/step - loss: 8.7189e-04 - val_loss: 4.9008e-04
# Epoch 210/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.0923e-04 - val_loss: 4.1889e-04
# Epoch 211/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.0007e-04 - val_loss: 3.8435e-04
# Epoch 212/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.7153e-04 - val_loss: 4.0558e-04
# Epoch 213/300
# 140/140 [==============================] - 0s 986us/step - loss: 8.4822e-04 - val_loss: 4.9941e-04
# Epoch 214/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.1677e-04 - val_loss: 4.2329e-04
# Epoch 215/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.5841e-04 - val_loss: 4.0065e-04
# Epoch 216/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.1129e-04 - val_loss: 3.2138e-04
# Epoch 217/300
# 140/140 [==============================] - 0s 979us/step - loss: 8.5760e-04 - val_loss: 4.1306e-04
# Epoch 218/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.4546e-04 - val_loss: 4.3288e-04
# Epoch 219/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.6077e-04 - val_loss: 3.3668e-04
# Epoch 220/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.5053e-04 - val_loss: 3.9680e-04
# Epoch 221/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.6201e-04 - val_loss: 4.0927e-04
# Epoch 222/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.7610e-04 - val_loss: 5.5551e-04
# Epoch 223/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.8104e-04 - val_loss: 3.6806e-04
# Epoch 224/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.2971e-04 - val_loss: 4.0636e-04
# Epoch 225/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.9905e-04 - val_loss: 3.4528e-04
# Epoch 226/300
# 140/140 [==============================] - 0s 981us/step - loss: 8.4926e-04 - val_loss: 4.7270e-04
# Epoch 227/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.1248e-04 - val_loss: 3.7845e-04
# Epoch 228/300
# 140/140 [==============================] - 0s 983us/step - loss: 8.4299e-04 - val_loss: 3.2038e-04
# Epoch 229/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.7407e-04 - val_loss: 4.5752e-04
# Epoch 230/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.0715e-04 - val_loss: 4.7235e-04
# Epoch 231/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.1662e-04 - val_loss: 4.2252e-04
# Epoch 232/300
# 140/140 [==============================] - 0s 979us/step - loss: 8.0648e-04 - val_loss: 3.4553e-04
# Epoch 233/300
# 140/140 [==============================] - 0s 991us/step - loss: 8.9869e-04 - val_loss: 3.4278e-04
# Epoch 234/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.8127e-04 - val_loss: 3.7887e-04
# Epoch 235/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.1386e-04 - val_loss: 3.1368e-04
# Epoch 236/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.9856e-04 - val_loss: 5.6136e-04
# Epoch 237/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.9061e-04 - val_loss: 3.1194e-04
# Epoch 238/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.1287e-04 - val_loss: 4.3872e-04
# Epoch 239/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.1399e-04 - val_loss: 4.6139e-04
# Epoch 240/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.2786e-04 - val_loss: 3.4546e-04
# Epoch 241/300
# 140/140 [==============================] - 0s 986us/step - loss: 7.7088e-04 - val_loss: 4.5380e-04
# Epoch 242/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.3611e-04 - val_loss: 4.0363e-04
# Epoch 243/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.9845e-04 - val_loss: 4.2392e-04
# Epoch 244/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.0608e-04 - val_loss: 4.1281e-04
# Epoch 245/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.4739e-04 - val_loss: 4.8726e-04
# Epoch 246/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.1939e-04 - val_loss: 4.2369e-04
# Epoch 247/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.5238e-04 - val_loss: 4.3331e-04
# Epoch 248/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.7893e-04 - val_loss: 2.8789e-04
# Epoch 249/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.8472e-04 - val_loss: 5.4711e-04
# Epoch 250/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.1741e-04 - val_loss: 4.0603e-04
# Epoch 251/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.5383e-04 - val_loss: 4.0179e-04
# Epoch 252/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.9924e-04 - val_loss: 4.6737e-04
# Epoch 253/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.0387e-04 - val_loss: 4.7743e-04
# Epoch 254/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.9341e-04 - val_loss: 4.2188e-04
# Epoch 255/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.6103e-04 - val_loss: 3.2011e-04
# Epoch 256/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.7626e-04 - val_loss: 3.9914e-04
# Epoch 257/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.2463e-04 - val_loss: 3.5237e-04
# Epoch 258/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.9939e-04 - val_loss: 4.1672e-04
# Epoch 259/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.8760e-04 - val_loss: 5.9176e-04
# Epoch 260/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.3105e-04 - val_loss: 3.7616e-04
# Epoch 261/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.9489e-04 - val_loss: 5.5395e-04
# Epoch 262/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.6936e-04 - val_loss: 4.2477e-04
# Epoch 263/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.8670e-04 - val_loss: 3.4012e-04
# Epoch 264/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.0690e-04 - val_loss: 3.9067e-04
# Epoch 265/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.2713e-04 - val_loss: 4.3290e-04
# Epoch 266/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.8361e-04 - val_loss: 3.7624e-04
# Epoch 267/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.0981e-04 - val_loss: 3.8295e-04
# Epoch 268/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.2162e-04 - val_loss: 4.2209e-04
# Epoch 269/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.2695e-04 - val_loss: 6.4698e-04
# Epoch 270/300
# 140/140 [==============================] - 0s 986us/step - loss: 7.7566e-04 - val_loss: 3.6715e-04
# Epoch 271/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.0196e-04 - val_loss: 3.6038e-04
# Epoch 272/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.4771e-04 - val_loss: 4.2804e-04
# Epoch 273/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.2297e-04 - val_loss: 3.7381e-04
# Epoch 274/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.7066e-04 - val_loss: 5.1894e-04
# Epoch 275/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.9278e-04 - val_loss: 4.4672e-04
# Epoch 276/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.0447e-04 - val_loss: 4.4194e-04
# Epoch 277/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.8875e-04 - val_loss: 4.1650e-04
# Epoch 278/300
# 140/140 [==============================] - 0s 953us/step - loss: 8.6270e-04 - val_loss: 5.2681e-04
# Epoch 279/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.8144e-04 - val_loss: 3.9241e-04
# Epoch 280/300
# 140/140 [==============================] - 0s 964us/step - loss: 7.8987e-04 - val_loss: 4.1711e-04
# Epoch 281/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.1409e-04 - val_loss: 3.4972e-04
# Epoch 282/300
# 140/140 [==============================] - 0s 966us/step - loss: 8.4406e-04 - val_loss: 3.9746e-04
# Epoch 283/300
# 140/140 [==============================] - 0s 965us/step - loss: 8.0907e-04 - val_loss: 4.5913e-04
# Epoch 284/300
# 140/140 [==============================] - 0s 970us/step - loss: 7.6725e-04 - val_loss: 3.5008e-04
# Epoch 285/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.2058e-04 - val_loss: 3.7971e-04
# Epoch 286/300
# 140/140 [==============================] - 0s 964us/step - loss: 8.0056e-04 - val_loss: 4.5575e-04
# Epoch 287/300
# 140/140 [==============================] - 0s 982us/step - loss: 8.1383e-04 - val_loss: 4.7894e-04
# Epoch 288/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.4618e-04 - val_loss: 3.5296e-04
# Epoch 289/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.7005e-04 - val_loss: 3.4072e-04
# Epoch 290/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.8867e-04 - val_loss: 3.3268e-04
# Epoch 291/300
# 140/140 [==============================] - 0s 995us/step - loss: 7.1955e-04 - val_loss: 3.7970e-04
# Epoch 292/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.8313e-04 - val_loss: 4.8834e-04
# Epoch 293/300
# 140/140 [==============================] - 0s 979us/step - loss: 8.2003e-04 - val_loss: 3.8756e-04
# Epoch 294/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.9235e-04 - val_loss: 3.8054e-04
# Epoch 295/300
# 140/140 [==============================] - 0s 986us/step - loss: 8.0716e-04 - val_loss: 3.7548e-04
# Epoch 296/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.0483e-04 - val_loss: 4.2069e-04
# Epoch 297/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.4166e-04 - val_loss: 3.5335e-04
# Epoch 298/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.8701e-04 - val_loss: 3.6423e-04
# Epoch 299/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.1372e-04 - val_loss: 3.4193e-04
# Epoch 300/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.9345e-04 - val_loss: 5.0487e-04
# 16/16 [==============================] - 0s 667us/step
# Epoch 1/300
# 140/140 [==============================] - 1s 2ms/step - loss: 0.0073 - val_loss: 0.0024
# Epoch 2/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0036 - val_loss: 0.0022
# Epoch 3/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0017
# Epoch 4/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0015
# Epoch 5/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0014
# Epoch 6/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0026 - val_loss: 0.0014
# Epoch 7/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0025 - val_loss: 0.0013
# Epoch 8/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0026 - val_loss: 0.0013
# Epoch 9/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 10/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 11/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 12/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0023 - val_loss: 0.0014
# Epoch 13/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 14/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0023 - val_loss: 0.0013
# Epoch 15/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0022 - val_loss: 0.0014
# Epoch 16/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0023 - val_loss: 0.0013
# Epoch 17/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0023 - val_loss: 0.0014
# Epoch 18/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0023 - val_loss: 0.0014
# Epoch 19/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0023 - val_loss: 0.0014
# Epoch 20/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0023 - val_loss: 0.0014
# Epoch 21/300
# 140/140 [==============================] - 0s 982us/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 22/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 23/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 24/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0022 - val_loss: 0.0014
# Epoch 25/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0022 - val_loss: 0.0014
# Epoch 26/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0022 - val_loss: 0.0014
# Epoch 27/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0022 - val_loss: 0.0015
# Epoch 28/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0022 - val_loss: 0.0014
# Epoch 29/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 30/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 31/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 32/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 33/300
# 140/140 [==============================] - 0s 999us/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 34/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 35/300
# 140/140 [==============================] - 0s 982us/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 36/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 37/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 38/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 39/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 40/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 41/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 42/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 43/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 44/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 45/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 46/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 47/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 48/300
# 140/140 [==============================] - 0s 991us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 49/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 50/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 51/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 52/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 53/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 54/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 55/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 56/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 57/300
# 140/140 [==============================] - 0s 982us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 58/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 59/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 60/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 61/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 62/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 63/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 64/300
# 140/140 [==============================] - 0s 978us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 65/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 66/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 67/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 68/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 69/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 70/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 71/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 72/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 73/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 74/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 75/300
# 140/140 [==============================] - 0s 978us/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 76/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 77/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 78/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 79/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 80/300
# 140/140 [==============================] - 0s 989us/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 81/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 82/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 83/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 84/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 85/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 86/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 87/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 88/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 89/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 90/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 91/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 92/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 93/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 94/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 95/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 96/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 97/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 98/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 99/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 100/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 101/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 102/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 103/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 104/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 105/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 106/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 107/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 108/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 109/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 110/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 111/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 112/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 113/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 114/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 115/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 116/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 117/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 118/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 119/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 120/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 121/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 122/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 123/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 124/300
# 140/140 [==============================] - 0s 991us/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 125/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 126/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 127/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 128/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 129/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 130/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 131/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 132/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 133/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 134/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 135/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 136/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 137/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 138/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 139/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 140/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 141/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 142/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 143/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 144/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 145/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 146/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 147/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 148/300
# 140/140 [==============================] - 0s 982us/step - loss: 0.0016 - val_loss: 0.0010
# Epoch 149/300
# ...
# Epoch 158/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.5342e-04 - val_loss: 7.0056e-04
# Epoch 159/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.6273e-04 - val_loss: 8.1931e-04
# Epoch 160/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.5960e-04 - val_loss: 8.0910e-04
# Epoch 161/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.7633e-04 - val_loss: 7.1571e-04
# Epoch 162/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.2334e-04 - val_loss: 6.9009e-04
# Epoch 163/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.2082e-04 - val_loss: 7.4247e-04
# Epoch 164/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.0287e-04 - val_loss: 7.4511e-04
# Epoch 165/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.2404e-04 - val_loss: 7.3291e-04
# Epoch 166/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.8473e-04 - val_loss: 6.8614e-04
# Epoch 167/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.1721e-04 - val_loss: 7.4789e-04
# Epoch 168/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.9727e-04 - val_loss: 7.0820e-04
# Epoch 169/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.0356e-04 - val_loss: 6.8581e-04
# Epoch 170/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.8006e-04 - val_loss: 7.2202e-04
# Epoch 171/300
# 140/140 [==============================] - 0s 987us/step - loss: 7.1487e-04 - val_loss: 6.8506e-04
# Epoch 172/300
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 7.3532e-04
# Epoch 173/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.7039e-04 - val_loss: 7.1616e-04
# Epoch 174/300
# 140/140 [==============================] - 0s 982us/step - loss: 7.9847e-04 - val_loss: 6.6873e-04
# Epoch 175/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.7973e-04 - val_loss: 6.8147e-04
# Epoch 176/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.6015e-04 - val_loss: 6.9551e-04
# Epoch 177/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.7925e-04 - val_loss: 7.7626e-04
# Epoch 178/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.0767e-04 - val_loss: 8.3021e-04
# Epoch 179/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.7342e-04 - val_loss: 7.0143e-04
# Epoch 180/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.0106e-04 - val_loss: 6.5129e-04
# Epoch 181/300
# 140/140 [==============================] - 0s 993us/step - loss: 8.3428e-04 - val_loss: 6.8258e-04
# Epoch 182/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.7266e-04 - val_loss: 6.4269e-04
# Epoch 183/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.9844e-04 - val_loss: 7.3673e-04
# Epoch 184/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.9208e-04 - val_loss: 7.1495e-04
# Epoch 185/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.6898e-04 - val_loss: 6.7249e-04
# Epoch 186/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.1958e-04 - val_loss: 6.9010e-04
# Epoch 187/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.9942e-04 - val_loss: 7.0134e-04
# Epoch 188/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.6608e-04 - val_loss: 7.0465e-04
# Epoch 189/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.4594e-04 - val_loss: 7.1927e-04
# Epoch 190/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.9268e-04 - val_loss: 6.1396e-04
# Epoch 191/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.2700e-04 - val_loss: 6.5997e-04
# Epoch 192/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.6609e-04 - val_loss: 6.8391e-04
# Epoch 193/300
# 140/140 [==============================] - 0s 981us/step - loss: 7.2517e-04 - val_loss: 6.3844e-04
# Epoch 194/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.2087e-04 - val_loss: 7.0791e-04
# Epoch 195/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.1139e-04 - val_loss: 6.8176e-04
# Epoch 196/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.7816e-04 - val_loss: 7.1591e-04
# Epoch 197/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.0638e-04 - val_loss: 7.8488e-04
# Epoch 198/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.1449e-04 - val_loss: 7.2330e-04
# Epoch 199/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.2171e-04 - val_loss: 7.0521e-04
# Epoch 200/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.2583e-04 - val_loss: 7.1551e-04
# Epoch 201/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.3703e-04 - val_loss: 6.9703e-04
# Epoch 202/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.4308e-04 - val_loss: 6.7568e-04
# Epoch 203/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.7048e-04 - val_loss: 6.5256e-04
# Epoch 204/300
# 140/140 [==============================] - 0s 979us/step - loss: 7.6735e-04 - val_loss: 6.7459e-04
# Epoch 205/300
# 140/140 [==============================] - 0s 982us/step - loss: 7.5614e-04 - val_loss: 7.2239e-04
# Epoch 206/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.6405e-04 - val_loss: 7.2590e-04
# Epoch 207/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.8954e-04 - val_loss: 7.6860e-04
# Epoch 208/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.9606e-04 - val_loss: 6.8211e-04
# Epoch 209/300
# 140/140 [==============================] - 0s 1ms/step - loss: 9.0911e-04 - val_loss: 7.6648e-04
# Epoch 210/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.4827e-04 - val_loss: 7.8864e-04
# Epoch 211/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.4328e-04 - val_loss: 6.6844e-04
# Epoch 212/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.5434e-04 - val_loss: 7.0890e-04
# Epoch 213/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.8938e-04 - val_loss: 7.3276e-04
# Epoch 214/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.1956e-04 - val_loss: 6.7082e-04
# Epoch 215/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.2443e-04 - val_loss: 7.1643e-04
# Epoch 216/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.5478e-04 - val_loss: 6.9915e-04
# Epoch 217/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.9776e-04 - val_loss: 6.4973e-04
# Epoch 218/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.9171e-04 - val_loss: 7.6763e-04
# Epoch 219/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.9670e-04 - val_loss: 6.3106e-04
# Epoch 220/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.1312e-04 - val_loss: 7.4790e-04
# Epoch 221/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.5709e-04 - val_loss: 7.1693e-04
# Epoch 222/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.4261e-04 - val_loss: 6.4388e-04
# Epoch 223/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.2389e-04 - val_loss: 7.2688e-04
# Epoch 224/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.3591e-04 - val_loss: 6.6582e-04
# Epoch 225/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.3912e-04 - val_loss: 7.2474e-04
# Epoch 226/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.8704e-04 - val_loss: 6.4977e-04
# Epoch 227/300
# 140/140 [==============================] - 0s 973us/step - loss: 6.8632e-04 - val_loss: 7.3331e-04
# Epoch 228/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.0497e-04 - val_loss: 7.5845e-04
# Epoch 229/300
# 140/140 [==============================] - 0s 983us/step - loss: 6.6739e-04 - val_loss: 6.6874e-04
# Epoch 230/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.9474e-04 - val_loss: 6.6502e-04
# Epoch 231/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.8988e-04 - val_loss: 6.3257e-04
# Epoch 232/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.0302e-04 - val_loss: 7.7777e-04
# Epoch 233/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.6127e-04 - val_loss: 6.5619e-04
# Epoch 234/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.7767e-04 - val_loss: 7.2821e-04
# Epoch 235/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.7242e-04 - val_loss: 6.9890e-04
# Epoch 236/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.2520e-04 - val_loss: 8.1699e-04
# Epoch 237/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.3666e-04 - val_loss: 6.7655e-04
# Epoch 238/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.0248e-04 - val_loss: 6.7032e-04
# Epoch 239/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.3796e-04 - val_loss: 6.7372e-04
# Epoch 240/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.6146e-04 - val_loss: 6.8680e-04
# Epoch 241/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.3130e-04 - val_loss: 7.9664e-04
# Epoch 242/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.0331e-04 - val_loss: 7.1271e-04
# Epoch 243/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.9954e-04 - val_loss: 6.5478e-04
# Epoch 244/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.1298e-04 - val_loss: 6.9497e-04
# Epoch 245/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.8242e-04 - val_loss: 6.5764e-04
# Epoch 246/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.5835e-04 - val_loss: 6.5818e-04
# Epoch 247/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.7359e-04 - val_loss: 5.9317e-04
# Epoch 248/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.7026e-04 - val_loss: 6.9183e-04
# Epoch 249/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.7551e-04 - val_loss: 6.6890e-04
# Epoch 250/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.4676e-04 - val_loss: 7.0225e-04
# Epoch 251/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.5154e-04 - val_loss: 6.6506e-04
# Epoch 252/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.1143e-04 - val_loss: 6.2739e-04
# Epoch 253/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.1510e-04 - val_loss: 6.7628e-04
# Epoch 254/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.0817e-04 - val_loss: 7.3482e-04
# Epoch 255/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.2043e-04 - val_loss: 8.1147e-04
# Epoch 256/300
# 140/140 [==============================] - 0s 1ms/step - loss: 5.8448e-04 - val_loss: 6.8301e-04
# Epoch 257/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.2130e-04 - val_loss: 7.0175e-04
# Epoch 258/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.3740e-04 - val_loss: 7.6843e-04
# Epoch 259/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.6528e-04 - val_loss: 6.8251e-04
# Epoch 260/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.1070e-04 - val_loss: 7.2723e-04
# Epoch 261/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.8995e-04 - val_loss: 6.2528e-04
# Epoch 262/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.6450e-04 - val_loss: 7.3441e-04
# Epoch 263/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.7492e-04 - val_loss: 7.2946e-04
# Epoch 264/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.6410e-04 - val_loss: 7.2280e-04
# Epoch 265/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.1115e-04 - val_loss: 7.3034e-04
# Epoch 266/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.7989e-04 - val_loss: 7.4069e-04
# Epoch 267/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.9416e-04 - val_loss: 7.7484e-04
# Epoch 268/300
# 140/140 [==============================] - 0s 1ms/step - loss: 8.1193e-04 - val_loss: 7.5923e-04
# Epoch 269/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.6434e-04 - val_loss: 6.3382e-04
# Epoch 270/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.6894e-04 - val_loss: 6.6125e-04
# Epoch 271/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.4290e-04 - val_loss: 6.3237e-04
# Epoch 272/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.5662e-04 - val_loss: 6.8457e-04
# Epoch 273/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.9535e-04 - val_loss: 6.7133e-04
# Epoch 274/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.0978e-04 - val_loss: 7.3059e-04
# Epoch 275/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.0249e-04 - val_loss: 6.7133e-04
# Epoch 276/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.6495e-04 - val_loss: 7.2714e-04
# Epoch 277/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.7207e-04 - val_loss: 7.3471e-04
# Epoch 278/300
# 140/140 [==============================] - 0s 1ms/step - loss: 5.9116e-04 - val_loss: 7.1720e-04
# Epoch 279/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.2067e-04 - val_loss: 8.1354e-04
# Epoch 280/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.2457e-04 - val_loss: 7.0573e-04
# Epoch 281/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.9459e-04 - val_loss: 6.8772e-04
# Epoch 282/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.8832e-04 - val_loss: 6.8277e-04
# Epoch 283/300
# 140/140 [==============================] - 0s 979us/step - loss: 6.6181e-04 - val_loss: 7.0504e-04
# Epoch 284/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.4308e-04 - val_loss: 7.5775e-04
# Epoch 285/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.2313e-04 - val_loss: 6.7331e-04
# Epoch 286/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.8941e-04 - val_loss: 7.2611e-04
# Epoch 287/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.2682e-04 - val_loss: 7.0842e-04
# Epoch 288/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.7637e-04 - val_loss: 7.9744e-04
# Epoch 289/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.4623e-04 - val_loss: 6.7442e-04
# Epoch 290/300
# 140/140 [==============================] - 0s 1ms/step - loss: 7.2716e-04 - val_loss: 7.3001e-04
# Epoch 291/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.3460e-04 - val_loss: 7.1174e-04
# Epoch 292/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.9894e-04 - val_loss: 6.9494e-04
# Epoch 293/300
# 140/140 [==============================] - 0s 997us/step - loss: 6.5912e-04 - val_loss: 6.9346e-04
# Epoch 294/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.5627e-04 - val_loss: 7.0714e-04
# Epoch 295/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.5530e-04 - val_loss: 6.6385e-04
# Epoch 296/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.6646e-04 - val_loss: 7.2481e-04
# Epoch 297/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.5952e-04 - val_loss: 7.3514e-04
# Epoch 298/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.0318e-04 - val_loss: 6.4199e-04
# Epoch 299/300
# 140/140 [==============================] - 0s 1ms/step - loss: 5.8602e-04 - val_loss: 6.4332e-04
# Epoch 300/300
# 140/140 [==============================] - 0s 1ms/step - loss: 6.4008e-04 - val_loss: 6.5006e-04
# 16/16 [==============================] - 0s 598us/step
# 16/16 [==============================] - 0s 601us/step

# %%
print('\033[1m' + 'Model without Dropout at Inference' + '\033[0m')
print('\033[1m' + 'Absorbance Peak' + '\033[0m')
print("MAE (eV): \t", "{:.4f}".format(matrix_2[0,0]), "{:.4f}".format(matrix_2[0,16]))
print("R2 (eV):\t", "{:.4f}".format(matrix_2[0,1]), "{:.4f}".format(matrix_2[0,17]))
print("RAE (eV):\t", "{:.4f}".format(matrix_2[0,2]), "{:.4f}".format(matrix_2[0,18]))
print("RMSE (eV):\t", "{:.4f}".format(matrix_2[0,3]), "{:.4f}".format(matrix_2[0,19]))

print("MAE (nm):\t","{:.4f}".format(matrix_2[0,8]), "{:.4f}".format(matrix_2[0,24]))
print("R2 (nm):\t", "{:.4f}".format(matrix_2[0,9]), "{:.4f}".format(matrix_2[0,25]))
print("RAE (nm):\t","{:.4f}".format(matrix_2[0,10]), "{:.4f}".format(matrix_2[0,26]))
print("RMSE (nm):\t", "{:.4f}".format(matrix_2[0,11]), "{:.4f}".format(matrix_2[0,27]))

print('\033[1m' + 'Absorbance FWHM (direct)' + '\033[0m')
print("MAE (eV): \t", "{:.4f}".format(matrix_3[0,0]), "{:.4f}".format(matrix_3[0,16]))
print("R2 (eV):\t", "{:.4f}".format(matrix_3[0,1]), "{:.4f}".format(matrix_3[0,17]))
print("RAE (eV):\t", "{:.4f}".format(matrix_3[0,2]), "{:.4f}".format(matrix_3[0,18]))
print("RMSE (eV):\t", "{:.4f}".format(matrix_3[0,3]), "{:.4f}".format(matrix_3[0,19]))

print("MAE (nm):\t","{:.4f}".format(matrix_3[0,8]), "{:.4f}".format(matrix_3[0,24]))
print("R2 (nm):\t", "{:.4f}".format(matrix_3[0,9]), "{:.4f}".format(matrix_3[0,25]))
print("RAE (nm):\t","{:.4f}".format(matrix_3[0,10]), "{:.4f}".format(matrix_3[0,26]))
print("RMSE (nm):\t", "{:.4f}".format(matrix_3[0,11]), "{:.4f}".format(matrix_3[0,27]))

print('\033[1m' + 'Absorbance FWHM (cascade)' + '\033[0m')
print("MAE (eV): \t", "{:.4f}".format(matrix_4[0,0]), "{:.4f}".format(matrix_4[0,16]))
print("R2 (eV):\t", "{:.4f}".format(matrix_4[0,1]), "{:.4f}".format(matrix_4[0,17]))
print("RAE (eV):\t", "{:.4f}".format(matrix_4[0,2]), "{:.4f}".format(matrix_4[0,18]))
print("RMSE (eV):\t", "{:.4f}".format(matrix_4[0,3]), "{:.4f}".format(matrix_4[0,19]))

print("MAE (nm):\t","{:.4f}".format(matrix_4[0,8]), "{:.4f}".format(matrix_4[0,24]))
print("R2 (nm):\t", "{:.4f}".format(matrix_4[0,9]), "{:.4f}".format(matrix_4[0,25]))
print("RAE (nm):\t","{:.4f}".format(matrix_4[0,10]), "{:.4f}".format(matrix_4[0,26]))
print("RMSE (nm):\t", "{:.4f}".format(matrix_4[0,11]), "{:.4f}".format(matrix_4[0,27]))
# Out:
# Model without Dropout at Inference
# Absorbance Peak
# MAE (eV): 	 0.0213 0.0034
# R2 (eV):	 0.9724 0.0123
# RAE (eV):	 0.1410 0.0229
# RMSE (eV):	 0.0292 0.0062
# MAE (nm):	 4.5436 0.7277
# R2 (nm):	 0.9692 0.0164
# RAE (nm):	 0.1441 0.0236
# RMSE (nm):	 6.3400 1.5806
# Absorbance FWHM (direct)
# MAE (eV): 	 0.0091 0.0008
# R2 (eV):	 0.6772 0.0768
# RAE (eV):	 0.4639 0.0527
# RMSE (eV):	 0.0140 0.0019
# MAE (nm):	 2.1507 0.2664
# R2 (nm):	 0.7095 0.0901
# RAE (nm):	 0.4204 0.0525
# RMSE (nm):	 3.2899 0.5334
# Absorbance FWHM (cascade)
# MAE (eV): 	 0.0072 0.0007
# R2 (eV):	 0.7751 0.0829
# RAE (eV):	 0.3650 0.0422
# RMSE (eV):	 0.0117 0.0027
# MAE (nm):	 1.7217 0.1679
# R2 (nm):	 0.7957 0.0786
# RAE (nm):	 0.3385 0.0504
# RMSE (nm):	 2.7537 0.6346

# %%
print('\033[1m' + 'Model with Dropout at Inference' + '\033[0m')
print('\033[1m' + 'Absorbance Peak' + '\033[0m')
print("MAE (eV): \t", "{:.4f}".format(matrix_2[0,4]), "{:.4f}".format(matrix_2[0,20]))
print("R2 (eV):\t", "{:.4f}".format(matrix_2[0,5]), "{:.4f}".format(matrix_2[0,21]))
print("RAE (eV):\t", "{:.4f}".format(matrix_2[0,6]), "{:.4f}".format(matrix_2[0,22]))
print("RMSE (eV):\t", "{:.4f}".format(matrix_2[0,7]), "{:.4f}".format(matrix_2[0,23]))

print("MAE (nm):\t","{:.4f}".format(matrix_2[0,12]), "{:.4f}".format(matrix_2[0,28]))
print("R2 (nm):\t", "{:.4f}".format(matrix_2[0,13]), "{:.4f}".format(matrix_2[0,29]))
print("RAE (nm):\t","{:.4f}".format(matrix_2[0,14]), "{:.4f}".format(matrix_2[0,30]))
print("RMSE (nm):\t", "{:.4f}".format(matrix_2[0,15]), "{:.4f}".format(matrix_2[0,31]))

print('\033[1m' + 'Absorbance FWHM (direct)' + '\033[0m')
print("MAE (eV): \t", "{:.4f}".format(matrix_3[0,4]), "{:.4f}".format(matrix_3[0,20]))
print("R2 (eV):\t", "{:.4f}".format(matrix_3[0,5]), "{:.4f}".format(matrix_3[0,21]))
print("RAE (eV):\t", "{:.4f}".format(matrix_3[0,6]), "{:.4f}".format(matrix_3[0,22]))
print("RMSE (eV):\t", "{:.4f}".format(matrix_3[0,7]), "{:.4f}".format(matrix_3[0,23]))

print("MAE (nm):\t","{:.4f}".format(matrix_3[0,12]), "{:.4f}".format(matrix_3[0,28]))
print("R2 (nm):\t", "{:.4f}".format(matrix_3[0,13]), "{:.4f}".format(matrix_3[0,29]))
print("RAE (nm):\t","{:.4f}".format(matrix_3[0,14]), "{:.4f}".format(matrix_3[0,30]))
print("RMSE (nm):\t", "{:.4f}".format(matrix_3[0,15]), "{:.4f}".format(matrix_3[0,31]))
print('\033[1m' + 'Absorbance FWHM (cascade)' + '\033[0m')
print("MAE (eV): \t", "{:.4f}".format(matrix_4[0,4]), "{:.4f}".format(matrix_4[0,20]))
print("R2 (eV):\t", "{:.4f}".format(matrix_4[0,5]), "{:.4f}".format(matrix_4[0,21]))
print("RAE (eV):\t", "{:.4f}".format(matrix_4[0,6]), "{:.4f}".format(matrix_4[0,22]))
print("RMSE (eV):\t", "{:.4f}".format(matrix_4[0,7]), "{:.4f}".format(matrix_4[0,23]))

print("MAE (nm):\t","{:.4f}".format(matrix_4[0,12]), "{:.4f}".format(matrix_4[0,28]))
print("R2 (nm):\t", "{:.4f}".format(matrix_4[0,13]), "{:.4f}".format(matrix_4[0,29]))
print("RAE (nm):\t","{:.4f}".format(matrix_4[0,14]), "{:.4f}".format(matrix_4[0,30]))
print("RMSE (nm):\t", "{:.4f}".format(matrix_4[0,15]), "{:.4f}".format(matrix_4[0,31]))
# Out:
# Model with Dropout at Inference
# Absorbance Peak
# MAE (eV): 	 0.0211 0.0035
# R2 (eV):	 0.9729 0.0125
# RAE (eV):	 0.1397 0.0234
# RMSE (eV):	 0.0289 0.0062
# MAE (nm):	 4.4986 0.7388
# R2 (nm):	 0.9698 0.0165
# RAE (nm):	 0.1427 0.0241
# RMSE (nm):	 6.2738 1.5711
# Absorbance FWHM (direct)
# MAE (eV): 	 0.0091 0.0008
# R2 (eV):	 0.6794 0.0740
# RAE (eV):	 0.4629 0.0525
# RMSE (eV):	 0.0140 0.0018
# MAE (nm):	 2.1467 0.2620
# R2 (nm):	 0.7108 0.0884
# RAE (nm):	 0.4197 0.0525
# RMSE (nm):	 3.2823 0.5211
# Absorbance FWHM (cascade)
# MAE (eV): 	 0.0071 0.0007
# R2 (eV):	 0.7800 0.0828
# RAE (eV):	 0.3598 0.0426
# RMSE (eV):	 0.0115 0.0027
# MAE (nm):	 1.7025 0.1703
# R2 (nm):	 0.7993 0.0746
# RAE (nm):	 0.3346 0.0497
# RMSE (nm):	 2.7316 0.6233

# %%
np.savetxt("NN+MMCN_UV_Val_peak.csv", matrix, delimiter=",")
np.savetxt("NN+MMCN_UV_Val_fwhm.csv", matrix_fwhm, delimiter=",")
np.savetxt("NN+MMCN_UV_Val_cascade.csv", matrix_cascade, delimiter=",")
