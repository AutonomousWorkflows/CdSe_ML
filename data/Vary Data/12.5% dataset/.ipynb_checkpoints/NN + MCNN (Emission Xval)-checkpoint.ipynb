# %%
import pandas as pd
import numpy as np
import keras
import scipy
import matplotlib.pyplot as plt
from numpy import mean
from numpy import std
from sklearn.model_selection import GroupKFold
from sklearn import linear_model
from lineartree import RandomForestRegressor
from sklearn import metrics
from scipy.signal import savgol_filter
from keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from scikeras.wrappers import KerasRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
from numpy.random import seed
seed(1)
from tensorflow.keras.utils import set_random_seed
set_random_seed(2)

# %%
def rae(actual, predicted):
    actual = np.asarray(actual).reshape(-1,1)
    predicted = np.asarray(predicted).reshape(-1,1)
    numerator = np.sum(np.abs(predicted - actual))
    denominator = np.sum(np.abs(np.mean(actual) - actual))
    return numerator / denominator

# %%
def peak_eV_nm(peak_eV):
    peak_eV = np.asarray(peak_eV).reshape(-1,1)
    return 1239.84193/peak_eV

# %%
def FWHM_eV_nm(peak_eV,fwhm_eV):
    peak_eV = np.asarray(peak_eV).reshape(-1,1)
    fwhm_eV = np.asarray(fwhm_eV).reshape(-1,1)
    return  2*(1239.84193/(peak_eV-fwhm_eV/2) - 1239.84193/(peak_eV))

# %%
def predict_dist(X, model, num_samples):
    preds = [model(X, training=True) for _ in range(num_samples)]
    return np.hstack(preds)

# %%
def predict_point(X, model, num_samples):
    pred_dist = predict_dist(X, model, num_samples)
    return pred_dist.mean(axis=1)

# %%
#Define models

initializer = keras.initializers.HeNormal(seed=1)
opt = keras.optimizers.Adam(learning_rate=0.001)

model_peak = keras.models.Sequential()
model_peak.add(Dense(5, input_shape=(5,), kernel_initializer=initializer, activation='relu'))
model_peak.add(Dense(50,  activation='relu'))
model_peak.add(keras.layers.Dropout(0.2))
model_peak.add(Dense(50,  activation='relu'))
model_peak.add(keras.layers.Dropout(0.2))
model_peak.add(Dense(1, kernel_initializer=initializer))
# Compile model
model_peak.compile(loss='mean_squared_error', optimizer= opt)

model_fwhm = keras.models.Sequential()
model_fwhm.add(Dense(5, input_shape=(5,), kernel_initializer=initializer, activation='relu'))
model_fwhm.add(Dense(50,  activation='relu'))
model_fwhm.add(keras.layers.Dropout(0.2))
model_fwhm.add(Dense(50,  activation='relu'))
model_fwhm.add(keras.layers.Dropout(0.2))
model_fwhm.add(Dense(1, kernel_initializer=initializer))
# Compile model
model_fwhm.compile(loss='mean_squared_error', optimizer= opt)

model_cascade = keras.models.Sequential()
model_cascade.add(Dense(6, input_shape=(6,), kernel_initializer=initializer, activation='relu'))
model_cascade.add(Dense(50,  activation='relu'))
model_cascade.add(keras.layers.Dropout(0.2))
model_cascade.add(Dense(50,  activation='relu'))
model_cascade.add(keras.layers.Dropout(0.2))
model_cascade.add(Dense(1, kernel_initializer=initializer))
# Compile model
model_cascade.compile(loss='mean_squared_error', optimizer= opt)

# %%
#Xval on Train/Val set, 10-fold cross validation (Group splits), PL Peak, FWHM (eV), Normalized
# load dataset into Pandas DataFrame (cleaned PL data)
df = pd.read_csv('CdSe PL Train Val.csv')

#normalize input and output data
min_params = pd.Series([0, 0, 3, 200, 0, 400, 15, 1239.84193/620, 0.05], index =['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV'])
max_params = pd.Series([50, 50, 150, 310, 600, 620, 80, 1239.84193/400, 0.4], index =['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV'])
df[['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV']] = (df[['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV']] - min_params) / (max_params- min_params)

X = df[['OA_Cd_ratio','T_reactor','Cd_mM','Se_mM','t_s']]
X2 = df[['OA_Cd_ratio','T_reactor','Cd_mM','Se_mM','t_s','Peak_eV']]
y = df['Peak_eV']
z = df['FWHM_eV']
group = df['Expt. No']

#Split groups for cross validation by Experiment number
gkf = GroupKFold(n_splits=10)
matrix = np.zeros([10,16])
matrix_fwhm = np.zeros([10,16])
matrix_cascade = np.zeros([10,16])

j = 0
#Loop through the 10 splits
for train_index, test_index in gkf.split(X, groups=group):
    #Separate out training and test sets
    X_train = X.iloc[train_index, :]
    X2_train = X2.iloc[train_index, :]
    y_train = y[train_index]
    z_train = z[train_index]
    X_test = X.iloc[test_index, :]
    X2_test = X2.iloc[test_index, :]
    y_test = y[test_index]
    z_test = z[test_index]
    
    #Load weights
    model_peak.load_weights('initialize_weights3.h5')
    model_fwhm.load_weights('initialize_weights3.h5')
    model_cascade.load_weights('initialize_weights4.h5')

    #Train models
    #prediction for Peak
    model_peak.fit(X_train, y_train, epochs=300, validation_data=(X_test, y_test),verbose = 1, use_multiprocessing=False, workers = 100)
    y_pred = model_peak.predict(X_test)
    #prediction for FWHM (direct)
    model_fwhm.fit(X_train, z_train, epochs=300, validation_data=(X_test, z_test),verbose = 1, use_multiprocessing=False, workers = 100)
    y_pred_fwhm = model_fwhm.predict(X_test)
    #prediction for FWHM (cascade)
    model_cascade.fit(X2_train, z_train, epochs=300, validation_data=(X2_test, z_test),verbose = 1, use_multiprocessing=False, workers = 100)
    X_test.insert(5, "Peak_eV", model_peak.predict(X_test), True)
    y_pred_cascade = model_cascade.predict(X_test)

    
    #prediction for Peak with dropout
    X_test = X.iloc[test_index, :]
    X_test_t = K.constant(X_test)
    y_pred_d =  predict_point(X_test_t, model_peak, 1000)
    #prediction for FWHM (direct)
    y_pred_fwhm_d = predict_point(X_test_t, model_fwhm, 1000)
    #prediction for FWHM (cascade)
    X_test.insert(5, "Peak_eV", y_pred_d, True)
    X_test_t2 = K.constant(X_test)
    y_pred_cascade_d = predict_point(X_test_t2, model_cascade, 1000)
    
    #errors in eV (normalized)
    #UN-normalize eV predictions by scaling with ratio

    ratio = (1239.84193/400 - 1239.84193/620)
    ratio2 = 0.35
    matrix[j,0] = metrics.mean_absolute_error(y_test, y_pred)*ratio
    matrix[j,1] = metrics.r2_score(y_test, y_pred)
    matrix[j,2] = rae(y_test, y_pred)
    matrix[j,3] = ratio*np.sqrt(metrics.mean_squared_error(y_test, y_pred))
    matrix[j,4] = metrics.mean_absolute_error(y_test, y_pred_d)*ratio 
    matrix[j,5] = metrics.r2_score(y_test, y_pred_d)
    matrix[j,6] = rae(y_test, y_pred_d)
    matrix[j,7] = ratio*np.sqrt(metrics.mean_squared_error(y_test, y_pred_d))

    matrix_fwhm[j,0] = metrics.mean_absolute_error(z_test, y_pred_fwhm)*ratio2
    matrix_fwhm[j,1] = metrics.r2_score(z_test, y_pred_fwhm)
    matrix_fwhm[j,2] = rae(z_test, y_pred_fwhm)
    matrix_fwhm[j,3] = ratio2*np.sqrt(metrics.mean_squared_error(z_test, y_pred_fwhm))
    matrix_fwhm[j,4] = metrics.mean_absolute_error(z_test, y_pred_fwhm_d)*ratio2
    matrix_fwhm[j,5] = metrics.r2_score(z_test, y_pred_fwhm_d)
    matrix_fwhm[j,6] = rae(z_test, y_pred_fwhm_d)
    matrix_fwhm[j,7] = ratio2*np.sqrt(metrics.mean_squared_error(z_test, y_pred_fwhm_d))
    
    matrix_cascade[j,0] = metrics.mean_absolute_error(z_test, y_pred_cascade)*ratio2
    matrix_cascade[j,1] = metrics.r2_score(z_test, y_pred_cascade)
    matrix_cascade[j,2] = rae(z_test, y_pred_cascade)
    matrix_cascade[j,3] = ratio2*np.sqrt(metrics.mean_squared_error(z_test, y_pred_cascade))
    matrix_cascade[j,4] = metrics.mean_absolute_error(z_test, y_pred_cascade_d)*ratio2
    matrix_cascade[j,5] = metrics.r2_score(z_test, y_pred_cascade_d)
    matrix_cascade[j,6] = rae(z_test, y_pred_cascade_d)
    matrix_cascade[j,7] = ratio2*np.sqrt(metrics.mean_squared_error(z_test, y_pred_cascade_d))
    
    

    #errors in nm
    #UNnormalize the data first
    y_test = y_test*(1239.84193/400 - 1239.84193/620)+1239.84193/620
    y_pred = y_pred*(1239.84193/400 - 1239.84193/620)+1239.84193/620
    y_pred_d = y_pred_d*(1239.84193/400 - 1239.84193/620)+1239.84193/620
    z_test = z_test*(0.35)+0.05
    y_pred_fwhm = y_pred_fwhm*(0.35)+0.05
    y_pred_fwhm_d = y_pred_fwhm_d*(0.35)+0.05
    y_pred_cascade = y_pred_cascade*(0.35)+0.05
    y_pred_cascade_d = y_pred_cascade_d*(0.35)+0.05
    
    #Calculate data in nm and eV
    matrix[j,8] = metrics.mean_absolute_error(peak_eV_nm(y_test), peak_eV_nm(y_pred))
    matrix[j,9] = metrics.r2_score(peak_eV_nm(y_test), peak_eV_nm(y_pred))
    matrix[j,10] = rae(peak_eV_nm(y_test), peak_eV_nm(y_pred))
    matrix[j,11] = np.sqrt(metrics.mean_squared_error(peak_eV_nm(y_test), peak_eV_nm(y_pred)))
    matrix[j,12] = metrics.mean_absolute_error(peak_eV_nm(y_test), peak_eV_nm(y_pred_d))
    matrix[j,13] = metrics.r2_score(peak_eV_nm(y_test), peak_eV_nm(y_pred_d))
    matrix[j,14] = rae(peak_eV_nm(y_test), peak_eV_nm(y_pred_d))
    matrix[j,15] = np.sqrt(metrics.mean_squared_error(peak_eV_nm(y_test), peak_eV_nm(y_pred_d)))

    matrix_fwhm[j,8] = metrics.mean_absolute_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm))
    matrix_fwhm[j,9] = metrics.r2_score(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm))
    matrix_fwhm[j,10] = rae(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm))
    matrix_fwhm[j,11] = np.sqrt(metrics.mean_squared_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm)))
    matrix_fwhm[j,12] = metrics.mean_absolute_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm_d)) 
    matrix_fwhm[j,13] = metrics.r2_score(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm_d))
    matrix_fwhm[j,14] = rae(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm_d)) 
    matrix_fwhm[j,15] = np.sqrt(metrics.mean_squared_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm_d))) 

    matrix_cascade[j,8] = metrics.mean_absolute_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade))
    matrix_cascade[j,9] = metrics.r2_score(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade))
    matrix_cascade[j,10] = rae(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade))
    matrix_cascade[j,11] = np.sqrt(metrics.mean_squared_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade)))
    matrix_cascade[j,12] = metrics.mean_absolute_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade_d))
    matrix_cascade[j,13] = metrics.r2_score(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade_d))
    matrix_cascade[j,14] = rae(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade_d))
    matrix_cascade[j,15] = np.sqrt(metrics.mean_squared_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade_d)))

    j+=1

matrix_2 = np.zeros([1,32])
matrix_2[0,:16] = matrix.mean(0)[:16]
matrix_2[0,16:32] = np.std(matrix[:,:16], axis=0)

matrix_3 = np.zeros([1,32])
matrix_3[0,:16] = matrix_fwhm.mean(0)[:16]
matrix_3[0,16:32]= np.std(matrix_fwhm[:,:16], axis=0)

matrix_4 = np.zeros([1,32])
matrix_4[0,:16] = matrix_cascade.mean(0)[:16]
matrix_4[0,16:32] = np.std(matrix_cascade[:,:16], axis=0)

np.set_printoptions(precision=5, threshold=5, edgeitems=4, suppress=True)
# Out:
# Epoch 1/300
# 144/144 [==============================] - 1s 2ms/step - loss: 0.0246 - val_loss: 0.0051
# Epoch 2/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0075 - val_loss: 0.0028
# Epoch 3/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0055 - val_loss: 0.0026
# Epoch 4/300
# 144/144 [==============================] - 0s 979us/step - loss: 0.0043 - val_loss: 0.0023
# Epoch 5/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0039 - val_loss: 0.0023
# Epoch 6/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0036 - val_loss: 0.0022
# Epoch 7/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0022
# Epoch 8/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0019
# Epoch 9/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0019
# Epoch 10/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0019
# Epoch 11/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0018
# Epoch 12/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 13/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0018
# Epoch 14/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0026 - val_loss: 0.0018
# Epoch 15/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0025 - val_loss: 0.0018
# Epoch 16/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0024 - val_loss: 0.0017
# Epoch 17/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0023 - val_loss: 0.0018
# Epoch 18/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 19/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 20/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 21/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 22/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 23/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 24/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 9.6550e-04
# Epoch 25/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 9.9013e-04
# Epoch 26/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 8.4360e-04
# Epoch 27/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 8.9378e-04
# Epoch 28/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 8.5082e-04
# Epoch 29/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 8.0128e-04
# Epoch 30/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 7.9621e-04
# Epoch 31/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 7.4816e-04
# Epoch 32/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 6.6883e-04
# Epoch 33/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 7.5211e-04
# Epoch 34/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 7.1062e-04
# Epoch 35/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 6.9361e-04
# Epoch 36/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0011 - val_loss: 6.2315e-04
# Epoch 37/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0010 - val_loss: 7.6772e-04
# Epoch 38/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0010 - val_loss: 7.2360e-04
# Epoch 39/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0010 - val_loss: 7.0619e-04
# Epoch 40/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0010 - val_loss: 7.4658e-04
# Epoch 41/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0010 - val_loss: 6.6410e-04
# Epoch 42/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0010 - val_loss: 7.4957e-04
# Epoch 43/300
# 144/144 [==============================] - 0s 1ms/step - loss: 9.6091e-04 - val_loss: 5.7238e-04
# Epoch 44/300
# 144/144 [==============================] - 0s 1ms/step - loss: 9.4595e-04 - val_loss: 7.6563e-04
# Epoch 45/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0010 - val_loss: 6.4275e-04
# Epoch 46/300
# 144/144 [==============================] - 0s 1ms/step - loss: 9.5900e-04 - val_loss: 6.1572e-04
# Epoch 47/300
# 144/144 [==============================] - 0s 1ms/step - loss: 9.5757e-04 - val_loss: 4.9533e-04
# Epoch 48/300
# 144/144 [==============================] - 0s 1ms/step - loss: 9.1302e-04 - val_loss: 4.9735e-04
# Epoch 49/300
# 144/144 [==============================] - 0s 1ms/step - loss: 9.1639e-04 - val_loss: 6.7241e-04
# Epoch 50/300
# 144/144 [==============================] - 0s 1ms/step - loss: 8.8311e-04 - val_loss: 6.6538e-04
# Epoch 51/300
# 144/144 [==============================] - 0s 1ms/step - loss: 9.2958e-04 - val_loss: 4.9071e-04
# Epoch 52/300
# 144/144 [==============================] - 0s 1ms/step - loss: 9.0155e-04 - val_loss: 4.9394e-04
# Epoch 53/300
# 144/144 [==============================] - 0s 1ms/step - loss: 8.7576e-04 - val_loss: 6.3993e-04
# Epoch 54/300
# 144/144 [==============================] - 0s 1ms/step - loss: 8.9601e-04 - val_loss: 5.5179e-04
# Epoch 55/300
# 144/144 [==============================] - 0s 1ms/step - loss: 8.6919e-04 - val_loss: 5.7009e-04
# Epoch 56/300
# 144/144 [==============================] - 0s 1ms/step - loss: 9.0884e-04 - val_loss: 7.3797e-04
# Epoch 57/300
# 144/144 [==============================] - 0s 1ms/step - loss: 8.3947e-04 - val_loss: 5.8344e-04
# Epoch 58/300
# 144/144 [==============================] - 0s 1ms/step - loss: 8.5994e-04 - val_loss: 5.6509e-04
# Epoch 59/300
# 144/144 [==============================] - 0s 1ms/step - loss: 8.7624e-04 - val_loss: 5.5089e-04
# Epoch 60/300
# 144/144 [==============================] - 0s 1ms/step - loss: 9.0392e-04 - val_loss: 6.0530e-04
# Epoch 61/300
# 144/144 [==============================] - 0s 1ms/step - loss: 8.7366e-04 - val_loss: 6.5699e-04
# Epoch 62/300
# 144/144 [==============================] - 0s 1ms/step - loss: 8.4703e-04 - val_loss: 5.7768e-04
# Epoch 63/300
# 144/144 [==============================] - 0s 950us/step - loss: 8.2121e-04 - val_loss: 5.7818e-04
# Epoch 64/300
# 144/144 [==============================] - 0s 1ms/step - loss: 8.5098e-04 - val_loss: 4.8478e-04
# Epoch 65/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.9827e-04 - val_loss: 5.5882e-04
# Epoch 66/300
# 144/144 [==============================] - 0s 979us/step - loss: 8.1511e-04 - val_loss: 5.3652e-04
# Epoch 67/300
# 144/144 [==============================] - 0s 1ms/step - loss: 8.2156e-04 - val_loss: 5.4784e-04
# Epoch 68/300
# 144/144 [==============================] - 0s 1ms/step - loss: 8.8738e-04 - val_loss: 5.6397e-04
# Epoch 69/300
# 144/144 [==============================] - 0s 1ms/step - loss: 8.1115e-04 - val_loss: 5.6138e-04
# Epoch 70/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.8722e-04 - val_loss: 5.8049e-04
# Epoch 71/300
# 144/144 [==============================] - 0s 1ms/step - loss: 8.0672e-04 - val_loss: 5.2980e-04
# Epoch 72/300
# 144/144 [==============================] - 0s 1ms/step - loss: 8.3370e-04 - val_loss: 5.0556e-04
# Epoch 73/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.6082e-04 - val_loss: 5.5921e-04
# Epoch 74/300
# 144/144 [==============================] - 0s 986us/step - loss: 7.8000e-04 - val_loss: 5.3215e-04
# Epoch 75/300
# 144/144 [==============================] - 0s 955us/step - loss: 7.8384e-04 - val_loss: 5.6023e-04
# Epoch 76/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.8205e-04 - val_loss: 5.0458e-04
# Epoch 77/300
# 144/144 [==============================] - 0s 992us/step - loss: 7.5305e-04 - val_loss: 5.9923e-04
# Epoch 78/300
# 144/144 [==============================] - 0s 951us/step - loss: 7.4570e-04 - val_loss: 5.4013e-04
# Epoch 79/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.8684e-04 - val_loss: 6.5616e-04
# Epoch 80/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.6742e-04 - val_loss: 4.9760e-04
# Epoch 81/300
# 144/144 [==============================] - 0s 1ms/step - loss: 8.0187e-04 - val_loss: 7.8051e-04
# Epoch 82/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.6427e-04 - val_loss: 6.1135e-04
# Epoch 83/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.9038e-04 - val_loss: 5.7228e-04
# Epoch 84/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.5141e-04 - val_loss: 6.2619e-04
# Epoch 85/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.9089e-04 - val_loss: 6.5058e-04
# Epoch 86/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.6632e-04 - val_loss: 5.2005e-04
# Epoch 87/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.5478e-04 - val_loss: 5.4019e-04
# Epoch 88/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.6899e-04 - val_loss: 4.6781e-04
# Epoch 89/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.7713e-04 - val_loss: 5.4048e-04
# Epoch 90/300
# 144/144 [==============================] - 0s 972us/step - loss: 7.5711e-04 - val_loss: 5.4370e-04
# Epoch 91/300
# 144/144 [==============================] - 0s 979us/step - loss: 7.3765e-04 - val_loss: 5.0274e-04
# Epoch 92/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.1235e-04 - val_loss: 5.6523e-04
# Epoch 93/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.5817e-04 - val_loss: 6.5746e-04
# Epoch 94/300
# 144/144 [==============================] - 0s 980us/step - loss: 7.5464e-04 - val_loss: 5.3736e-04
# Epoch 95/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.3368e-04 - val_loss: 5.5013e-04
# Epoch 96/300
# 144/144 [==============================] - 0s 955us/step - loss: 7.3647e-04 - val_loss: 4.3574e-04
# Epoch 97/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.3302e-04 - val_loss: 5.3454e-04
# Epoch 98/300
# 144/144 [==============================] - 0s 982us/step - loss: 7.5702e-04 - val_loss: 5.5429e-04
# Epoch 99/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.5485e-04 - val_loss: 4.8387e-04
# Epoch 100/300
# 144/144 [==============================] - 0s 962us/step - loss: 7.2962e-04 - val_loss: 5.4826e-04
# Epoch 101/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.4216e-04 - val_loss: 5.1510e-04
# Epoch 102/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.9758e-04 - val_loss: 5.2454e-04
# Epoch 103/300
# 144/144 [==============================] - 0s 993us/step - loss: 7.0097e-04 - val_loss: 4.6417e-04
# Epoch 104/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.5270e-04 - val_loss: 5.8591e-04
# Epoch 105/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.1180e-04 - val_loss: 6.7519e-04
# Epoch 106/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.0585e-04 - val_loss: 4.8649e-04
# Epoch 107/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.1969e-04 - val_loss: 5.1786e-04
# Epoch 108/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.4527e-04 - val_loss: 7.4805e-04
# Epoch 109/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.7623e-04 - val_loss: 5.0908e-04
# Epoch 110/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.2653e-04 - val_loss: 5.0872e-04
# Epoch 111/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.1219e-04 - val_loss: 6.5919e-04
# Epoch 112/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.4928e-04 - val_loss: 4.9561e-04
# Epoch 113/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.9037e-04 - val_loss: 5.5217e-04
# Epoch 114/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.8407e-04 - val_loss: 6.1277e-04
# Epoch 115/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.8550e-04 - val_loss: 5.2171e-04
# Epoch 116/300
# 144/144 [==============================] - 0s 995us/step - loss: 7.1973e-04 - val_loss: 6.3613e-04
# Epoch 117/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.0299e-04 - val_loss: 5.6914e-04
# Epoch 118/300
# 144/144 [==============================] - 0s 989us/step - loss: 6.7322e-04 - val_loss: 4.5765e-04
# Epoch 119/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.7237e-04 - val_loss: 5.0840e-04
# Epoch 120/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.1293e-04 - val_loss: 6.1228e-04
# Epoch 121/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.0987e-04 - val_loss: 5.6398e-04
# Epoch 122/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.0084e-04 - val_loss: 5.6623e-04
# Epoch 123/300
# 144/144 [==============================] - 0s 971us/step - loss: 6.9111e-04 - val_loss: 5.2298e-04
# Epoch 124/300
# 144/144 [==============================] - 0s 951us/step - loss: 6.9215e-04 - val_loss: 5.5370e-04
# Epoch 125/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.8594e-04 - val_loss: 5.3992e-04
# Epoch 126/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.6919e-04 - val_loss: 5.3542e-04
# Epoch 127/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.9175e-04 - val_loss: 5.0305e-04
# Epoch 128/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.6981e-04 - val_loss: 5.6299e-04
# Epoch 129/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.5325e-04 - val_loss: 5.0354e-04
# Epoch 130/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.7593e-04 - val_loss: 4.6890e-04
# Epoch 131/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.4459e-04 - val_loss: 6.1050e-04
# Epoch 132/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.9763e-04 - val_loss: 4.8669e-04
# Epoch 133/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.8079e-04 - val_loss: 5.6889e-04
# Epoch 134/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.6338e-04 - val_loss: 5.2821e-04
# Epoch 135/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.9069e-04 - val_loss: 4.5785e-04
# Epoch 136/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.9328e-04 - val_loss: 5.0701e-04
# Epoch 137/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.5175e-04 - val_loss: 4.4018e-04
# Epoch 138/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.0126e-04 - val_loss: 5.2591e-04
# Epoch 139/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.2692e-04 - val_loss: 5.5784e-04
# Epoch 140/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.0034e-04 - val_loss: 4.8196e-04
# Epoch 141/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.4486e-04 - val_loss: 5.2882e-04
# Epoch 142/300
# 144/144 [==============================] - 0s 995us/step - loss: 6.6550e-04 - val_loss: 5.5558e-04
# Epoch 143/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.4590e-04 - val_loss: 6.2696e-04
# Epoch 144/300
# 144/144 [==============================] - 0s 972us/step - loss: 6.9771e-04 - val_loss: 5.9328e-04
# Epoch 145/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.8456e-04 - val_loss: 4.3695e-04
# Epoch 146/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.6107e-04 - val_loss: 6.1899e-04
# Epoch 147/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.5920e-04 - val_loss: 5.1268e-04
# Epoch 148/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.9231e-04 - val_loss: 4.1579e-04
# Epoch 149/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.7579e-04 - val_loss: 5.3869e-04
# Epoch 150/300
# 144/144 [==============================] - 0s 951us/step - loss: 6.5837e-04 - val_loss: 5.4263e-04
# Epoch 151/300
# 144/144 [==============================] - 0s 955us/step - loss: 6.4616e-04 - val_loss: 4.9955e-04
# Epoch 152/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.7617e-04 - val_loss: 4.8235e-04
# Epoch 153/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.4870e-04 - val_loss: 4.5553e-04
# Epoch 154/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.0520e-04 - val_loss: 5.8867e-04
# Epoch 155/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.6713e-04 - val_loss: 4.2225e-04
# Epoch 156/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.4708e-04 - val_loss: 5.4969e-04
# Epoch 157/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.5910e-04 - val_loss: 5.2349e-04
# Epoch 158/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.4669e-04 - val_loss: 5.5474e-04
# Epoch 159/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.3493e-04 - val_loss: 5.6184e-04
# Epoch 160/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.8498e-04 - val_loss: 5.4756e-04
# Epoch 161/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.5261e-04 - val_loss: 5.0339e-04
# Epoch 162/300
# 144/144 [==============================] - 0s 983us/step - loss: 6.6504e-04 - val_loss: 5.9190e-04
# Epoch 163/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.5906e-04 - val_loss: 5.1510e-04
# Epoch 164/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.3321e-04 - val_loss: 5.0319e-04
# Epoch 165/300
# 144/144 [==============================] - 0s 1000us/step - loss: 6.6578e-04 - val_loss: 4.3789e-04
# Epoch 166/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.5589e-04 - val_loss: 4.5194e-04
# Epoch 167/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.9753e-04 - val_loss: 4.2837e-04
# Epoch 168/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.5870e-04 - val_loss: 5.2046e-04
# Epoch 169/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.4555e-04 - val_loss: 5.4460e-04
# Epoch 170/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.6113e-04 - val_loss: 6.6289e-04
# Epoch 171/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.3356e-04 - val_loss: 5.0781e-04
# Epoch 172/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.4117e-04 - val_loss: 4.8816e-04
# Epoch 173/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.4840e-04 - val_loss: 4.4492e-04
# Epoch 174/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.4395e-04 - val_loss: 5.4629e-04
# Epoch 175/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.2991e-04 - val_loss: 4.0112e-04
# Epoch 176/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.2036e-04 - val_loss: 5.5443e-04
# Epoch 177/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.3943e-04 - val_loss: 4.8657e-04
# Epoch 178/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.2943e-04 - val_loss: 5.6428e-04
# Epoch 179/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.6561e-04 - val_loss: 5.2527e-04
# Epoch 180/300
# 144/144 [==============================] - 0s 983us/step - loss: 6.7287e-04 - val_loss: 5.2071e-04
# Epoch 181/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.4298e-04 - val_loss: 4.4155e-04
# Epoch 182/300
# 144/144 [==============================] - 0s 975us/step - loss: 5.9822e-04 - val_loss: 5.1366e-04
# Epoch 183/300
# 144/144 [==============================] - 0s 955us/step - loss: 6.1026e-04 - val_loss: 4.3676e-04
# Epoch 184/300
# 144/144 [==============================] - 0s 994us/step - loss: 6.5905e-04 - val_loss: 4.2405e-04
# Epoch 185/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.7948e-04 - val_loss: 4.8538e-04
# Epoch 186/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.5810e-04 - val_loss: 4.7332e-04
# Epoch 187/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.3011e-04 - val_loss: 4.8138e-04
# Epoch 188/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.5836e-04 - val_loss: 4.5281e-04
# Epoch 189/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.6120e-04 - val_loss: 5.1124e-04
# Epoch 190/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.3663e-04 - val_loss: 5.1497e-04
# Epoch 191/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.3875e-04 - val_loss: 4.5620e-04
# Epoch 192/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.6058e-04 - val_loss: 5.5444e-04
# Epoch 193/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.2640e-04 - val_loss: 4.7500e-04
# Epoch 194/300
# 144/144 [==============================] - 0s 968us/step - loss: 6.1731e-04 - val_loss: 4.9987e-04
# Epoch 195/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.2526e-04 - val_loss: 4.4451e-04
# Epoch 196/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.2560e-04 - val_loss: 4.5977e-04
# Epoch 197/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.5015e-04 - val_loss: 4.2441e-04
# Epoch 198/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.0380e-04 - val_loss: 6.8451e-04
# Epoch 199/300
# 144/144 [==============================] - 0s 969us/step - loss: 6.2486e-04 - val_loss: 5.0943e-04
# Epoch 200/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.8802e-04 - val_loss: 5.0787e-04
# Epoch 201/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.1362e-04 - val_loss: 5.2758e-04
# Epoch 202/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.1166e-04 - val_loss: 4.2702e-04
# Epoch 203/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.2196e-04 - val_loss: 5.1414e-04
# Epoch 204/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.1810e-04 - val_loss: 5.0698e-04
# Epoch 205/300
# 144/144 [==============================] - 0s 987us/step - loss: 6.1688e-04 - val_loss: 5.2628e-04
# Epoch 206/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.0252e-04 - val_loss: 4.3257e-04
# Epoch 207/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.9133e-04 - val_loss: 6.6872e-04
# Epoch 208/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.3047e-04 - val_loss: 6.0564e-04
# Epoch 209/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.5748e-04 - val_loss: 6.1255e-04
# Epoch 210/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.2398e-04 - val_loss: 5.1163e-04
# Epoch 211/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.2318e-04 - val_loss: 4.6192e-04
# Epoch 212/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.2152e-04 - val_loss: 5.0302e-04
# Epoch 213/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.0868e-04 - val_loss: 5.0919e-04
# Epoch 214/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.3391e-04 - val_loss: 4.6811e-04
# Epoch 215/300
# 144/144 [==============================] - 0s 998us/step - loss: 6.2305e-04 - val_loss: 4.8000e-04
# Epoch 216/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.1318e-04 - val_loss: 5.0012e-04
# Epoch 217/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.0629e-04 - val_loss: 4.8697e-04
# Epoch 218/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.3518e-04 - val_loss: 4.7268e-04
# Epoch 219/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.0166e-04 - val_loss: 5.3271e-04
# Epoch 220/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.0806e-04 - val_loss: 4.7359e-04
# Epoch 221/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.9153e-04 - val_loss: 4.5388e-04
# Epoch 222/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.2793e-04 - val_loss: 4.9161e-04
# Epoch 223/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.3578e-04 - val_loss: 5.3545e-04
# Epoch 224/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.5275e-04 - val_loss: 4.4858e-04
# Epoch 225/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.2464e-04 - val_loss: 5.1544e-04
# Epoch 226/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.4159e-04 - val_loss: 5.0849e-04
# Epoch 227/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.1953e-04 - val_loss: 5.1995e-04
# Epoch 228/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.0208e-04 - val_loss: 4.5341e-04
# Epoch 229/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.9457e-04 - val_loss: 5.9123e-04
# Epoch 230/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.1755e-04 - val_loss: 4.3140e-04
# Epoch 231/300
# 144/144 [==============================] - 0s 979us/step - loss: 5.9622e-04 - val_loss: 5.3053e-04
# Epoch 232/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.0509e-04 - val_loss: 4.5976e-04
# Epoch 233/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.9122e-04 - val_loss: 4.1843e-04
# Epoch 234/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.7570e-04 - val_loss: 4.5086e-04
# Epoch 235/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.0321e-04 - val_loss: 4.2273e-04
# Epoch 236/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.2647e-04 - val_loss: 4.3944e-04
# Epoch 237/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.1568e-04 - val_loss: 4.7099e-04
# Epoch 238/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.8653e-04 - val_loss: 6.2052e-04
# Epoch 239/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.9613e-04 - val_loss: 5.8376e-04
# Epoch 240/300
# 144/144 [==============================] - 0s 982us/step - loss: 6.3044e-04 - val_loss: 5.4241e-04
# Epoch 241/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.4672e-04 - val_loss: 4.8581e-04
# Epoch 242/300
# 144/144 [==============================] - 0s 987us/step - loss: 5.9073e-04 - val_loss: 4.8822e-04
# Epoch 243/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.8755e-04 - val_loss: 4.4818e-04
# Epoch 244/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.2031e-04 - val_loss: 4.7930e-04
# Epoch 245/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.1173e-04 - val_loss: 5.0370e-04
# Epoch 246/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.1998e-04 - val_loss: 5.1049e-04
# Epoch 247/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.3480e-04 - val_loss: 4.2140e-04
# Epoch 248/300
# 144/144 [==============================] - 0s 996us/step - loss: 6.2216e-04 - val_loss: 6.3705e-04
# Epoch 249/300
# 144/144 [==============================] - 0s 975us/step - loss: 6.0167e-04 - val_loss: 5.0201e-04
# Epoch 250/300
# 144/144 [==============================] - 0s 986us/step - loss: 6.0868e-04 - val_loss: 4.4135e-04
# Epoch 251/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.7950e-04 - val_loss: 5.3626e-04
# Epoch 252/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.1625e-04 - val_loss: 4.8030e-04
# Epoch 253/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.0960e-04 - val_loss: 4.4673e-04
# Epoch 254/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.1399e-04 - val_loss: 5.6126e-04
# Epoch 255/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.1019e-04 - val_loss: 6.4112e-04
# Epoch 256/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.2327e-04 - val_loss: 4.5478e-04
# Epoch 257/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.8608e-04 - val_loss: 5.8017e-04
# Epoch 258/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.5668e-04 - val_loss: 4.1007e-04
# Epoch 259/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.9830e-04 - val_loss: 4.8359e-04
# Epoch 260/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.9826e-04 - val_loss: 4.6752e-04
# Epoch 261/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.1873e-04 - val_loss: 4.1562e-04
# Epoch 262/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.0645e-04 - val_loss: 5.5986e-04
# Epoch 263/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.9799e-04 - val_loss: 4.2617e-04
# Epoch 264/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.9790e-04 - val_loss: 5.0409e-04
# Epoch 265/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.9129e-04 - val_loss: 5.3456e-04
# Epoch 266/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.7842e-04 - val_loss: 4.9290e-04
# Epoch 267/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.9791e-04 - val_loss: 5.0238e-04
# Epoch 268/300
# 144/144 [==============================] - 0s 984us/step - loss: 6.1187e-04 - val_loss: 5.8812e-04
# Epoch 269/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.0345e-04 - val_loss: 4.5758e-04
# Epoch 270/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.1591e-04 - val_loss: 4.9976e-04
# Epoch 271/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.5020e-04 - val_loss: 6.4463e-04
# Epoch 272/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.0675e-04 - val_loss: 5.0374e-04
# Epoch 273/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.9264e-04 - val_loss: 4.1549e-04
# Epoch 274/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.3450e-04 - val_loss: 4.9713e-04
# Epoch 275/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.8592e-04 - val_loss: 5.3136e-04
# Epoch 276/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.7336e-04 - val_loss: 3.8708e-04
# Epoch 277/300
# 144/144 [==============================] - 0s 966us/step - loss: 5.8462e-04 - val_loss: 4.7658e-04
# Epoch 278/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.7357e-04 - val_loss: 4.2681e-04
# Epoch 279/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.6816e-04 - val_loss: 4.3150e-04
# Epoch 280/300
# 144/144 [==============================] - 0s 954us/step - loss: 5.8035e-04 - val_loss: 4.5661e-04
# Epoch 281/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.8997e-04 - val_loss: 4.6965e-04
# Epoch 282/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.7923e-04 - val_loss: 4.3660e-04
# Epoch 283/300
# 144/144 [==============================] - 0s 980us/step - loss: 5.9931e-04 - val_loss: 4.7221e-04
# Epoch 284/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.0570e-04 - val_loss: 4.7652e-04
# Epoch 285/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.8169e-04 - val_loss: 4.1435e-04
# Epoch 286/300
# 144/144 [==============================] - 0s 979us/step - loss: 5.7803e-04 - val_loss: 6.3652e-04
# Epoch 287/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.1672e-04 - val_loss: 5.2739e-04
# Epoch 288/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.7916e-04 - val_loss: 4.5276e-04
# Epoch 289/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.7100e-04 - val_loss: 3.9516e-04
# Epoch 290/300
# 144/144 [==============================] - 0s 979us/step - loss: 5.8187e-04 - val_loss: 5.9075e-04
# Epoch 291/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.0635e-04 - val_loss: 4.3421e-04
# Epoch 292/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.0054e-04 - val_loss: 4.8205e-04
# Epoch 293/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.2303e-04 - val_loss: 4.4700e-04
# Epoch 294/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.0088e-04 - val_loss: 4.5978e-04
# Epoch 295/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.7459e-04 - val_loss: 5.1968e-04
# Epoch 296/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.6379e-04 - val_loss: 4.7071e-04
# Epoch 297/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.8667e-04 - val_loss: 4.8105e-04
# Epoch 298/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.6300e-04 - val_loss: 3.9781e-04
# Epoch 299/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.8188e-04 - val_loss: 4.9600e-04
# Epoch 300/300
# 144/144 [==============================] - 0s 1ms/step - loss: 5.7647e-04 - val_loss: 4.7483e-04
# 16/16 [==============================] - 0s 798us/step
# Epoch 1/300
# 144/144 [==============================] - 1s 2ms/step - loss: 0.0064 - val_loss: 0.0024
# Epoch 2/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0022
# Epoch 3/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0021
# Epoch 4/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0021
# Epoch 5/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0020
# Epoch 6/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0026 - val_loss: 0.0018
# Epoch 7/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0024 - val_loss: 0.0018
# Epoch 8/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0023 - val_loss: 0.0017
# Epoch 9/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0022 - val_loss: 0.0016
# Epoch 10/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 11/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 12/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 13/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 14/300
# 144/144 [==============================] - 0s 955us/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 15/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 16/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 17/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 18/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 19/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 20/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 21/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 22/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 23/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 24/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 25/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 26/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 27/300
# 144/144 [==============================] - 0s 979us/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 28/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 29/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 30/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 31/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 32/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 33/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 34/300
# 144/144 [==============================] - 0s 981us/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 35/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 36/300
# 144/144 [==============================] - 0s 986us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 37/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 38/300
# 144/144 [==============================] - 0s 979us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 39/300
# 144/144 [==============================] - 0s 951us/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 40/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 41/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 42/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 43/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 44/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 45/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 46/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 47/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 48/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 49/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 50/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 51/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 52/300
# 144/144 [==============================] - 0s 988us/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 53/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 54/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 55/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 56/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 57/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 58/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 59/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 60/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 61/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 62/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 63/300
# 144/144 [==============================] - 0s 972us/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 64/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 65/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 66/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 67/300
# 144/144 [==============================] - 0s 996us/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 68/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 69/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 70/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 71/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 72/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 73/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 74/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 75/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 76/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 77/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 78/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 79/300
# 144/144 [==============================] - 0s 949us/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 80/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 81/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 82/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 83/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 84/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 85/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 86/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 87/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 88/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 89/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 90/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 91/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 92/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 93/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 94/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 95/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 96/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 97/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 98/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 99/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 100/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 101/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 102/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 103/300
# 144/144 [==============================] - 0s 989us/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 104/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 105/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 106/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 107/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 108/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 109/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 110/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 111/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 112/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 113/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 114/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 115/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 116/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 117/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 118/300
# 144/144 [==============================] - 0s 996us/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 119/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 120/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 121/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 122/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 123/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 124/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 125/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 126/300
# 144/144 [==============================] - 0s 974us/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 127/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 128/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 129/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 130/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 131/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 132/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 133/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 134/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 135/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 136/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 137/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 138/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 139/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 140/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 141/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 142/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 143/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 144/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 145/300
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 146/300
# ...
# Epoch 158/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.4787e-04 - val_loss: 8.8812e-04
# Epoch 159/300
# 144/144 [==============================] - 0s 1ms/step - loss: 8.0735e-04 - val_loss: 9.0830e-04
# Epoch 160/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.7869e-04 - val_loss: 9.2223e-04
# Epoch 161/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.8688e-04 - val_loss: 9.0714e-04
# Epoch 162/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.8077e-04 - val_loss: 9.4898e-04
# Epoch 163/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.6224e-04 - val_loss: 9.6168e-04
# Epoch 164/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.7390e-04 - val_loss: 9.7193e-04
# Epoch 165/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.2240e-04 - val_loss: 9.1073e-04
# Epoch 166/300
# 144/144 [==============================] - 0s 1ms/step - loss: 8.3189e-04 - val_loss: 9.1227e-04
# Epoch 167/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.7718e-04 - val_loss: 9.4026e-04
# Epoch 168/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.7373e-04 - val_loss: 0.0010
# Epoch 169/300
# 144/144 [==============================] - 0s 1ms/step - loss: 8.2441e-04 - val_loss: 9.3099e-04
# Epoch 170/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.4755e-04 - val_loss: 9.4804e-04
# Epoch 171/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.3835e-04 - val_loss: 8.9995e-04
# Epoch 172/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.6843e-04 - val_loss: 0.0010
# Epoch 173/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.5151e-04 - val_loss: 9.2093e-04
# Epoch 174/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.8858e-04 - val_loss: 9.7113e-04
# Epoch 175/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.5501e-04 - val_loss: 9.0956e-04
# Epoch 176/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.8681e-04 - val_loss: 9.5931e-04
# Epoch 177/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.5174e-04 - val_loss: 9.2537e-04
# Epoch 178/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.8192e-04 - val_loss: 8.6965e-04
# Epoch 179/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.6616e-04 - val_loss: 9.1853e-04
# Epoch 180/300
# 144/144 [==============================] - 0s 1ms/step - loss: 8.0358e-04 - val_loss: 8.8401e-04
# Epoch 181/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.6654e-04 - val_loss: 9.3756e-04
# Epoch 182/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.4835e-04 - val_loss: 9.3531e-04
# Epoch 183/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.8145e-04 - val_loss: 9.0601e-04
# Epoch 184/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.4633e-04 - val_loss: 9.4638e-04
# Epoch 185/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.6539e-04 - val_loss: 9.4365e-04
# Epoch 186/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.3153e-04 - val_loss: 8.9354e-04
# Epoch 187/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.6385e-04 - val_loss: 8.7670e-04
# Epoch 188/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.7490e-04 - val_loss: 9.8057e-04
# Epoch 189/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.5945e-04 - val_loss: 9.6937e-04
# Epoch 190/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.4604e-04 - val_loss: 9.6816e-04
# Epoch 191/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.7168e-04 - val_loss: 8.8769e-04
# Epoch 192/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.4938e-04 - val_loss: 9.2026e-04
# Epoch 193/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.3687e-04 - val_loss: 9.4533e-04
# Epoch 194/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.4029e-04 - val_loss: 9.0376e-04
# Epoch 195/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.9437e-04 - val_loss: 9.6782e-04
# Epoch 196/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.0689e-04 - val_loss: 8.8441e-04
# Epoch 197/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.6682e-04 - val_loss: 8.6725e-04
# Epoch 198/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.0164e-04 - val_loss: 9.0324e-04
# Epoch 199/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.4824e-04 - val_loss: 9.1226e-04
# Epoch 200/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.3964e-04 - val_loss: 8.9086e-04
# Epoch 201/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.2600e-04 - val_loss: 8.9031e-04
# Epoch 202/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.4663e-04 - val_loss: 9.3189e-04
# Epoch 203/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.3568e-04 - val_loss: 8.9750e-04
# Epoch 204/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.3696e-04 - val_loss: 8.6895e-04
# Epoch 205/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.4833e-04 - val_loss: 9.2844e-04
# Epoch 206/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.3001e-04 - val_loss: 9.0829e-04
# Epoch 207/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.1843e-04 - val_loss: 9.4525e-04
# Epoch 208/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.2334e-04 - val_loss: 9.2845e-04
# Epoch 209/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.3106e-04 - val_loss: 9.3811e-04
# Epoch 210/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.1949e-04 - val_loss: 8.7161e-04
# Epoch 211/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.5175e-04 - val_loss: 9.2504e-04
# Epoch 212/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.9943e-04 - val_loss: 9.4979e-04
# Epoch 213/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.6671e-04 - val_loss: 8.5651e-04
# Epoch 214/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.5821e-04 - val_loss: 8.6715e-04
# Epoch 215/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.4265e-04 - val_loss: 9.0825e-04
# Epoch 216/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.1714e-04 - val_loss: 8.9518e-04
# Epoch 217/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.4489e-04 - val_loss: 9.6203e-04
# Epoch 218/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.6019e-04 - val_loss: 9.2167e-04
# Epoch 219/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.4756e-04 - val_loss: 9.4656e-04
# Epoch 220/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.1311e-04 - val_loss: 9.4794e-04
# Epoch 221/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.3277e-04 - val_loss: 9.1815e-04
# Epoch 222/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.3124e-04 - val_loss: 8.4063e-04
# Epoch 223/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.1126e-04 - val_loss: 0.0010
# Epoch 224/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.9391e-04 - val_loss: 8.9196e-04
# Epoch 225/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.2321e-04 - val_loss: 8.9842e-04
# Epoch 226/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.0233e-04 - val_loss: 9.4571e-04
# Epoch 227/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.9629e-04 - val_loss: 8.9741e-04
# Epoch 228/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.2956e-04 - val_loss: 8.8701e-04
# Epoch 229/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.9492e-04 - val_loss: 8.7445e-04
# Epoch 230/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.0881e-04 - val_loss: 9.3593e-04
# Epoch 231/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.1334e-04 - val_loss: 9.1153e-04
# Epoch 232/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.1270e-04 - val_loss: 8.6519e-04
# Epoch 233/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.3381e-04 - val_loss: 9.0823e-04
# Epoch 234/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.5788e-04 - val_loss: 8.9531e-04
# Epoch 235/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.0304e-04 - val_loss: 9.0838e-04
# Epoch 236/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.1256e-04 - val_loss: 9.2353e-04
# Epoch 237/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.9859e-04 - val_loss: 8.9193e-04
# Epoch 238/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.9909e-04 - val_loss: 8.7697e-04
# Epoch 239/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.1699e-04 - val_loss: 8.5019e-04
# Epoch 240/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.1489e-04 - val_loss: 9.2046e-04
# Epoch 241/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.7881e-04 - val_loss: 8.5266e-04
# Epoch 242/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.9033e-04 - val_loss: 8.4257e-04
# Epoch 243/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.0709e-04 - val_loss: 8.0947e-04
# Epoch 244/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.1872e-04 - val_loss: 8.9643e-04
# Epoch 245/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.7240e-04 - val_loss: 8.4546e-04
# Epoch 246/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.7632e-04 - val_loss: 8.3442e-04
# Epoch 247/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.0931e-04 - val_loss: 9.2075e-04
# Epoch 248/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.1502e-04 - val_loss: 8.4564e-04
# Epoch 249/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.1464e-04 - val_loss: 8.5080e-04
# Epoch 250/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.1137e-04 - val_loss: 8.7018e-04
# Epoch 251/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.1300e-04 - val_loss: 8.6371e-04
# Epoch 252/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.1230e-04 - val_loss: 8.5836e-04
# Epoch 253/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.9851e-04 - val_loss: 7.9789e-04
# Epoch 254/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.9946e-04 - val_loss: 8.0827e-04
# Epoch 255/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.1086e-04 - val_loss: 8.9102e-04
# Epoch 256/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.9882e-04 - val_loss: 8.1768e-04
# Epoch 257/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.7847e-04 - val_loss: 8.9929e-04
# Epoch 258/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.0791e-04 - val_loss: 8.4053e-04
# Epoch 259/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.5755e-04 - val_loss: 8.6243e-04
# Epoch 260/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.2133e-04 - val_loss: 8.2651e-04
# Epoch 261/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.9232e-04 - val_loss: 8.6179e-04
# Epoch 262/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.5563e-04 - val_loss: 9.3702e-04
# Epoch 263/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.9959e-04 - val_loss: 8.7435e-04
# Epoch 264/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.2967e-04 - val_loss: 8.6531e-04
# Epoch 265/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.7306e-04 - val_loss: 8.7669e-04
# Epoch 266/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.4019e-04 - val_loss: 9.1737e-04
# Epoch 267/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.7481e-04 - val_loss: 8.4302e-04
# Epoch 268/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.6992e-04 - val_loss: 9.1918e-04
# Epoch 269/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.8743e-04 - val_loss: 8.8865e-04
# Epoch 270/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.6019e-04 - val_loss: 8.7256e-04
# Epoch 271/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.0927e-04 - val_loss: 7.8435e-04
# Epoch 272/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.7900e-04 - val_loss: 8.7127e-04
# Epoch 273/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.8410e-04 - val_loss: 8.5757e-04
# Epoch 274/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.8126e-04 - val_loss: 8.3493e-04
# Epoch 275/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.0354e-04 - val_loss: 8.0535e-04
# Epoch 276/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.6614e-04 - val_loss: 8.2992e-04
# Epoch 277/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.3975e-04 - val_loss: 8.9892e-04
# Epoch 278/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.5907e-04 - val_loss: 8.4399e-04
# Epoch 279/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.1002e-04 - val_loss: 8.3078e-04
# Epoch 280/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.9045e-04 - val_loss: 9.0639e-04
# Epoch 281/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.7563e-04 - val_loss: 8.2412e-04
# Epoch 282/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.5276e-04 - val_loss: 8.6852e-04
# Epoch 283/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.9666e-04 - val_loss: 8.2657e-04
# Epoch 284/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.6848e-04 - val_loss: 8.7260e-04
# Epoch 285/300
# 144/144 [==============================] - 0s 1ms/step - loss: 7.3937e-04 - val_loss: 8.3900e-04
# Epoch 286/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.2802e-04 - val_loss: 8.4117e-04
# Epoch 287/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.7255e-04 - val_loss: 7.9401e-04
# Epoch 288/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.6661e-04 - val_loss: 8.6413e-04
# Epoch 289/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.8463e-04 - val_loss: 7.9493e-04
# Epoch 290/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.6031e-04 - val_loss: 8.0536e-04
# Epoch 291/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.7839e-04 - val_loss: 8.3298e-04
# Epoch 292/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.4700e-04 - val_loss: 8.5071e-04
# Epoch 293/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.8541e-04 - val_loss: 8.2636e-04
# Epoch 294/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.6282e-04 - val_loss: 7.7746e-04
# Epoch 295/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.9095e-04 - val_loss: 7.7139e-04
# Epoch 296/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.4430e-04 - val_loss: 7.9881e-04
# Epoch 297/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.6313e-04 - val_loss: 8.2478e-04
# Epoch 298/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.8628e-04 - val_loss: 8.0527e-04
# Epoch 299/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.8674e-04 - val_loss: 8.2063e-04
# Epoch 300/300
# 144/144 [==============================] - 0s 1ms/step - loss: 6.8433e-04 - val_loss: 8.2804e-04
# 16/16 [==============================] - 0s 667us/step
# 16/16 [==============================] - 0s 666us/step

# %%
print('\033[1m' + 'Model without Dropout at Inference' + '\033[0m')
print('\033[1m' + 'Absorbance Peak' + '\033[0m')
print("MAE (eV): \t", "{:.4f}".format(matrix_2[0,0]), "{:.4f}".format(matrix_2[0,16]))
print("R2 (eV):\t", "{:.4f}".format(matrix_2[0,1]), "{:.4f}".format(matrix_2[0,17]))
print("RAE (eV):\t", "{:.4f}".format(matrix_2[0,2]), "{:.4f}".format(matrix_2[0,18]))
print("RMSE (eV):\t", "{:.4f}".format(matrix_2[0,3]), "{:.4f}".format(matrix_2[0,19]))

print("MAE (nm):\t","{:.4f}".format(matrix_2[0,8]), "{:.4f}".format(matrix_2[0,24]))
print("R2 (nm):\t", "{:.4f}".format(matrix_2[0,9]), "{:.4f}".format(matrix_2[0,25]))
print("RAE (nm):\t","{:.4f}".format(matrix_2[0,10]), "{:.4f}".format(matrix_2[0,26]))
print("RMSE (nm):\t", "{:.4f}".format(matrix_2[0,11]), "{:.4f}".format(matrix_2[0,27]))

print('\033[1m' + 'Absorbance FWHM (direct)' + '\033[0m')
print("MAE (eV): \t", "{:.4f}".format(matrix_3[0,0]), "{:.4f}".format(matrix_3[0,16]))
print("R2 (eV):\t", "{:.4f}".format(matrix_3[0,1]), "{:.4f}".format(matrix_3[0,17]))
print("RAE (eV):\t", "{:.4f}".format(matrix_3[0,2]), "{:.4f}".format(matrix_3[0,18]))
print("RMSE (eV):\t", "{:.4f}".format(matrix_3[0,3]), "{:.4f}".format(matrix_3[0,19]))

print("MAE (nm):\t","{:.4f}".format(matrix_3[0,8]), "{:.4f}".format(matrix_3[0,24]))
print("R2 (nm):\t", "{:.4f}".format(matrix_3[0,9]), "{:.4f}".format(matrix_3[0,25]))
print("RAE (nm):\t","{:.4f}".format(matrix_3[0,10]), "{:.4f}".format(matrix_3[0,26]))
print("RMSE (nm):\t", "{:.4f}".format(matrix_3[0,11]), "{:.4f}".format(matrix_3[0,27]))

print('\033[1m' + 'Absorbance FWHM (cascade)' + '\033[0m')
print("MAE (eV): \t", "{:.4f}".format(matrix_4[0,0]), "{:.4f}".format(matrix_4[0,16]))
print("R2 (eV):\t", "{:.4f}".format(matrix_4[0,1]), "{:.4f}".format(matrix_4[0,17]))
print("RAE (eV):\t", "{:.4f}".format(matrix_4[0,2]), "{:.4f}".format(matrix_4[0,18]))
print("RMSE (eV):\t", "{:.4f}".format(matrix_4[0,3]), "{:.4f}".format(matrix_4[0,19]))

print("MAE (nm):\t","{:.4f}".format(matrix_4[0,8]), "{:.4f}".format(matrix_4[0,24]))
print("R2 (nm):\t", "{:.4f}".format(matrix_4[0,9]), "{:.4f}".format(matrix_4[0,25]))
print("RAE (nm):\t","{:.4f}".format(matrix_4[0,10]), "{:.4f}".format(matrix_4[0,26]))
print("RMSE (nm):\t", "{:.4f}".format(matrix_4[0,11]), "{:.4f}".format(matrix_4[0,27]))
# Out:
# Model without Dropout at Inference
# Absorbance Peak
# MAE (eV): 	 0.0191 0.0023
# R2 (eV):	 0.9703 0.0070
# RAE (eV):	 0.1502 0.0192
# RMSE (eV):	 0.0258 0.0029
# MAE (nm):	 4.3621 0.4664
# R2 (nm):	 0.9689 0.0071
# RAE (nm):	 0.1524 0.0193
# RMSE (nm):	 5.8758 0.5976
# Absorbance FWHM (direct)
# MAE (eV): 	 0.0091 0.0015
# R2 (eV):	 0.5644 0.1082
# RAE (eV):	 0.5681 0.0828
# RMSE (eV):	 0.0135 0.0018
# MAE (nm):	 2.2591 0.3373
# R2 (nm):	 0.6472 0.0866
# RAE (nm):	 0.5190 0.0708
# RMSE (nm):	 3.2950 0.4506
# Absorbance FWHM (cascade)
# MAE (eV): 	 0.0073 0.0007
# R2 (eV):	 0.6942 0.0747
# RAE (eV):	 0.4588 0.0484
# RMSE (eV):	 0.0113 0.0013
# MAE (nm):	 1.8344 0.1709
# R2 (nm):	 0.7531 0.0739
# RAE (nm):	 0.4234 0.0520
# RMSE (nm):	 2.7256 0.2683

# %%
print('\033[1m' + 'Model with Dropout at Inference' + '\033[0m')
print('\033[1m' + 'Absorbance Peak' + '\033[0m')
print("MAE (eV): \t", "{:.4f}".format(matrix_2[0,4]), "{:.4f}".format(matrix_2[0,20]))
print("R2 (eV):\t", "{:.4f}".format(matrix_2[0,5]), "{:.4f}".format(matrix_2[0,21]))
print("RAE (eV):\t", "{:.4f}".format(matrix_2[0,6]), "{:.4f}".format(matrix_2[0,22]))
print("RMSE (eV):\t", "{:.4f}".format(matrix_2[0,7]), "{:.4f}".format(matrix_2[0,23]))

print("MAE (nm):\t","{:.4f}".format(matrix_2[0,12]), "{:.4f}".format(matrix_2[0,28]))
print("R2 (nm):\t", "{:.4f}".format(matrix_2[0,13]), "{:.4f}".format(matrix_2[0,29]))
print("RAE (nm):\t","{:.4f}".format(matrix_2[0,14]), "{:.4f}".format(matrix_2[0,30]))
print("RMSE (nm):\t", "{:.4f}".format(matrix_2[0,15]), "{:.4f}".format(matrix_2[0,31]))

print('\033[1m' + 'Absorbance FWHM (direct)' + '\033[0m')
print("MAE (eV): \t", "{:.4f}".format(matrix_3[0,4]), "{:.4f}".format(matrix_3[0,20]))
print("R2 (eV):\t", "{:.4f}".format(matrix_3[0,5]), "{:.4f}".format(matrix_3[0,21]))
print("RAE (eV):\t", "{:.4f}".format(matrix_3[0,6]), "{:.4f}".format(matrix_3[0,22]))
print("RMSE (eV):\t", "{:.4f}".format(matrix_3[0,7]), "{:.4f}".format(matrix_3[0,23]))

print("MAE (nm):\t","{:.4f}".format(matrix_3[0,12]), "{:.4f}".format(matrix_3[0,28]))
print("R2 (nm):\t", "{:.4f}".format(matrix_3[0,13]), "{:.4f}".format(matrix_3[0,29]))
print("RAE (nm):\t","{:.4f}".format(matrix_3[0,14]), "{:.4f}".format(matrix_3[0,30]))
print("RMSE (nm):\t", "{:.4f}".format(matrix_3[0,15]), "{:.4f}".format(matrix_3[0,31]))
print('\033[1m' + 'Absorbance FWHM (cascade)' + '\033[0m')
print("MAE (eV): \t", "{:.4f}".format(matrix_4[0,4]), "{:.4f}".format(matrix_4[0,20]))
print("R2 (eV):\t", "{:.4f}".format(matrix_4[0,5]), "{:.4f}".format(matrix_4[0,21]))
print("RAE (eV):\t", "{:.4f}".format(matrix_4[0,6]), "{:.4f}".format(matrix_4[0,22]))
print("RMSE (eV):\t", "{:.4f}".format(matrix_4[0,7]), "{:.4f}".format(matrix_4[0,23]))

print("MAE (nm):\t","{:.4f}".format(matrix_4[0,12]), "{:.4f}".format(matrix_4[0,28]))
print("R2 (nm):\t", "{:.4f}".format(matrix_4[0,13]), "{:.4f}".format(matrix_4[0,29]))
print("RAE (nm):\t","{:.4f}".format(matrix_4[0,14]), "{:.4f}".format(matrix_4[0,30]))
print("RMSE (nm):\t", "{:.4f}".format(matrix_4[0,15]), "{:.4f}".format(matrix_4[0,31]))
# Out:
# Model with Dropout at Inference
# Absorbance Peak
# MAE (eV): 	 0.0190 0.0023
# R2 (eV):	 0.9710 0.0072
# RAE (eV):	 0.1490 0.0201
# RMSE (eV):	 0.0255 0.0028
# MAE (nm):	 4.3289 0.4792
# R2 (nm):	 0.9695 0.0074
# RAE (nm):	 0.1513 0.0201
# RMSE (nm):	 5.8096 0.5952
# Absorbance FWHM (direct)
# MAE (eV): 	 0.0092 0.0014
# R2 (eV):	 0.5658 0.1069
# RAE (eV):	 0.5702 0.0793
# RMSE (eV):	 0.0134 0.0018
# MAE (nm):	 2.2639 0.3214
# R2 (nm):	 0.6476 0.0856
# RAE (nm):	 0.5202 0.0680
# RMSE (nm):	 3.2936 0.4395
# Absorbance FWHM (cascade)
# MAE (eV): 	 0.0074 0.0006
# R2 (eV):	 0.6994 0.0706
# RAE (eV):	 0.4599 0.0466
# RMSE (eV):	 0.0112 0.0012
# MAE (nm):	 1.8386 0.1598
# R2 (nm):	 0.7563 0.0711
# RAE (nm):	 0.4245 0.0505
# RMSE (nm):	 2.7104 0.2545

# %%
np.savetxt("NN+MMCN_PL_Val_peak.csv", matrix, delimiter=",")
np.savetxt("NN+MMCN_PL_Val_fwhm.csv", matrix_fwhm, delimiter=",")
np.savetxt("NN+MMCN_PL_Val_cascade.csv", matrix_cascade, delimiter=",")
