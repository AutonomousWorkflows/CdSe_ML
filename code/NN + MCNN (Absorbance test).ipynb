# %%
import pandas as pd
import numpy as np
import keras
import scipy
import matplotlib.pyplot as plt
from numpy import mean
from numpy import std
from sklearn.model_selection import GroupKFold
from sklearn import linear_model
from lineartree import RandomForestRegressor
from sklearn import metrics
from scipy.signal import savgol_filter
from keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from scikeras.wrappers import KerasRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
from numpy.random import seed
seed(1)
from tensorflow.keras.utils import set_random_seed
set_random_seed(2)

# %%
def rae(actual, predicted):
    actual = np.asarray(actual).reshape(-1,1)
    predicted = np.asarray(predicted).reshape(-1,1)
    numerator = np.sum(np.abs(predicted - actual))
    denominator = np.sum(np.abs(np.mean(actual) - actual))
    return numerator / denominator

# %%
def peak_eV_nm(peak_eV):
    peak_eV = np.asarray(peak_eV).reshape(-1,1)
    return 1239.84193/peak_eV

# %%
def FWHM_eV_nm(peak_eV,fwhm_eV):
    peak_eV = np.asarray(peak_eV).reshape(-1,1)
    fwhm_eV = np.asarray(fwhm_eV).reshape(-1,1)
    return  2*(1239.84193/(peak_eV-fwhm_eV/2) - 1239.84193/(peak_eV))

# %%
def predict_dist(X, model, num_samples):
    preds = [model(X, training=True) for _ in range(num_samples)]
    return np.hstack(preds)

# %%
def predict_point(X, model, num_samples):
    pred_dist = predict_dist(X, model, num_samples)
    return pred_dist.mean(axis=1)

# %%
def predict_stdev(X, model, num_samples):
    pred_dist = predict_dist(X, model, num_samples)
    return pred_dist.std(axis=1)

# %%
#Define models

initializer = keras.initializers.HeNormal(seed=1)
opt = keras.optimizers.Adam(learning_rate=0.001)

model_peak = keras.models.Sequential()
model_peak.add(Dense(5, input_shape=(5,), kernel_initializer=initializer, activation='relu'))
model_peak.add(Dense(50,  activation='relu'))
model_peak.add(keras.layers.Dropout(0.1))
model_peak.add(Dense(50,  activation='relu'))
model_peak.add(keras.layers.Dropout(0.1))
model_peak.add(Dense(1, kernel_initializer=initializer))
# Compile model
model_peak.compile(loss='mean_squared_error', optimizer= opt)

model_fwhm = keras.models.Sequential()
model_fwhm.add(Dense(5, input_shape=(5,), kernel_initializer=initializer, activation='relu'))
model_fwhm.add(Dense(50,  activation='relu'))
model_fwhm.add(keras.layers.Dropout(0.1))
model_fwhm.add(Dense(50,  activation='relu'))
model_fwhm.add(keras.layers.Dropout(0.1))
model_fwhm.add(Dense(1, kernel_initializer=initializer))
# Compile model
model_fwhm.compile(loss='mean_squared_error', optimizer= opt)

model_cascade = keras.models.Sequential()
model_cascade.add(Dense(6, input_shape=(6,), kernel_initializer=initializer, activation='relu'))
model_cascade.add(Dense(50,  activation='relu'))
model_cascade.add(keras.layers.Dropout(0.1))
model_cascade.add(Dense(50,  activation='relu'))
model_cascade.add(keras.layers.Dropout(0.1))
model_cascade.add(Dense(1, kernel_initializer=initializer))
# Compile model
model_cascade.compile(loss='mean_squared_error', optimizer= opt)

# %%
# Train model on entire dataset (Absorbance)
# load dataset into Pandas DataFrame (cleaned UV data)
df = pd.read_csv('CdSe UV Train Val.csv')

#normalize input and output data
min_params = pd.Series([0, 0, 3, 200, 0, 400, 15, 1239.84193/620, 0.05], index =['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV'])
max_params = pd.Series([50, 50, 150, 310, 600, 620, 80, 1239.84193/400, 0.4], index =['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV'])
df[['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV']] = (df[['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV']] - min_params) / (max_params- min_params)

X = df[['OA_Cd_ratio','T_reactor','Cd_mM','Se_mM','t_s']]
X2 = df[['OA_Cd_ratio','T_reactor','Cd_mM','Se_mM','t_s','Peak_eV']]
y = df['Peak_eV']
z = df['FWHM_eV']

matrix = np.zeros([1,8])
matrix_fwhm = np.zeros([1,8])
matrix_cascade = np.zeros([1,8])

#Separate out training and test sets (in this case they are the same)
X_train = X
X2_train = X2
y_train = y
z_train = z
X_test = X
X2_test = X2
y_test = y
z_test = z
j=0

#Initialize with fixed weights
model_peak.load_weights('initialize_weights3.h5')
model_fwhm.load_weights('initialize_weights3.h5')
model_cascade.load_weights('initialize_weights4.h5')

#Train models
#prediction for Peak
model_peak.fit(X_train, y_train, epochs=300, validation_data=(X_test, y_test),verbose = 1, use_multiprocessing=False, workers = 100)
y_pred = model_peak.predict(X_test)
#prediction for FWHM (direct)
model_fwhm.fit(X_train, z_train, epochs=300, validation_data=(X_test, z_test),verbose = 1, use_multiprocessing=False, workers = 100)
y_pred_fwhm = model_fwhm.predict(X_test)
#prediction for FWHM (cascade)
model_cascade.fit(X2_train, z_train, epochs=300, validation_data=(X2_test, z_test),verbose = 1, use_multiprocessing=False, workers = 100)
X_test.insert(5, "Peak_eV", model_peak.predict(X_test), True)
y_pred_cascade = model_cascade.predict(X_test)

#errors in eV (normalized)
#UN-normalize eV predictions by scaling with ratio

ratio = (1239.84193/400 - 1239.84193/620)
ratio2 = 0.35
matrix[j,0] = metrics.mean_absolute_error(y_test, y_pred)*ratio
matrix[j,1] = metrics.r2_score(y_test, y_pred)
matrix[j,2] = rae(y_test, y_pred)
matrix[j,3] = ratio*np.sqrt(metrics.mean_squared_error(y_test, y_pred))

matrix_fwhm[j,0] = metrics.mean_absolute_error(z_test, y_pred_fwhm)*ratio2
matrix_fwhm[j,1] = metrics.r2_score(z_test, y_pred_fwhm)
matrix_fwhm[j,2] = rae(z_test, y_pred_fwhm)
matrix_fwhm[j,3] = ratio2*np.sqrt(metrics.mean_squared_error(z_test, y_pred_fwhm))

matrix_cascade[j,0] = metrics.mean_absolute_error(z_test, y_pred_cascade)*ratio2
matrix_cascade[j,1] = metrics.r2_score(z_test, y_pred_cascade)
matrix_cascade[j,2] = rae(z_test, y_pred_cascade)
matrix_cascade[j,3] = ratio2*np.sqrt(metrics.mean_squared_error(z_test, y_pred_cascade))

#errors in nm
#UNnormalize the data first
y_test = y_test*(1239.84193/400 - 1239.84193/620)+1239.84193/620
y_pred = y_pred*(1239.84193/400 - 1239.84193/620)+1239.84193/620
z_test = z_test*(0.35)+0.05
y_pred_fwhm = y_pred_fwhm*(0.35)+0.05
y_pred_cascade = y_pred_cascade*(0.35)+0.05

#Calculate data in nm and eV
matrix[j,4] = metrics.mean_absolute_error(peak_eV_nm(y_test), peak_eV_nm(y_pred))
matrix[j,5] = metrics.r2_score(peak_eV_nm(y_test), peak_eV_nm(y_pred))
matrix[j,6] = rae(peak_eV_nm(y_test), peak_eV_nm(y_pred))
matrix[j,7] = np.sqrt(metrics.mean_squared_error(peak_eV_nm(y_test), peak_eV_nm(y_pred)))

matrix_fwhm[j,4] = metrics.mean_absolute_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm))
matrix_fwhm[j,5] = metrics.r2_score(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm))
matrix_fwhm[j,6] = rae(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm))
matrix_fwhm[j,7] = np.sqrt(metrics.mean_squared_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm)))

matrix_cascade[j,4] = metrics.mean_absolute_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade))
matrix_cascade[j,5] = metrics.r2_score(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade))
matrix_cascade[j,6] = rae(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade))
matrix_cascade[j,7] = np.sqrt(metrics.mean_squared_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade)))

np.set_printoptions(precision=5, threshold=5, edgeitems=4, suppress=True)

print('\033[1m' + 'Absorption Peak/FWHM Training Accuracy (no dropout at inference)' + '\033[0m')
print('\033[1m' + 'Absorbance Peak' + '\033[0m')
print("MAE (eV):\t", "{:.4f}".format(matrix[0,0]))
print("R2 (eV):\t", "{:.4f}".format(matrix[0,1]))
print("RAE (eV):\t", "{:.4f}".format(matrix[0,2]))
print("RMSE (eV):\t", "{:.4f}".format(matrix[0,3]))
print("MAE (nm):\t","{:.4f}".format(matrix[0,4]))
print("R2 (nm):\t", "{:.4f}".format(matrix[0,5]))
print("RAE (nm):\t","{:.4f}".format(matrix[0,6]))
print("RMSE (nm):\t", "{:.4f}".format(matrix[0,7]))

print('\033[1m' + 'Absorbance FWHM (direct)' + '\033[0m')
print("MAE (eV):\t", "{:.4f}".format(matrix_fwhm[0,0]))
print("R2 (eV):\t", "{:.4f}".format(matrix_fwhm[0,1]))
print("RAE (eV):\t", "{:.4f}".format(matrix_fwhm[0,2]))
print("RMSE (eV):\t", "{:.4f}".format(matrix_fwhm[0,3]))
print("MAE (nm):\t","{:.4f}".format(matrix_fwhm[0,4]))
print("R2 (nm):\t", "{:.4f}".format(matrix_fwhm[0,5]))
print("RAE (nm):\t","{:.4f}".format(matrix_fwhm[0,6]))
print("RMSE (nm):\t", "{:.4f}".format(matrix_fwhm[0,7]))

print('\033[1m' + 'Absorbance FWHM (cascade)' + '\033[0m')
print("MAE (eV):\t", "{:.4f}".format(matrix_cascade[0,0]))
print("R2 (eV):\t", "{:.4f}".format(matrix_cascade[0,1]))
print("RAE (eV):\t", "{:.4f}".format(matrix_cascade[0,2]))
print("RMSE (eV):\t", "{:.4f}".format(matrix_cascade[0,3]))
print("MAE (nm):\t","{:.4f}".format(matrix_cascade[0,4]))
print("R2 (nm):\t", "{:.4f}".format(matrix_cascade[0,5]))
print("RAE (nm):\t","{:.4f}".format(matrix_cascade[0,6]))
print("RMSE (nm):\t", "{:.4f}".format(matrix_cascade[0,7]))

# serialize weights to HDF5
#model_peak.save_weights("Abs_peak.h5")
#model_fwhm.save_weights("Abs_fwhm.h5")
#model_cascade.save_weights("Abs_cascade.h5")
# Out:
# Epoch 1/300
# 155/155 [==============================] - 1s 3ms/step - loss: 0.0352 - val_loss: 0.0101
# Epoch 2/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0107 - val_loss: 0.0058
# Epoch 3/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.0041
# Epoch 4/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0035
# Epoch 5/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0034
# Epoch 6/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0040
# Epoch 7/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0031
# Epoch 8/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0042 - val_loss: 0.0032
# Epoch 9/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0029
# Epoch 10/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0040 - val_loss: 0.0030
# Epoch 11/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0028
# Epoch 12/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0036 - val_loss: 0.0026
# Epoch 13/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0036 - val_loss: 0.0027
# Epoch 14/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0035 - val_loss: 0.0027
# Epoch 15/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0034 - val_loss: 0.0025
# Epoch 16/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0034 - val_loss: 0.0024
# Epoch 17/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0031 - val_loss: 0.0024
# Epoch 18/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0031 - val_loss: 0.0022
# Epoch 19/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0020
# Epoch 20/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 21/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0023 - val_loss: 0.0016
# Epoch 22/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 23/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 24/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 25/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 26/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 27/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 28/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 29/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 30/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 31/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 32/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 9.8927e-04
# Epoch 33/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 9.9353e-04
# Epoch 34/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 9.8982e-04
# Epoch 35/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 9.7472e-04
# Epoch 36/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 9.3985e-04
# Epoch 37/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 9.2145e-04
# Epoch 38/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 8.8320e-04
# Epoch 39/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 9.2711e-04
# Epoch 40/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 8.8220e-04
# Epoch 41/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 8.5077e-04
# Epoch 42/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 9.3186e-04
# Epoch 43/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 8.1161e-04
# Epoch 44/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 45/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 7.6860e-04
# Epoch 46/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 8.1778e-04
# Epoch 47/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 7.5370e-04
# Epoch 48/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 7.8708e-04
# Epoch 49/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 6.7644e-04
# Epoch 50/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 7.8025e-04
# Epoch 51/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 7.0844e-04
# Epoch 52/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 7.2215e-04
# Epoch 53/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 7.9951e-04
# Epoch 54/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 7.2957e-04
# Epoch 55/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 6.6792e-04
# Epoch 56/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 8.3730e-04
# Epoch 57/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 7.6812e-04
# Epoch 58/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 8.6442e-04
# Epoch 59/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 6.8455e-04
# Epoch 60/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 6.2911e-04
# Epoch 61/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 6.0114e-04
# Epoch 62/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 9.9586e-04
# Epoch 63/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 5.9244e-04
# Epoch 64/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 5.7409e-04
# Epoch 65/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 6.7288e-04
# Epoch 66/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 6.5118e-04
# Epoch 67/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 7.2196e-04
# Epoch 68/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 6.4236e-04
# Epoch 69/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 7.0776e-04
# Epoch 70/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 6.0630e-04
# Epoch 71/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 6.5712e-04
# Epoch 72/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 6.2521e-04
# Epoch 73/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0010 - val_loss: 5.1689e-04
# Epoch 74/300
# 155/155 [==============================] - 0s 1ms/step - loss: 0.0010 - val_loss: 5.5555e-04
# Epoch 75/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 6.2964e-04
# Epoch 76/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0010 - val_loss: 7.1926e-04
# Epoch 77/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0010 - val_loss: 6.3410e-04
# Epoch 78/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0010 - val_loss: 6.2922e-04
# Epoch 79/300
# 155/155 [==============================] - 0s 2ms/step - loss: 9.8895e-04 - val_loss: 4.9709e-04
# Epoch 80/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0010 - val_loss: 5.9581e-04
# Epoch 81/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0010 - val_loss: 6.1916e-04
# Epoch 82/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0010 - val_loss: 5.8295e-04
# Epoch 83/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 5.5752e-04
# Epoch 84/300
# 155/155 [==============================] - 0s 2ms/step - loss: 9.6555e-04 - val_loss: 5.6737e-04
# Epoch 85/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0010 - val_loss: 5.7999e-04
# Epoch 86/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0010 - val_loss: 5.1940e-04
# Epoch 87/300
# 155/155 [==============================] - 0s 2ms/step - loss: 9.8263e-04 - val_loss: 5.4572e-04
# Epoch 88/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0010 - val_loss: 5.2628e-04
# Epoch 89/300
# 155/155 [==============================] - 0s 2ms/step - loss: 9.7461e-04 - val_loss: 6.5282e-04
# Epoch 90/300
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0010 - val_loss: 4.6594e-04
# Epoch 91/300
# 155/155 [==============================] - 0s 2ms/step - loss: 9.8265e-04 - val_loss: 6.1394e-04
# Epoch 92/300
# 155/155 [==============================] - 0s 2ms/step - loss: 9.9364e-04 - val_loss: 5.6607e-04
# Epoch 93/300
# 155/155 [==============================] - 0s 2ms/step - loss: 9.8660e-04 - val_loss: 4.9865e-04
# Epoch 94/300
# 155/155 [==============================] - 0s 2ms/step - loss: 9.5934e-04 - val_loss: 5.4871e-04
# Epoch 95/300
# 155/155 [==============================] - 0s 2ms/step - loss: 9.5331e-04 - val_loss: 4.9531e-04
# Epoch 96/300
# 155/155 [==============================] - 0s 2ms/step - loss: 9.9019e-04 - val_loss: 5.4938e-04
# Epoch 97/300
# 155/155 [==============================] - 0s 2ms/step - loss: 9.9135e-04 - val_loss: 5.2003e-04
# Epoch 98/300
# 155/155 [==============================] - 0s 2ms/step - loss: 9.8206e-04 - val_loss: 5.2455e-04
# Epoch 99/300
# 155/155 [==============================] - 0s 2ms/step - loss: 9.8480e-04 - val_loss: 4.9337e-04
# Epoch 100/300
# 155/155 [==============================] - 0s 2ms/step - loss: 9.3665e-04 - val_loss: 5.5120e-04
# Epoch 101/300
# 155/155 [==============================] - 0s 2ms/step - loss: 9.9347e-04 - val_loss: 5.8426e-04
# Epoch 102/300
# 155/155 [==============================] - 0s 2ms/step - loss: 9.2931e-04 - val_loss: 5.0442e-04
# Epoch 103/300
# 155/155 [==============================] - 0s 2ms/step - loss: 9.6813e-04 - val_loss: 5.3603e-04
# Epoch 104/300
# 155/155 [==============================] - 0s 2ms/step - loss: 9.4658e-04 - val_loss: 4.6203e-04
# Epoch 105/300
# 155/155 [==============================] - 0s 2ms/step - loss: 9
300
# 155/155 [==============================] - 0s 2ms/step - loss: 8.4546e-04 - val_loss: 6.6548e-04
# Epoch 206/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.5438e-04 - val_loss: 6.5126e-04
# Epoch 207/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.9529e-04 - val_loss: 7.0560e-04
# Epoch 208/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.5684e-04 - val_loss: 5.5307e-04
# Epoch 209/300
# 155/155 [==============================] - 0s 2ms/step - loss: 8.4405e-04 - val_loss: 7.2355e-04
# Epoch 210/300
# 155/155 [==============================] - 0s 2ms/step - loss: 8.0963e-04 - val_loss: 5.5867e-04
# Epoch 211/300
# 155/155 [==============================] - 0s 2ms/step - loss: 8.0026e-04 - val_loss: 5.7475e-04
# Epoch 212/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.9377e-04 - val_loss: 5.5510e-04
# Epoch 213/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.7259e-04 - val_loss: 6.1239e-04
# Epoch 214/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.9394e-04 - val_loss: 5.5895e-04
# Epoch 215/300
# 155/155 [==============================] - 0s 2ms/step - loss: 8.1435e-04 - val_loss: 6.0271e-04
# Epoch 216/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.7639e-04 - val_loss: 6.3906e-04
# Epoch 217/300
# 155/155 [==============================] - 0s 2ms/step - loss: 8.9224e-04 - val_loss: 6.8720e-04
# Epoch 218/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.6909e-04 - val_loss: 6.1504e-04
# Epoch 219/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.8989e-04 - val_loss: 5.5157e-04
# Epoch 220/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.1045e-04 - val_loss: 5.5145e-04
# Epoch 221/300
# 155/155 [==============================] - 0s 2ms/step - loss: 9.1869e-04 - val_loss: 5.6202e-04
# Epoch 222/300
# 155/155 [==============================] - 0s 2ms/step - loss: 8.3321e-04 - val_loss: 6.0196e-04
# Epoch 223/300
# 155/155 [==============================] - 0s 2ms/step - loss: 8.2421e-04 - val_loss: 5.7020e-04
# Epoch 224/300
# 155/155 [==============================] - 0s 2ms/step - loss: 8.0227e-04 - val_loss: 5.9631e-04
# Epoch 225/300
# 155/155 [==============================] - 0s 2ms/step - loss: 8.3366e-04 - val_loss: 8.2309e-04
# Epoch 226/300
# 155/155 [==============================] - 0s 2ms/step - loss: 8.7622e-04 - val_loss: 5.8739e-04
# Epoch 227/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.8502e-04 - val_loss: 5.6263e-04
# Epoch 228/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.7099e-04 - val_loss: 6.4684e-04
# Epoch 229/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.6350e-04 - val_loss: 6.1753e-04
# Epoch 230/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.6046e-04 - val_loss: 5.7715e-04
# Epoch 231/300
# 155/155 [==============================] - 0s 2ms/step - loss: 8.1833e-04 - val_loss: 5.4273e-04
# Epoch 232/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.4709e-04 - val_loss: 6.4284e-04
# Epoch 233/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.6152e-04 - val_loss: 7.8087e-04
# Epoch 234/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.6877e-04 - val_loss: 6.2767e-04
# Epoch 235/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.9423e-04 - val_loss: 5.7064e-04
# Epoch 236/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.9255e-04 - val_loss: 5.4888e-04
# Epoch 237/300
# 155/155 [==============================] - 0s 2ms/step - loss: 8.1004e-04 - val_loss: 9.2999e-04
# Epoch 238/300
# 155/155 [==============================] - 0s 2ms/step - loss: 8.3128e-04 - val_loss: 6.0285e-04
# Epoch 239/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.4604e-04 - val_loss: 5.7058e-04
# Epoch 240/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.7963e-04 - val_loss: 6.2186e-04
# Epoch 241/300
# 155/155 [==============================] - 0s 1ms/step - loss: 8.2651e-04 - val_loss: 7.0467e-04
# Epoch 242/300
# 155/155 [==============================] - 0s 2ms/step - loss: 8.4230e-04 - val_loss: 5.6742e-04
# Epoch 243/300
# 155/155 [==============================] - 0s 1ms/step - loss: 7.4535e-04 - val_loss: 5.1986e-04
# Epoch 244/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.4144e-04 - val_loss: 5.6619e-04
# Epoch 245/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.5628e-04 - val_loss: 5.4063e-04
# Epoch 246/300
# 155/155 [==============================] - 0s 1ms/step - loss: 7.4427e-04 - val_loss: 5.7065e-04
# Epoch 247/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.4692e-04 - val_loss: 5.6482e-04
# Epoch 248/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.5247e-04 - val_loss: 5.5558e-04
# Epoch 249/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.3494e-04 - val_loss: 5.1199e-04
# Epoch 250/300
# 155/155 [==============================] - 0s 2ms/step - loss: 8.0040e-04 - val_loss: 0.0012
# Epoch 251/300
# 155/155 [==============================] - 0s 2ms/step - loss: 8.9537e-04 - val_loss: 5.5462e-04
# Epoch 252/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.4807e-04 - val_loss: 5.3720e-04
# Epoch 253/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.4418e-04 - val_loss: 5.6780e-04
# Epoch 254/300
# 155/155 [==============================] - 0s 2ms/step - loss: 9.4217e-04 - val_loss: 6.4471e-04
# Epoch 255/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.3377e-04 - val_loss: 5.2905e-04
# Epoch 256/300
# 155/155 [==============================] - 0s 2ms/step - loss: 8.4448e-04 - val_loss: 5.3315e-04
# Epoch 257/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.3211e-04 - val_loss: 5.7139e-04
# Epoch 258/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.7626e-04 - val_loss: 6.5900e-04
# Epoch 259/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.3782e-04 - val_loss: 5.5512e-04
# Epoch 260/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.5302e-04 - val_loss: 5.8774e-04
# Epoch 261/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.9056e-04 - val_loss: 5.3524e-04
# Epoch 262/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.2347e-04 - val_loss: 5.6265e-04
# Epoch 263/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.4361e-04 - val_loss: 5.0538e-04
# Epoch 264/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.7769e-04 - val_loss: 5.3471e-04
# Epoch 265/300
# 155/155 [==============================] - 0s 2ms/step - loss: 8.0370e-04 - val_loss: 5.6296e-04
# Epoch 266/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.2533e-04 - val_loss: 5.7896e-04
# Epoch 267/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.9373e-04 - val_loss: 7.3121e-04
# Epoch 268/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.4495e-04 - val_loss: 5.3910e-04
# Epoch 269/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.6212e-04 - val_loss: 7.3266e-04
# Epoch 270/300
# 155/155 [==============================] - 0s 2ms/step - loss: 8.6114e-04 - val_loss: 5.7929e-04
# Epoch 271/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.6336e-04 - val_loss: 5.9180e-04
# Epoch 272/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.9429e-04 - val_loss: 6.4631e-04
# Epoch 273/300
# 155/155 [==============================] - 0s 2ms/step - loss: 8.2697e-04 - val_loss: 6.1966e-04
# Epoch 274/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.3116e-04 - val_loss: 5.7781e-04
# Epoch 275/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.3627e-04 - val_loss: 6.4423e-04
# Epoch 276/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.6248e-04 - val_loss: 4.8902e-04
# Epoch 277/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.5456e-04 - val_loss: 5.2144e-04
# Epoch 278/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.0223e-04 - val_loss: 5.5970e-04
# Epoch 279/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.6899e-04 - val_loss: 5.8701e-04
# Epoch 280/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.9761e-04 - val_loss: 5.6878e-04
# Epoch 281/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.4317e-04 - val_loss: 5.4353e-04
# Epoch 282/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.7474e-04 - val_loss: 5.7339e-04
# Epoch 283/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.5119e-04 - val_loss: 5.6787e-04
# Epoch 284/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.2616e-04 - val_loss: 5.6680e-04
# Epoch 285/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.4352e-04 - val_loss: 5.4558e-04
# Epoch 286/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.2121e-04 - val_loss: 5.9173e-04
# Epoch 287/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.3358e-04 - val_loss: 7.3933e-04
# Epoch 288/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.5557e-04 - val_loss: 5.5302e-04
# Epoch 289/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.0430e-04 - val_loss: 5.9895e-04
# Epoch 290/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.2340e-04 - val_loss: 5.1461e-04
# Epoch 291/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.1031e-04 - val_loss: 5.5416e-04
# Epoch 292/300
# 155/155 [==============================] - 0s 2ms/step - loss: 9.2841e-04 - val_loss: 5.6500e-04
# Epoch 293/300
# 155/155 [==============================] - 0s 2ms/step - loss: 8.1539e-04 - val_loss: 6.6425e-04
# Epoch 294/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.9578e-04 - val_loss: 5.2946e-04
# Epoch 295/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.4781e-04 - val_loss: 5.5053e-04
# Epoch 296/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.1317e-04 - val_loss: 7.0952e-04
# Epoch 297/300
# 155/155 [==============================] - 0s 2ms/step - loss: 9.8309e-04 - val_loss: 5.5546e-04
# Epoch 298/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.5558e-04 - val_loss: 5.8374e-04
# Epoch 299/300
# 155/155 [==============================] - 0s 2ms/step - loss: 7.2742e-04 - val_loss: 5.3001e-04
# Epoch 300/300
# 155/155 [==============================] - 0s 2ms/step - loss: 8.3015e-04 - val_loss: 5.2820e-04
# 155/155 [==============================] - 0s 620us/step
# 155/155 [==============================] - 0s 635us/step
# Absorption Peak/FWHM Training Accuracy (no dropout at inference)
# Absorbance Peak
# MAE (eV):	 0.0162
# R2 (eV):	 0.9853
# RAE (eV):	 0.1059
# RMSE (eV):	 0.0220
# MAE (nm):	 3.4929
# R2 (nm):	 0.9831
# RAE (nm):	 0.1096
# RMSE (nm):	 4.8668
# Absorbance FWHM (direct)
# MAE (eV):	 0.0069
# R2 (eV):	 0.8227
# RAE (eV):	 0.3500
# RMSE (eV):	 0.0106
# MAE (nm):	 1.6033
# R2 (nm):	 0.8523
# RAE (nm):	 0.3072
# RMSE (nm):	 2.4110
# Absorbance FWHM (cascade)
# MAE (eV):	 0.0059
# R2 (eV):	 0.8709
# RAE (eV):	 0.2969
# RMSE (eV):	 0.0090
# MAE (nm):	 1.3411
# R2 (nm):	 0.8936
# RAE (nm):	 0.2570
# RMSE (nm):	 2.0461

# %%
#Predictions with dropout

# load dataset into Pandas DataFrame (cleaned UV data)
df = pd.read_csv('CdSe UV Train Val.csv')

#normalize input and output data
min_params = pd.Series([0, 0, 3, 200, 0, 400, 15, 1239.84193/620, 0.05], index =['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV'])
max_params = pd.Series([50, 50, 150, 310, 600, 620, 80, 1239.84193/400, 0.4], index =['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV'])
df[['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV']] = (df[['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV']] - min_params) / (max_params- min_params)

X = df[['OA_Cd_ratio','T_reactor','Cd_mM','Se_mM','t_s']]
X2 = df[['OA_Cd_ratio','T_reactor','Cd_mM','Se_mM','t_s','Peak_eV']]
y = df['Peak_eV']
z = df['FWHM_eV']

matrix = np.zeros([1,8])
matrix_fwhm = np.zeros([1,8])
matrix_cascade = np.zeros([1,8])

#Separate out training and test sets (in this case they are the same)
X_train = X
X2_train = X2
y_train = y
z_train = z
X_test = X
y_test = y
z_test = z

X_test_t = K.constant(X_test)

#prediction for Peak
y_pred =  predict_point(X_test_t, model_peak, 1000)
#prediction for FWHM (direct)
y_pred_fwhm = predict_point(X_test_t, model_fwhm, 1000)
#prediction for FWHM (cascade)
X_test.insert(5, "Peak_eV", y_pred, True)
X_test_t = K.constant(X_test)
y_pred_cascade = predict_point(X_test_t, model_cascade, 1000)

#errors in eV (normalized)
#UN-normalize eV predictions by scaling with ratio

ratio = (1239.84193/400 - 1239.84193/620)
ratio2 = 0.35
matrix[j,0] = metrics.mean_absolute_error(y_test, y_pred)*ratio
matrix[j,1] = metrics.r2_score(y_test, y_pred)
matrix[j,2] = rae(y_test, y_pred)
matrix[j,3] = ratio*np.sqrt(metrics.mean_squared_error(y_test, y_pred))

matrix_fwhm[j,0] = metrics.mean_absolute_error(z_test, y_pred_fwhm)*ratio2
matrix_fwhm[j,1] = metrics.r2_score(z_test, y_pred_fwhm)
matrix_fwhm[j,2] = rae(z_test, y_pred_fwhm)
matrix_fwhm[j,3] = ratio2*np.sqrt(metrics.mean_squared_error(z_test, y_pred_fwhm))

matrix_cascade[j,0] = metrics.mean_absolute_error(z_test, y_pred_cascade)*ratio2
matrix_cascade[j,1] = metrics.r2_score(z_test, y_pred_cascade)
matrix_cascade[j,2] = rae(z_test, y_pred_cascade)
matrix_cascade[j,3] = ratio2*np.sqrt(metrics.mean_squared_error(z_test, y_pred_cascade))

#errors in nm
#UNnormalize the data first
y_test = y_test*(1239.84193/400 - 1239.84193/620)+1239.84193/620
y_pred = y_pred*(1239.84193/400 - 1239.84193/620)+1239.84193/620
z_test = z_test*(0.35)+0.05
y_pred_fwhm = y_pred_fwhm*(0.35)+0.05
y_pred_cascade = y_pred_cascade*(0.35)+0.05

#Calculate data in nm and eV
matrix[j,4] = metrics.mean_absolute_error(peak_eV_nm(y_test), peak_eV_nm(y_pred))
matrix[j,5] = metrics.r2_score(peak_eV_nm(y_test), peak_eV_nm(y_pred))
matrix[j,6] = rae(peak_eV_nm(y_test), peak_eV_nm(y_pred))
matrix[j,7] = np.sqrt(metrics.mean_squared_error(peak_eV_nm(y_test), peak_eV_nm(y_pred)))

matrix_fwhm[j,4] = metrics.mean_absolute_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm))
matrix_fwhm[j,5] = metrics.r2_score(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm))
matrix_fwhm[j,6] = rae(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm))
matrix_fwhm[j,7] = np.sqrt(metrics.mean_squared_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm)))

matrix_cascade[j,4] = metrics.mean_absolute_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade))
matrix_cascade[j,5] = metrics.r2_score(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade))
matrix_cascade[j,6] = rae(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade))
matrix_cascade[j,7] = np.sqrt(metrics.mean_squared_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade)))

np.set_printoptions(precision=5, threshold=5, edgeitems=4, suppress=True)

print('\033[1m' + 'Absorption Peak/FWHM Training Accuracy (with dropout at inference)' + '\033[0m')
print('\033[1m' + 'Absorbance Peak' + '\033[0m')
print("MAE (eV):\t", "{:.4f}".format(matrix[0,0]))
print("R2 (eV):\t", "{:.4f}".format(matrix[0,1]))
print("RAE (eV):\t", "{:.4f}".format(matrix[0,2]))
print("RMSE (eV):\t", "{:.4f}".format(matrix[0,3]))
print("MAE (nm):\t","{:.4f}".format(matrix[0,4]))
print("R2 (nm):\t", "{:.4f}".format(matrix[0,5]))
print("RAE (nm):\t","{:.4f}".format(matrix[0,6]))
print("RMSE (nm):\t", "{:.4f}".format(matrix[0,7]))

print('\033[1m' + 'Absorbance FWHM (direct)' + '\033[0m')
print("MAE (eV):\t", "{:.4f}".format(matrix_fwhm[0,0]))
print("R2 (eV):\t", "{:.4f}".format(matrix_fwhm[0,1]))
print("RAE (eV):\t", "{:.4f}".format(matrix_fwhm[0,2]))
print("RMSE (eV):\t", "{:.4f}".format(matrix_fwhm[0,3]))
print("MAE (nm):\t","{:.4f}".format(matrix_fwhm[0,4]))
print("R2 (nm):\t", "{:.4f}".format(matrix_fwhm[0,5]))
print("RAE (nm):\t","{:.4f}".format(matrix_fwhm[0,6]))
print("RMSE (nm):\t", "{:.4f}".format(matrix_fwhm[0,7]))

print('\033[1m' + 'Absorbance FWHM (cascade)' + '\033[0m')
print("MAE (eV):\t", "{:.4f}".format(matrix_cascade[0,0]))
print("R2 (eV):\t", "{:.4f}".format(matrix_cascade[0,1]))
print("RAE (eV):\t", "{:.4f}".format(matrix_cascade[0,2]))
print("RMSE (eV):\t", "{:.4f}".format(matrix_cascade[0,3]))
print("MAE (nm):\t","{:.4f}".format(matrix_cascade[0,4]))
print("R2 (nm):\t", "{:.4f}".format(matrix_cascade[0,5]))
print("RAE (nm):\t","{:.4f}".format(matrix_cascade[0,6]))
print("RMSE (nm):\t", "{:.4f}".format(matrix_cascade[0,7]))
# Out:
# Absorption Peak/FWHM Training Accuracy (with dropout at inference)
# Absorbance Peak
# MAE (eV):	 0.0153
# R2 (eV):	 0.9867
# RAE (eV):	 0.1002
# RMSE (eV):	 0.0210
# MAE (nm):	 3.3001
# R2 (nm):	 0.9850
# RAE (nm):	 0.1035
# RMSE (nm):	 4.5954
# Absorbance FWHM (direct)
# MAE (eV):	 0.0069
# R2 (eV):	 0.8231
# RAE (eV):	 0.3498
# RMSE (eV):	 0.0105
# MAE (nm):	 1.5789
# R2 (nm):	 0.8574
# RAE (nm):	 0.3025
# RMSE (nm):	 2.3692
# Absorbance FWHM (cascade)
# MAE (eV):	 0.0058
# R2 (eV):	 0.8718
# RAE (eV):	 0.2942
# RMSE (eV):	 0.0090
# MAE (nm):	 1.3304
# R2 (nm):	 0.8943
# RAE (nm):	 0.2549
# RMSE (nm):	 2.0394

# %%
# load dataset into Pandas DataFrame
# load dataset into Pandas DataFrame (cleaned PL data)
df = pd.read_csv('CdSe UV Train Val.csv')

#normalize input and output data
min_params = pd.Series([0, 0, 3, 200, 0, 400, 15, 1239.84193/620, 0.05], index =['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV'])
max_params = pd.Series([50, 50, 150, 310, 600, 620, 80, 1239.84193/400, 0.4], index =['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV'])
df[['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV']] = (df[['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV']] - min_params) / (max_params- min_params)

X = df[['OA_Cd_ratio','T_reactor','Cd_mM','Se_mM','t_s']]
X2 = df[['OA_Cd_ratio','T_reactor','Cd_mM','Se_mM','t_s','Peak_eV']]
y = df['Peak_eV']
z = df['FWHM_eV']

background = X.sample(n = 500)
background2 = X2.sample(n = 500)

# load dataset into Pandas DataFrame
test1 = pd.read_csv('testpoints1.csv')
test2 = pd.read_csv('testpoints2.csv')

test1 = test1[['OA_Cd_ratio','T_reactor','Cd_mM','Se_mM','t_s']]
test2 = test2[['OA_Cd_ratio','T_reactor','Cd_mM','Se_mM','t_s','Peak_eV']]

# %%
#SHAP on training data for Peak
import shap
explainer = shap.KernelExplainer(model_peak, background)
shap_values1 = explainer.shap_values(test1)
shap.summary_plot(shap_values1[0], test1)
shap.summary_plot(shap_values1, test1, plot_type="bar")
np.savetxt("NN_UV_peak_shap.csv", shap_values1[0], delimiter=",")
# Out:
# Using 500 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
#SHAP on training data for FWHM
explainer = shap.KernelExplainer(model_fwhm, background)
shap_values2 = explainer.shap_values(test1)
shap.summary_plot(shap_values2[0], test1)
shap.summary_plot(shap_values2, test1, plot_type="bar")
np.savetxt("NN_UV_fwhm_shap.csv", shap_values2[0], delimiter=",")
# Out:
# Using 500 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
#SHAP on training data for FWHM (cascade)
explainer = shap.KernelExplainer(model_cascade, background2)
shap_values3 = explainer.shap_values(test2)
shap.summary_plot(shap_values3[0], test2)
shap.summary_plot(shap_values3, test2, plot_type="bar")
np.savetxt("NN_UV_cascade_shap.csv", shap_values3[0], delimiter=",")
# Out:
# Using 500 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
#Test NN on interpolation without dropout, UV Peak, FWHM (eV)

#Test data set (interpolation)
df2 = pd.read_csv('CdSe UV Test (in).csv')
#normalize input and output data
min_params = pd.Series([0, 0, 3, 200, 0, 400, 15, 1239.84193/620, 0.05], index =['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV'])
max_params = pd.Series([50, 50, 150, 310, 600, 620, 80, 1239.84193/400, 0.4], index =['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV'])
df2[['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV']] = (df2[['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV']] - min_params) / (max_params- min_params)

X = df2[['OA_Cd_ratio','T_reactor','Cd_mM','Se_mM','t_s']]
y = df2['Peak_eV']
z = df2['FWHM_eV']

X_test = X
y_test = y
z_test = z


#prediction for Peak
y_pred = model_peak.predict(X_test)
#prediction for FWHM (direct)
y_pred_fwhm = model_fwhm.predict(X_test)
#prediction for FWHM (cascade)
X_test.insert(5, "Peak_eV", model_peak.predict(X_test), True)
y_pred_cascade = model_cascade.predict(X_test)


matrix = np.zeros([1,13])
matrix_fwhm = np.zeros([1,13])
matrix_cascade = np.zeros([1,14])

j=0

#errors in eV (normalized)
#UN-normalize eV predictions by scaling with ratio

ratio = (1239.84193/400 - 1239.84193/620)
ratio2 = 0.35
matrix[j,0] = metrics.mean_absolute_error(y_test, y_pred)*ratio
matrix[j,1] = metrics.r2_score(y_test, y_pred)
matrix[j,2] = rae(y_test, y_pred)
matrix[j,3] = ratio*np.sqrt(metrics.mean_squared_error(y_test, y_pred))

matrix_fwhm[j,0] = metrics.mean_absolute_error(z_test, y_pred_fwhm)*ratio2
matrix_fwhm[j,1] = metrics.r2_score(z_test, y_pred_fwhm)
matrix_fwhm[j,2] = rae(z_test, y_pred_fwhm)
matrix_fwhm[j,3] = ratio2*np.sqrt(metrics.mean_squared_error(z_test, y_pred_fwhm))

matrix_cascade[j,0] = metrics.mean_absolute_error(z_test, y_pred_cascade)*ratio2
matrix_cascade[j,1] = metrics.r2_score(z_test, y_pred_cascade)
matrix_cascade[j,2] = rae(z_test, y_pred_cascade)
matrix_cascade[j,3] = ratio2*np.sqrt(metrics.mean_squared_error(z_test, y_pred_cascade))

#errors in nm
#UNnormalize the data first
y_test = y_test*(1239.84193/400 - 1239.84193/620)+1239.84193/620
y_pred = y_pred*(1239.84193/400 - 1239.84193/620)+1239.84193/620
z_test = z_test*(0.35)+0.05
y_pred_fwhm = y_pred_fwhm*(0.35)+0.05
y_pred_cascade = y_pred_cascade*(0.35)+0.05

#Calculate data in nm and eV
matrix[j,4] = metrics.mean_absolute_error(peak_eV_nm(y_test), peak_eV_nm(y_pred))
matrix[j,5] = metrics.r2_score(peak_eV_nm(y_test), peak_eV_nm(y_pred))
matrix[j,6] = rae(peak_eV_nm(y_test), peak_eV_nm(y_pred))
matrix[j,7] = np.sqrt(metrics.mean_squared_error(peak_eV_nm(y_test), peak_eV_nm(y_pred)))

matrix_fwhm[j,4] = metrics.mean_absolute_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm))
matrix_fwhm[j,5] = metrics.r2_score(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm))
matrix_fwhm[j,6] = rae(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm))
matrix_fwhm[j,7] = np.sqrt(metrics.mean_squared_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm)))

matrix_cascade[j,4] = metrics.mean_absolute_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade))
matrix_cascade[j,5] = metrics.r2_score(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade))
matrix_cascade[j,6] = rae(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade))
matrix_cascade[j,7] = np.sqrt(metrics.mean_squared_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade)))

np.set_printoptions(precision=5, threshold=5, edgeitems=4, suppress=True)

print('\033[1m' + 'Absorption Peak/FWHM Interpolation (no dropout at inference)' + '\033[0m')
print('\033[1m' + 'Absorbance Peak' + '\033[0m')
print("MAE (eV):\t", "{:.4f}".format(matrix[0,0]))
print("R2 (eV):\t", "{:.4f}".format(matrix[0,1]))
print("RAE (eV):\t", "{:.4f}".format(matrix[0,2]))
print("RMSE (eV):\t", "{:.4f}".format(matrix[0,3]))
print("MAE (nm):\t","{:.4f}".format(matrix[0,4]))
print("R2 (nm):\t", "{:.4f}".format(matrix[0,5]))
print("RAE (nm):\t","{:.4f}".format(matrix[0,6]))
print("RMSE (nm):\t", "{:.4f}".format(matrix[0,7]))

print('\033[1m' + 'Absorbance FWHM (direct)' + '\033[0m')
print("MAE (eV):\t", "{:.4f}".format(matrix_fwhm[0,0]))
print("R2 (eV):\t", "{:.4f}".format(matrix_fwhm[0,1]))
print("RAE (eV):\t", "{:.4f}".format(matrix_fwhm[0,2]))
print("RMSE (eV):\t", "{:.4f}".format(matrix_fwhm[0,3]))
print("MAE (nm):\t","{:.4f}".format(matrix_fwhm[0,4]))
print("R2 (nm):\t", "{:.4f}".format(matrix_fwhm[0,5]))
print("RAE (nm):\t","{:.4f}".format(matrix_fwhm[0,6]))
print("RMSE (nm):\t", "{:.4f}".format(matrix_fwhm[0,7]))

print('\033[1m' + 'Absorbance FWHM (cascade)' + '\033[0m')
print("MAE (eV):\t", "{:.4f}".format(matrix_cascade[0,0]))
print("R2 (eV):\t", "{:.4f}".format(matrix_cascade[0,1]))
print("RAE (eV):\t", "{:.4f}".format(matrix_cascade[0,2]))
print("RMSE (eV):\t", "{:.4f}".format(matrix_cascade[0,3]))
print("MAE (nm):\t","{:.4f}".format(matrix_cascade[0,4]))
print("R2 (nm):\t", "{:.4f}".format(matrix_cascade[0,5]))
print("RAE (nm):\t","{:.4f}".format(matrix_cascade[0,6]))
print("RMSE (nm):\t", "{:.4f}".format(matrix_cascade[0,7]))

y_test = y_test.to_numpy().reshape(1,-1)
z_test = z_test.to_numpy().reshape(1,-1)
y_pred = y_pred.reshape(1,-1)
y_pred_fwhm = y_pred_fwhm.reshape(1,-1)
y_pred_cascade = y_pred_cascade.reshape(1,-1)

np.savetxt("NN_UV_in_test_peak.csv", np.vstack((y_test,y_pred)).T, delimiter=",")
np.savetxt("NN_UV_in_test_fwhm.csv", np.vstack((z_test,y_pred_fwhm)).T, delimiter=",")
np.savetxt("NN_UV_in_test_cascade.csv", np.vstack((z_test,y_pred_cascade)).T, delimiter=",")
# Out:
# 15/15 [==============================] - 0s 790us/step
# 15/15 [==============================] - 0s 715us/step
# 15/15 [==============================] - 0s 716us/step
# 15/15 [==============================] - 0s 855us/step
# Absorption Peak/FWHM Interpolation (no dropout at inference)
# Absorbance Peak
# MAE (eV):	 0.0266
# R2 (eV):	 0.9535
# RAE (eV):	 0.2019
# RMSE (eV):	 0.0341
# MAE (nm):	 5.6466
# R2 (nm):	 0.9539
# RAE (nm):	 0.2002
# RMSE (nm):	 7.1462
# Absorbance FWHM (direct)
# MAE (eV):	 0.0073
# R2 (eV):	 0.8329
# RAE (eV):	 0.3659
# RMSE (eV):	 0.0101
# MAE (nm):	 1.8633
# R2 (nm):	 0.8389
# RAE (nm):	 0.3456
# RMSE (nm):	 2.5305
# Absorbance FWHM (cascade)
# MAE (eV):	 0.0074
# R2 (eV):	 0.8192
# RAE (eV):	 0.3740
# RMSE (eV):	 0.0105
# MAE (nm):	 1.6583
# R2 (nm):	 0.8586
# RAE (nm):	 0.3075
# RMSE (nm):	 2.3713

# %%
#Test NN on interpolation with dropout, UV Peak, FWHM (eV)

#Test data set (interpolation)
df2 = pd.read_csv('CdSe UV Test (in).csv')
#normalize input and output data
min_params = pd.Series([0, 0, 3, 200, 0, 400, 15, 1239.84193/620, 0.05], index =['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV'])
max_params = pd.Series([50, 50, 150, 310, 600, 620, 80, 1239.84193/400, 0.4], index =['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV'])
df2[['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV']] = (df2[['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV']] - min_params) / (max_params- min_params)

X = df2[['OA_Cd_ratio','T_reactor','Cd_mM','Se_mM','t_s']]
y = df2['Peak_eV']
z = df2['FWHM_eV']

X_test = X
y_test = y
z_test = z

X_test_t = K.constant(X_test)

#prediction for Peak
y_pred =  predict_point(X_test_t, model_peak, 1000)
#prediction for FWHM (direct)
y_pred_fwhm = predict_point(X_test_t, model_fwhm, 1000)
#prediction for FWHM (cascade)
X_test.insert(5, "Peak_eV", y_pred, True)
X_test_t = K.constant(X_test)
y_pred_cascade = predict_point(X_test_t, model_cascade, 1000)

matrix = np.zeros([1,13])
matrix_fwhm = np.zeros([1,13])
matrix_cascade = np.zeros([1,14])

j=0

#errors in eV (normalized)
#UN-normalize eV predictions by scaling with ratio

ratio = (1239.84193/400 - 1239.84193/620)
ratio2 = 0.35
matrix[j,0] = metrics.mean_absolute_error(y_test, y_pred)*ratio
matrix[j,1] = metrics.r2_score(y_test, y_pred)
matrix[j,2] = rae(y_test, y_pred)
matrix[j,3] = ratio*np.sqrt(metrics.mean_squared_error(y_test, y_pred))

matrix_fwhm[j,0] = metrics.mean_absolute_error(z_test, y_pred_fwhm)*ratio2
matrix_fwhm[j,1] = metrics.r2_score(z_test, y_pred_fwhm)
matrix_fwhm[j,2] = rae(z_test, y_pred_fwhm)
matrix_fwhm[j,3] = ratio2*np.sqrt(metrics.mean_squared_error(z_test, y_pred_fwhm))

matrix_cascade[j,0] = metrics.mean_absolute_error(z_test, y_pred_cascade)*ratio2
matrix_cascade[j,1] = metrics.r2_score(z_test, y_pred_cascade)
matrix_cascade[j,2] = rae(z_test, y_pred_cascade)
matrix_cascade[j,3] = ratio2*np.sqrt(metrics.mean_squared_error(z_test, y_pred_cascade))

#errors in nm
#UNnormalize the data first
y_test = y_test*(1239.84193/400 - 1239.84193/620)+1239.84193/620
y_pred = y_pred*(1239.84193/400 - 1239.84193/620)+1239.84193/620
z_test = z_test*(0.35)+0.05
y_pred_fwhm = y_pred_fwhm*(0.35)+0.05
y_pred_cascade = y_pred_cascade*(0.35)+0.05

#Calculate data in nm and eV
matrix[j,4] = metrics.mean_absolute_error(peak_eV_nm(y_test), peak_eV_nm(y_pred))
matrix[j,5] = metrics.r2_score(peak_eV_nm(y_test), peak_eV_nm(y_pred))
matrix[j,6] = rae(peak_eV_nm(y_test), peak_eV_nm(y_pred))
matrix[j,7] = np.sqrt(metrics.mean_squared_error(peak_eV_nm(y_test), peak_eV_nm(y_pred)))

matrix_fwhm[j,4] = metrics.mean_absolute_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm))
matrix_fwhm[j,5] = metrics.r2_score(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm))
matrix_fwhm[j,6] = rae(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm))
matrix_fwhm[j,7] = np.sqrt(metrics.mean_squared_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm)))

matrix_cascade[j,4] = metrics.mean_absolute_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade))
matrix_cascade[j,5] = metrics.r2_score(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade))
matrix_cascade[j,6] = rae(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade))
matrix_cascade[j,7] = np.sqrt(metrics.mean_squared_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade)))

np.set_printoptions(precision=5, threshold=5, edgeitems=4, suppress=True)

print('\033[1m' + 'Absorption Peak/FWHM Interpolation (with dropout at inference)' + '\033[0m')
print('\033[1m' + 'Absorbance Peak' + '\033[0m')
print("MAE (eV):\t", "{:.4f}".format(matrix[0,0]))
print("R2 (eV):\t", "{:.4f}".format(matrix[0,1]))
print("RAE (eV):\t", "{:.4f}".format(matrix[0,2]))
print("RMSE (eV):\t", "{:.4f}".format(matrix[0,3]))
print("MAE (nm):\t","{:.4f}".format(matrix[0,4]))
print("R2 (nm):\t", "{:.4f}".format(matrix[0,5]))
print("RAE (nm):\t","{:.4f}".format(matrix[0,6]))
print("RMSE (nm):\t", "{:.4f}".format(matrix[0,7]))

print('\033[1m' + 'Absorbance FWHM (direct)' + '\033[0m')
print("MAE (eV):\t", "{:.4f}".format(matrix_fwhm[0,0]))
print("R2 (eV):\t", "{:.4f}".format(matrix_fwhm[0,1]))
print("RAE (eV):\t", "{:.4f}".format(matrix_fwhm[0,2]))
print("RMSE (eV):\t", "{:.4f}".format(matrix_fwhm[0,3]))
print("MAE (nm):\t","{:.4f}".format(matrix_fwhm[0,4]))
print("R2 (nm):\t", "{:.4f}".format(matrix_fwhm[0,5]))
print("RAE (nm):\t","{:.4f}".format(matrix_fwhm[0,6]))
print("RMSE (nm):\t", "{:.4f}".format(matrix_fwhm[0,7]))

print('\033[1m' + 'Absorbance FWHM (cascade)' + '\033[0m')
print("MAE (eV):\t", "{:.4f}".format(matrix_cascade[0,0]))
print("R2 (eV):\t", "{:.4f}".format(matrix_cascade[0,1]))
print("RAE (eV):\t", "{:.4f}".format(matrix_cascade[0,2]))
print("RMSE (eV):\t", "{:.4f}".format(matrix_cascade[0,3]))
print("MAE (nm):\t","{:.4f}".format(matrix_cascade[0,4]))
print("R2 (nm):\t", "{:.4f}".format(matrix_cascade[0,5]))
print("RAE (nm):\t","{:.4f}".format(matrix_cascade[0,6]))
print("RMSE (nm):\t", "{:.4f}".format(matrix_cascade[0,7]))

y_test = y_test.to_numpy().reshape(1,-1)
z_test = z_test.to_numpy().reshape(1,-1)
y_pred = y_pred.reshape(1,-1)
y_pred_fwhm = y_pred_fwhm.reshape(1,-1)
y_pred_cascade = y_pred_cascade.reshape(1,-1)

np.savetxt("MCNN_UV_in_test_peak.csv", np.vstack((y_test,y_pred)).T, delimiter=",")
np.savetxt("MCNN_UV_in_test_fwhm.csv", np.vstack((z_test,y_pred_fwhm)).T, delimiter=",")
np.savetxt("MCNN_UV_in_test_cascade.csv", np.vstack((z_test,y_pred_cascade)).T, delimiter=",")
# Out:
# Absorption Peak/FWHM Interpolation (with dropout at inference)
# Absorbance Peak
# MAE (eV):	 0.0246
# R2 (eV):	 0.9571
# RAE (eV):	 0.1864
# RMSE (eV):	 0.0328
# MAE (nm):	 5.1541
# R2 (nm):	 0.9587
# RAE (nm):	 0.1828
# RMSE (nm):	 6.7647
# Absorbance FWHM (direct)
# MAE (eV):	 0.0073
# R2 (eV):	 0.8326
# RAE (eV):	 0.3664
# RMSE (eV):	 0.0101
# MAE (nm):	 1.8236
# R2 (nm):	 0.8465
# RAE (nm):	 0.3382
# RMSE (nm):	 2.4704
# Absorbance FWHM (cascade)
# MAE (eV):	 0.0074
# R2 (eV):	 0.8268
# RAE (eV):	 0.3724
# RMSE (eV):	 0.0103
# MAE (nm):	 1.6296
# R2 (nm):	 0.8674
# RAE (nm):	 0.3022
# RMSE (nm):	 2.2958

# %%
#Test Linear model on extrapolation, UV Peak, FWHM (eV)

#Test data set (extrapolation)
df2 = pd.read_csv('CdSe UV Test (out).csv')
#normalize input and output data
min_params = pd.Series([0, 0, 3, 200, 0, 400, 15, 1239.84193/620, 0.05], index =['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV'])
max_params = pd.Series([50, 50, 150, 310, 600, 620, 80, 1239.84193/400, 0.4], index =['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV'])
df2[['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV']] = (df2[['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV']] - min_params) / (max_params- min_params)

X = df2[['OA_Cd_ratio','T_reactor','Cd_mM','Se_mM','t_s']]
y = df2['Peak_eV']
z = df2['FWHM_eV']

X_test = X
y_test = y
z_test = z

#prediction for Peak
y_pred = model_peak.predict(X_test)
#prediction for FWHM (direct)
y_pred_fwhm = model_fwhm.predict(X_test)
#prediction for FWHM (cascade)
X_test.insert(5, "Peak_eV", model_peak.predict(X_test), True)
y_pred_cascade = model_cascade.predict(X_test)

matrix = np.zeros([1,13])
matrix_fwhm = np.zeros([1,13])
matrix_cascade = np.zeros([1,14])

j=0

#errors in eV (normalized)
#UN-normalize eV predictions by scaling with ratio

ratio = (1239.84193/400 - 1239.84193/620)
ratio2 = 0.35
matrix[j,0] = metrics.mean_absolute_error(y_test, y_pred)*ratio
matrix[j,1] = metrics.r2_score(y_test, y_pred)
matrix[j,2] = rae(y_test, y_pred)
matrix[j,3] = ratio*np.sqrt(metrics.mean_squared_error(y_test, y_pred))

matrix_fwhm[j,0] = metrics.mean_absolute_error(z_test, y_pred_fwhm)*ratio2
matrix_fwhm[j,1] = metrics.r2_score(z_test, y_pred_fwhm)
matrix_fwhm[j,2] = rae(z_test, y_pred_fwhm)
matrix_fwhm[j,3] = ratio2*np.sqrt(metrics.mean_squared_error(z_test, y_pred_fwhm))

matrix_cascade[j,0] = metrics.mean_absolute_error(z_test, y_pred_cascade)*ratio2
matrix_cascade[j,1] = metrics.r2_score(z_test, y_pred_cascade)
matrix_cascade[j,2] = rae(z_test, y_pred_cascade)
matrix_cascade[j,3] = ratio2*np.sqrt(metrics.mean_squared_error(z_test, y_pred_cascade))

#errors in nm
#UNnormalize the data first
y_test = y_test*(1239.84193/400 - 1239.84193/620)+1239.84193/620
y_pred = y_pred*(1239.84193/400 - 1239.84193/620)+1239.84193/620
z_test = z_test*(0.35)+0.05
y_pred_fwhm = y_pred_fwhm*(0.35)+0.05
y_pred_cascade = y_pred_cascade*(0.35)+0.05

#Calculate data in nm and eV
matrix[j,4] = metrics.mean_absolute_error(peak_eV_nm(y_test), peak_eV_nm(y_pred))
matrix[j,5] = metrics.r2_score(peak_eV_nm(y_test), peak_eV_nm(y_pred))
matrix[j,6] = rae(peak_eV_nm(y_test), peak_eV_nm(y_pred))
matrix[j,7] = np.sqrt(metrics.mean_squared_error(peak_eV_nm(y_test), peak_eV_nm(y_pred)))

matrix_fwhm[j,4] = metrics.mean_absolute_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm))
matrix_fwhm[j,5] = metrics.r2_score(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm))
matrix_fwhm[j,6] = rae(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm))
matrix_fwhm[j,7] = np.sqrt(metrics.mean_squared_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm)))

matrix_cascade[j,4] = metrics.mean_absolute_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade))
matrix_cascade[j,5] = metrics.r2_score(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade))
matrix_cascade[j,6] = rae(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade))
matrix_cascade[j,7] = np.sqrt(metrics.mean_squared_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade)))

np.set_printoptions(precision=5, threshold=5, edgeitems=4, suppress=True)

print('\033[1m' + 'Absorption Peak/FWHM Extrapolation (no dropout at inference)' + '\033[0m')
print('\033[1m' + 'Absorbance Peak' + '\033[0m')
print("MAE (eV):\t", "{:.4f}".format(matrix[0,0]))
print("R2 (eV):\t", "{:.4f}".format(matrix[0,1]))
print("RAE (eV):\t", "{:.4f}".format(matrix[0,2]))
print("RMSE (eV):\t", "{:.4f}".format(matrix[0,3]))
print("MAE (nm):\t","{:.4f}".format(matrix[0,4]))
print("R2 (nm):\t", "{:.4f}".format(matrix[0,5]))
print("RAE (nm):\t","{:.4f}".format(matrix[0,6]))
print("RMSE (nm):\t", "{:.4f}".format(matrix[0,7]))

print('\033[1m' + 'Absorbance FWHM (direct)' + '\033[0m')
print("MAE (eV):\t", "{:.4f}".format(matrix_fwhm[0,0]))
print("R2 (eV):\t", "{:.4f}".format(matrix_fwhm[0,1]))
print("RAE (eV):\t", "{:.4f}".format(matrix_fwhm[0,2]))
print("RMSE (eV):\t", "{:.4f}".format(matrix_fwhm[0,3]))
print("MAE (nm):\t","{:.4f}".format(matrix_fwhm[0,4]))
print("R2 (nm):\t", "{:.4f}".format(matrix_fwhm[0,5]))
print("RAE (nm):\t","{:.4f}".format(matrix_fwhm[0,6]))
print("RMSE (nm):\t", "{:.4f}".format(matrix_fwhm[0,7]))

print('\033[1m' + 'Absorbance FWHM (cascade)' + '\033[0m')
print("MAE (eV):\t", "{:.4f}".format(matrix_cascade[0,0]))
print("R2 (eV):\t", "{:.4f}".format(matrix_cascade[0,1]))
print("RAE (eV):\t", "{:.4f}".format(matrix_cascade[0,2]))
print("RMSE (eV):\t", "{:.4f}".format(matrix_cascade[0,3]))
print("MAE (nm):\t","{:.4f}".format(matrix_cascade[0,4]))
print("R2 (nm):\t", "{:.4f}".format(matrix_cascade[0,5]))
print("RAE (nm):\t","{:.4f}".format(matrix_cascade[0,6]))
print("RMSE (nm):\t", "{:.4f}".format(matrix_cascade[0,7]))

y_test = y_test.to_numpy().reshape(1,-1)
z_test = z_test.to_numpy().reshape(1,-1)
y_pred = y_pred.reshape(1,-1)
y_pred_fwhm = y_pred_fwhm.reshape(1,-1)
y_pred_cascade = y_pred_cascade.reshape(1,-1)

np.savetxt("NN_UV_out_test_peak.csv", np.vstack((y_test,y_pred)).T, delimiter=",")
np.savetxt("NN_UV_out_test_fwhm.csv", np.vstack((z_test,y_pred_fwhm)).T, delimiter=",")
np.savetxt("NN_UV_out_test_cascade.csv", np.vstack((z_test,y_pred_cascade)).T, delimiter=",")
# Out:
# 12/12 [==============================] - 0s 840us/step
# 12/12 [==============================] - 0s 906us/step
# 12/12 [==============================] - 0s 0s/step
# 12/12 [==============================] - 0s 0s/step
# Absorption Peak/FWHM Extrapolation (no dropout at inference)
# Absorbance Peak
# MAE (eV):	 0.0502
# R2 (eV):	 0.8775
# RAE (eV):	 0.3034
# RMSE (eV):	 0.0696
# MAE (nm):	 11.0949
# R2 (nm):	 0.8408
# RAE (nm):	 0.3133
# RMSE (nm):	 16.7063
# Absorbance FWHM (direct)
# MAE (eV):	 0.0274
# R2 (eV):	 -0.5143
# RAE (eV):	 1.0133
# RMSE (eV):	 0.0388
# MAE (nm):	 6.4106
# R2 (nm):	 -3.0730
# RAE (nm):	 1.4200
# RMSE (nm):	 10.6111
# Absorbance FWHM (cascade)
# MAE (eV):	 0.0286
# R2 (eV):	 -0.7298
# RAE (eV):	 1.0600
# RMSE (eV):	 0.0415
# MAE (nm):	 7.0510
# R2 (nm):	 -3.6140
# RAE (nm):	 1.5619
# RMSE (nm):	 11.2939

# %%
#Test NN on interpolation with dropout, UV Peak, FWHM (eV)

#Test data set (interpolation)
df2 = pd.read_csv('CdSe UV Test (out).csv')
#normalize input and output data
min_params = pd.Series([0, 0, 3, 200, 0, 400, 15, 1239.84193/620, 0.05], index =['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV'])
max_params = pd.Series([50, 50, 150, 310, 600, 620, 80, 1239.84193/400, 0.4], index =['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV'])
df2[['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV']] = (df2[['Cd_mM', 'Se_mM', 'OA_Cd_ratio', 'T_reactor', 't_s','Peak_nm','FWHM_nm','Peak_eV','FWHM_eV']] - min_params) / (max_params- min_params)

X = df2[['OA_Cd_ratio','T_reactor','Cd_mM','Se_mM','t_s']]
y = df2['Peak_eV']
z = df2['FWHM_eV']

X_test = X
y_test = y
z_test = z

X_test_t = K.constant(X_test)

#prediction for Peak
y_pred =  predict_point(X_test_t, model_peak, 1000)
#prediction for FWHM (direct)
y_pred_fwhm = predict_point(X_test_t, model_fwhm, 1000)
#prediction for FWHM (cascade)
X_test.insert(5, "Peak_eV", y_pred, True)
X_test_t = K.constant(X_test)
y_pred_cascade = predict_point(X_test_t, model_cascade, 1000)

matrix = np.zeros([1,13])
matrix_fwhm = np.zeros([1,13])
matrix_cascade = np.zeros([1,14])

j=0

#errors in eV (normalized)
#UN-normalize eV predictions by scaling with ratio

ratio = (1239.84193/400 - 1239.84193/620)
ratio2 = 0.35
matrix[j,0] = metrics.mean_absolute_error(y_test, y_pred)*ratio
matrix[j,1] = metrics.r2_score(y_test, y_pred)
matrix[j,2] = rae(y_test, y_pred)
matrix[j,3] = ratio*np.sqrt(metrics.mean_squared_error(y_test, y_pred))

matrix_fwhm[j,0] = metrics.mean_absolute_error(z_test, y_pred_fwhm)*ratio2
matrix_fwhm[j,1] = metrics.r2_score(z_test, y_pred_fwhm)
matrix_fwhm[j,2] = rae(z_test, y_pred_fwhm)
matrix_fwhm[j,3] = ratio2*np.sqrt(metrics.mean_squared_error(z_test, y_pred_fwhm))

matrix_cascade[j,0] = metrics.mean_absolute_error(z_test, y_pred_cascade)*ratio2
matrix_cascade[j,1] = metrics.r2_score(z_test, y_pred_cascade)
matrix_cascade[j,2] = rae(z_test, y_pred_cascade)
matrix_cascade[j,3] = ratio2*np.sqrt(metrics.mean_squared_error(z_test, y_pred_cascade))

#errors in nm
#UNnormalize the data first
y_test = y_test*(1239.84193/400 - 1239.84193/620)+1239.84193/620
y_pred = y_pred*(1239.84193/400 - 1239.84193/620)+1239.84193/620
z_test = z_test*(0.35)+0.05
y_pred_fwhm = y_pred_fwhm*(0.35)+0.05
y_pred_cascade = y_pred_cascade*(0.35)+0.05

#Calculate data in nm and eV
matrix[j,4] = metrics.mean_absolute_error(peak_eV_nm(y_test), peak_eV_nm(y_pred))
matrix[j,5] = metrics.r2_score(peak_eV_nm(y_test), peak_eV_nm(y_pred))
matrix[j,6] = rae(peak_eV_nm(y_test), peak_eV_nm(y_pred))
matrix[j,7] = np.sqrt(metrics.mean_squared_error(peak_eV_nm(y_test), peak_eV_nm(y_pred)))

matrix_fwhm[j,4] = metrics.mean_absolute_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm))
matrix_fwhm[j,5] = metrics.r2_score(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm))
matrix_fwhm[j,6] = rae(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm))
matrix_fwhm[j,7] = np.sqrt(metrics.mean_squared_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_fwhm)))

matrix_cascade[j,4] = metrics.mean_absolute_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade))
matrix_cascade[j,5] = metrics.r2_score(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade))
matrix_cascade[j,6] = rae(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade))
matrix_cascade[j,7] = np.sqrt(metrics.mean_squared_error(FWHM_eV_nm(y_test,z_test), FWHM_eV_nm(y_pred,y_pred_cascade)))

np.set_printoptions(precision=5, threshold=5, edgeitems=4, suppress=True)

print('\033[1m' + 'Absorption Peak/FWHM Extrapolation (with dropout at inference)' + '\033[0m')
print('\033[1m' + 'Absorbance Peak' + '\033[0m')
print("MAE (eV):\t", "{:.4f}".format(matrix[0,0]))
print("R2 (eV):\t", "{:.4f}".format(matrix[0,1]))
print("RAE (eV):\t", "{:.4f}".format(matrix[0,2]))
print("RMSE (eV):\t", "{:.4f}".format(matrix[0,3]))
print("MAE (nm):\t","{:.4f}".format(matrix[0,4]))
print("R2 (nm):\t", "{:.4f}".format(matrix[0,5]))
print("RAE (nm):\t","{:.4f}".format(matrix[0,6]))
print("RMSE (nm):\t", "{:.4f}".format(matrix[0,7]))

print('\033[1m' + 'Absorbance FWHM (direct)' + '\033[0m')
print("MAE (eV):\t", "{:.4f}".format(matrix_fwhm[0,0]))
print("R2 (eV):\t", "{:.4f}".format(matrix_fwhm[0,1]))
print("RAE (eV):\t", "{:.4f}".format(matrix_fwhm[0,2]))
print("RMSE (eV):\t", "{:.4f}".format(matrix_fwhm[0,3]))
print("MAE (nm):\t","{:.4f}".format(matrix_fwhm[0,4]))
print("R2 (nm):\t", "{:.4f}".format(matrix_fwhm[0,5]))
print("RAE (nm):\t","{:.4f}".format(matrix_fwhm[0,6]))
print("RMSE (nm):\t", "{:.4f}".format(matrix_fwhm[0,7]))

print('\033[1m' + 'Absorbance FWHM (cascade)' + '\033[0m')
print("MAE (eV):\t", "{:.4f}".format(matrix_cascade[0,0]))
print("R2 (eV):\t", "{:.4f}".format(matrix_cascade[0,1]))
print("RAE (eV):\t", "{:.4f}".format(matrix_cascade[0,2]))
print("RMSE (eV):\t", "{:.4f}".format(matrix_cascade[0,3]))
print("MAE (nm):\t","{:.4f}".format(matrix_cascade[0,4]))
print("R2 (nm):\t", "{:.4f}".format(matrix_cascade[0,5]))
print("RAE (nm):\t","{:.4f}".format(matrix_cascade[0,6]))
print("RMSE (nm):\t", "{:.4f}".format(matrix_cascade[0,7]))

y_test = y_test.to_numpy().reshape(1,-1)
z_test = z_test.to_numpy().reshape(1,-1)
y_pred = y_pred.reshape(1,-1)
y_pred_fwhm = y_pred_fwhm.reshape(1,-1)
y_pred_cascade = y_pred_cascade.reshape(1,-1)

np.savetxt("MCNN_UV_out_test_peak.csv", np.vstack((y_test,y_pred)).T, delimiter=",")
np.savetxt("MCNN_UV_out_test_fwhm.csv", np.vstack((z_test,y_pred_fwhm)).T, delimiter=",")
np.savetxt("MCNN_UV_out_test_cascade.csv", np.vstack((z_test,y_pred_cascade)).T, delimiter=",")
# Out:
# Absorption Peak/FWHM Extrapolation (with dropout at inference)
# Absorbance Peak
# MAE (eV):	 0.0505
# R2 (eV):	 0.8721
# RAE (eV):	 0.3048
# RMSE (eV):	 0.0712
# MAE (nm):	 11.2346
# R2 (nm):	 0.8268
# RAE (nm):	 0.3172
# RMSE (nm):	 17.4266
# Absorbance FWHM (direct)
# MAE (eV):	 0.0274
# R2 (eV):	 -0.5122
# RAE (eV):	 1.0131
# RMSE (eV):	 0.0388
# MAE (nm):	 6.4489
# R2 (nm):	 -3.1955
# RAE (nm):	 1.4285
# RMSE (nm):	 10.7695
# Absorbance FWHM (cascade)
# MAE (eV):	 0.0287
# R2 (eV):	 -0.6942
# RAE (eV):	 1.0631
# RMSE (eV):	 0.0411
# MAE (nm):	 7.0895
# R2 (nm):	 -3.5380
# RAE (nm):	 1.5704
# RMSE (nm):	 11.2005

# %%
random_points = pd.read_csv('randompoints.csv')
random_points = random_points[['OA_Cd_ratio','T_reactor','Cd_mM','Se_mM','t_s']]

# %%
#prediction for Peak

X_test = random_points

#prediction for Peak
y_pred = model_peak.predict(X_test)
#prediction for FWHM (direct)
y_pred_fwhm = model_fwhm.predict(X_test)
#prediction for FWHM (cascade)
X_test.insert(5, "Peak_eV", model_peak.predict(X_test), True)
y_pred_cascade = model_cascade.predict(X_test)


points1 = y_pred*(1239.84193/400 - 1239.84193/620)+1239.84193/620
points2 = y_pred_cascade*(0.35)+0.05
plt.scatter(points1,points2)
# Out:
# 3125/3125 [==============================] - 2s 746us/step
# 3125/3125 [==============================] - 2s 696us/step
# 3125/3125 [==============================] - 2s 704us/step
# 3125/3125 [==============================] - 2s 685us/step

# %%
plt.scatter(points1,points2, s=5, alpha = 0.1)

# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt
import random
  
# Creating dataset
peaks = points1.reshape(-1)
fwhm = points2.reshape(-1)
  
fig, ax = plt.subplots(figsize =(10, 7))
# Creating plot
counts, xedges, yedges, im  = ax.hist2d(peaks, fwhm, bins = 100,cmap = plt.cm.nipy_spectral)
plt.title("Simple 2D Histogram")
  
# show plot
plt.show()
fig.colorbar(im, ax = ax)
